# %%
from laboneq_helper import *

serial_num = 'dev12460'

yaml_fn = generate_descriptor_yaml(
    filename = 'default_descriptor.yaml',
    devices = {
        "SHFQC" : [{
            'serial': serial_num,
            # 'external_clock':True,
            'ro_multiplex': 8
            }],
        },
    )
