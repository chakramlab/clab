# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Reload-modules" data-toc-modified-id="Reload-modules-0.0.1"><span class="toc-item-num">0.0.1&nbsp;&nbsp;</span>Reload modules</a></span></li><li><span><a href="#Fitting-functions" data-toc-modified-id="Fitting-functions-0.0.2"><span class="toc-item-num">0.0.2&nbsp;&nbsp;</span>Fitting functions</a></span></li></ul></li></ul></li><li><span><a href="#Experiments" data-toc-modified-id="Experiments-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Experiments</a></span><ul class="toc-item"><li><span><a href="#First--tone" data-toc-modified-id="First--tone-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>First  tone</a></span><ul class="toc-item"><li><span><a href="#1st-tone" data-toc-modified-id="1st-tone-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>1st tone</a></span></li><li><span><a href="#1st-tone-pi-pulse" data-toc-modified-id="1st-tone-pi-pulse-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>1st tone pi pulse</a></span></li><li><span><a href="#Power-scan" data-toc-modified-id="Power-scan-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>Power scan</a></span></li><li><span><a href="#Qubit-spec" data-toc-modified-id="Qubit-spec-1.1.4"><span class="toc-item-num">1.1.4&nbsp;&nbsp;</span>Qubit spec</a></span><ul class="toc-item"><li><span><a href="#Save" data-toc-modified-id="Save-1.1.4.1"><span class="toc-item-num">1.1.4.1&nbsp;&nbsp;</span>Save</a></span></li></ul></li><li><span><a href="#Qubit-spec-2d" data-toc-modified-id="Qubit-spec-2d-1.1.5"><span class="toc-item-num">1.1.5&nbsp;&nbsp;</span>Qubit spec 2d</a></span></li><li><span><a href="#Fidelity-plots" data-toc-modified-id="Fidelity-plots-1.1.6"><span class="toc-item-num">1.1.6&nbsp;&nbsp;</span>Fidelity plots</a></span></li><li><span><a href="#Histogram-f-qubit" data-toc-modified-id="Histogram-f-qubit-1.1.7"><span class="toc-item-num">1.1.7&nbsp;&nbsp;</span>Histogram f qubit</a></span><ul class="toc-item"><li><span><a href="#blobs" data-toc-modified-id="blobs-1.1.7.1"><span class="toc-item-num">1.1.7.1&nbsp;&nbsp;</span>blobs</a></span></li></ul></li><li><span><a href="#Rabi" data-toc-modified-id="Rabi-1.1.8"><span class="toc-item-num">1.1.8&nbsp;&nbsp;</span>Rabi</a></span></li><li><span><a href="#1d" data-toc-modified-id="1d-1.1.9"><span class="toc-item-num">1.1.9&nbsp;&nbsp;</span>1d</a></span></li><li><span><a href="#Ramsey" data-toc-modified-id="Ramsey-1.1.10"><span class="toc-item-num">1.1.10&nbsp;&nbsp;</span>Ramsey</a></span></li><li><span><a href="#spin-echo" data-toc-modified-id="spin-echo-1.1.11"><span class="toc-item-num">1.1.11&nbsp;&nbsp;</span>spin echo</a></span></li><li><span><a href="#Multiple-spin-echo" data-toc-modified-id="Multiple-spin-echo-1.1.12"><span class="toc-item-num">1.1.12&nbsp;&nbsp;</span>Multiple spin echo</a></span></li><li><span><a href="#T1-with-pulses" data-toc-modified-id="T1-with-pulses-1.1.13"><span class="toc-item-num">1.1.13&nbsp;&nbsp;</span>T1 with pulses</a></span><ul class="toc-item"><li><span><a href="#2d-t1" data-toc-modified-id="2d-t1-1.1.13.1"><span class="toc-item-num">1.1.13.1&nbsp;&nbsp;</span>2d t1</a></span></li><li><span><a href="#ef-T1" data-toc-modified-id="ef-T1-1.1.13.2"><span class="toc-item-num">1.1.13.2&nbsp;&nbsp;</span>ef T1</a></span></li><li><span><a href="#Temp-dependence" data-toc-modified-id="Temp-dependence-1.1.13.3"><span class="toc-item-num">1.1.13.3&nbsp;&nbsp;</span>Temp dependence</a></span></li></ul></li><li><span><a href="#ef-spectroscopy" data-toc-modified-id="ef-spectroscopy-1.1.14"><span class="toc-item-num">1.1.14&nbsp;&nbsp;</span>ef spectroscopy</a></span></li><li><span><a href="#ef-spec-at-peak-only" data-toc-modified-id="ef-spec-at-peak-only-1.1.15"><span class="toc-item-num">1.1.15&nbsp;&nbsp;</span>ef spec at peak only</a></span></li><li><span><a href="#ef-rabi-2d" data-toc-modified-id="ef-rabi-2d-1.1.16"><span class="toc-item-num">1.1.16&nbsp;&nbsp;</span>ef rabi 2d</a></span></li><li><span><a href="#ef-rabi-1d" data-toc-modified-id="ef-rabi-1d-1.1.17"><span class="toc-item-num">1.1.17&nbsp;&nbsp;</span>ef rabi 1d</a></span></li><li><span><a href="#ef-ramsey" data-toc-modified-id="ef-ramsey-1.1.18"><span class="toc-item-num">1.1.18&nbsp;&nbsp;</span>ef ramsey</a></span></li><li><span><a href="#Qubit-Temp" data-toc-modified-id="Qubit-Temp-1.1.19"><span class="toc-item-num">1.1.19&nbsp;&nbsp;</span>Qubit Temp</a></span><ul class="toc-item"><li><span><a href="#Qubit-temp-calibration" data-toc-modified-id="Qubit-temp-calibration-1.1.19.1"><span class="toc-item-num">1.1.19.1&nbsp;&nbsp;</span>Qubit temp calibration</a></span></li></ul></li><li><span><a href="#T1rho" data-toc-modified-id="T1rho-1.1.20"><span class="toc-item-num">1.1.20&nbsp;&nbsp;</span>T1rho</a></span></li><li><span><a href="#fh-spec" data-toc-modified-id="fh-spec-1.1.21"><span class="toc-item-num">1.1.21&nbsp;&nbsp;</span>fh spec</a></span></li><li><span><a href="#Temp-Loop" data-toc-modified-id="Temp-Loop-1.1.22"><span class="toc-item-num">1.1.22&nbsp;&nbsp;</span>Temp Loop</a></span></li></ul></li></ul></li><li><span><a href="#Octave-Testing" data-toc-modified-id="Octave-Testing-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Octave Testing</a></span></li><li><span><a href="#Octave-Introduction" data-toc-modified-id="Octave-Introduction-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Octave Introduction</a></span></li></ul></div>

# %%
from qm.QuantumMachinesManager import QuantumMachinesManager
from qm.qua import *
from configuration import *

import matplotlib.pyplot as plt
import time
from IPython import display
import importlib, sys
import scipy.constants as sci

sys.path.append('C:\\Users\\tdinapoli\\Desktop\\QM OPX\\T150_OPX')
sys.path.append('C:\\_Lib\\python\\QM')
sys.path.append('C:\\Users\\measPC\\OneDrive - Rutgers University\\Documents\\slab-master-1\\slab-master\\slab')

from dsfit import *

from slab.instruments import PNAX
import pandas as pd
from matplotlib import colors
from datetime import datetime
from gershlab.MWmeasurement import MWmeas

# %%
#%matplotlib notebook
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
opx_ip='192.168.88.252'
opx_port='9510'

# %%
qmm = QuantumMachinesManager(host=opx_ip, port=opx_port, octave=octave_config)
# Out:
# 2023-10-31 12:08:14,051 - qm - INFO     - Performing health check
# 2023-10-31 12:08:14,062 - qm - INFO     - Health check passed

# %%
# Is this needed after the cell above? - ROB
qmm = QuantumMachinesManager()
# Out:
# 2023-10-31 12:04:43,640 - qm - ERROR    - Failed to detect a QuantumMachines server. Tried connecting to 192.168.88.252:80.
# Errors:
# 192.168.88.252:80: All connection attempts failed
# Traceback (most recent call last):
#   File "d:\anaconda3\lib\site-packages\anyio\_core\_sockets.py", line 127, in try_connect
#     stream = await asynclib.connect_tcp(remote_host, remote_port, local_address)
#   File "d:\anaconda3\lib\site-packages\anyio\_backends\_asyncio.py", line 1518, in connect_tcp
#     await get_running_loop().create_connection(StreamProtocol, host, port,
#   File "d:\anaconda3\lib\asyncio\base_events.py", line 1025, in create_connection
#     raise exceptions[0]
#   File "d:\anaconda3\lib\asyncio\base_events.py", line 1010, in create_connection
#     sock = await self._connect_sock(
#   File "d:\anaconda3\lib\asyncio\base_events.py", line 924, in _connect_sock
#     await self.sock_connect(sock, address)
# ...

# %%
qmm.list_open_quantum_machines()
# Out:
# ['qm-1698767192432']

# %%
importlib.reload(sys.modules['gershlab.MWmeasurement'])
importlib.reload(sys.modules['gershlab.QCmeasurement'])
from gershlab.MWmeasurement import MWmeas

# %%
bf=MWmeas('T150_OPX')

# %%
from qcodes.instrument.base import InstrumentBase
from qcodes.instrument.parameter import Parameter, ArrayParameter, MultiParameter, ManualParameter
from qcodes.tests.instrument_mocks import DummyInstrument
from qcodes.utils import validators

# %%
from qcodes.instrument.parameter import Parameter

fr_param=Parameter(name='Frequency',label='Frequency',unit='Hz')
fftfreq_param=Parameter(name='fftfreq',label='Frequency',unit='GHz')

# %%
from qcodes.instrument.parameter import Parameter

i_param=Parameter(name='I',label='I',unit='V')
q_param=Parameter(name='Q',label='Q',unit='V')
mag_param=Parameter(name='mag',label='mag',unit='V')
fft_param=Parameter(name='mag',label='mag',unit='V')

V_gate=Parameter(name='Vgate',label='Vgate',unit='V')
amplitude=Parameter(name='amp',label='amp',unit=None)
buffer=Parameter(name='buff',label='buff',unit=None)

# %%
import time
from qcodes.instrument.parameter import Parameter

Time=Parameter(name='Time',label='Time',unit='ns')
Timesec=Parameter(name='Timesec',label='Time',unit='sec')

Time.ini = lambda: time.time()-start

# %%
class IQArray(MultiParameter):
    def __init__(self):
        # names, labels, and units are the same
        super().__init__('iq_array', names=('I', 'Q'), shapes=((), ()),
                         labels=('In phase amplitude', 'Quadrature amplitude'),
                         units=('V', 'V'),
                         # note that EACH item needs a sequence of setpoint arrays
                         # so a 1D item has its setpoints wrapped in a length-1 tuple
                         setpoints=((), ()),
                         docstring='param that returns two single values, I and Q')

    def get_raw(self):
        return ((),())

iq_array = IQArray()
fft_array = IQArray()

# %% [markdown]
# ### Reload modules

# %%
importlib.reload(sys.modules['configuration'])
from configuration import *

# %%
from OPXexperiments import *
T150=OPXexp()
# Out:
# 2023-10-31 12:07:29,649 - qm - ERROR    - Failed to detect a QuantumMachines server. Tried connecting to 192.168.88.252:80.
# Errors:
# 192.168.88.252:80: All connection attempts failed
# Traceback (most recent call last):
#   File "d:\anaconda3\lib\site-packages\anyio\_core\_sockets.py", line 127, in try_connect
#     stream = await asynclib.connect_tcp(remote_host, remote_port, local_address)
#   File "d:\anaconda3\lib\site-packages\anyio\_backends\_asyncio.py", line 1518, in connect_tcp
#     await get_running_loop().create_connection(StreamProtocol, host, port,
#   File "d:\anaconda3\lib\asyncio\base_events.py", line 1025, in create_connection
#     raise exceptions[0]
#   File "d:\anaconda3\lib\asyncio\base_events.py", line 1010, in create_connection
#     sock = await self._connect_sock(
#   File "d:\anaconda3\lib\asyncio\base_events.py", line 924, in _connect_sock
#     await self.sock_connect(sock, address)
# ...

# %%
importlib.reload(sys.modules['OPXexperiments'])
from OPXexperiments import *

# %%
T150=OPXexp()

# %%
from scipy.fft import fft, fftfreq, fftshift

# %% [markdown]
# ### Fitting functions

# %%
from scipy import optimize

def exp_fit(x, a, b,c):
    return a * np.exp(-x/b)+c
def qp_exp_fit(x, a, b,c):
    return np.sqrt(b*x)*a * np.exp(-b/x)+c
def boltz_fit(x, a, b):
    return a * np.exp(-b/x)

def double_exp_fit(x, a, b,c,d,f):
    return a * np.exp(-x/b)+c+d*np.exp(-x/f)

def rabi_fit(x, a, b,c,omega,phi):
    return a * np.exp(-x/b)*np.cos(np.pi*omega*x+phi)+c
def ramsey_fit(x, a, b,c,Delta,phi):
    return a * np.exp(-x/b)*np.cos(2*np.pi*Delta*x+phi)+c
def ef_rabi_fit(x, a, b,c,omega,phi,d,f):
    return a * np.exp(-x/b)*np.cos(np.pi*omega*x+phi)-f*np.exp(-x/d)+c
def histogram(Is,Qs,numbins=100):


    a_num = len(Is[0])
    

    colors = ['r', 'b', 'g','orange']
    labels = ['g', 'e', 'f','h']
    titles = ['-I', '-Q']

    fig = plt.figure(figsize=(12,16))

    ax = fig.add_subplot(421)
    x0g, y0g = np.mean(Is[0]), np.mean(Qs[0])
    x0e, y0e = np.mean(Is[1]), np.mean(Qs[1])
    phi = np.arctan((y0e - y0g) / (x0e - x0g))
    for ii in range(2):
        ax.plot(Is[ii], Qs[ii], '.', color=colors[ii], alpha=0.85)
    ax.plot(x0g, y0g,'v',color='black')
    ax.plot(x0e, y0e,'^',color='black')

    ax.set_xlabel('I (V)')
    ax.set_ylabel('Q (V)')


    ax = fig.add_subplot(422)

    ax.plot(x0g, y0g,'v',color='black')
    ax.plot(x0e, y0e,'^',color='black')
    ax.set_xlabel('I')
    ax.set_ylabel('Q')




    Isrot = [Is[ii] * np.cos(phi) + Qs[ii] * np.sin(phi) for ii in range(2)]
    Qsrot = [-Is[ii] * np.sin(phi) + Qs[ii] * np.cos(phi) for ii in range(2)]


    ax = fig.add_subplot(423, title='rotated')
    Is,Qs = Isrot,Qsrot
    
    x0g, y0g = np.mean(Is[0]), np.mean(Qs[0])
    x0e, y0e = np.mean(Is[1]), np.mean(Qs[1])
    phi = np.arctan((y0e - y0g) / (x0e - x0g))
    for ii in range(2):
        ax.plot(Is[ii], Qs[ii], '.', color=colors[ii], alpha=0.85)
    ax.plot(x0g, y0g,'v',color='black')
    ax.plot(x0e, y0e,'^',color='black')

    ax.set_xlabel('I (V)')
    ax.set_ylabel('Q (V)')


    ax = fig.add_subplot(424)

    ax.plot(x0g, y0g,'v',color='black')
    ax.plot(x0e, y0e,'^',color='black')
    ax.set_xlabel('I')
    ax.set_ylabel('Q')


    ax = fig.add_subplot(4, 2, 5, title='I')
    ax.hist(Is[0], bins=numbins, alpha=0.75, color=colors[0])
    ax.hist(Is[1], bins=numbins, alpha=0.75, color=colors[1])
    ax.set_xlabel('I' + '(V)')
    ax.set_ylabel('Number')
    ax.legend()


    ax = fig.add_subplot(4, 2, 6, title='Q')
    ax.hist(Qs[0], bins=numbins, alpha=0.75, color=colors[0])
    ax.hist(Qs[1], bins=numbins, alpha=0.75, color=colors[1])

    ax.set_xlabel('Q' + '(V)')
    ax.set_ylabel('Number')
    ax.legend()

    sshg, ssbinsg = np.histogram(Is[0], bins=numbins,range = [min(Is[0]),max(Is[0])])
    sshe, ssbinse = np.histogram(Is[1], bins=numbins,range = [min(Is[0]),max(Is[0])])
    fid = np.abs(((np.cumsum(sshg) - np.cumsum(sshe)) / sshg.sum())).max()
    
    returnfid = fid
    print("Single shot readout fidility from channel I", " = ", fid)
    print('---------------------------')
    
    ax = fig.add_subplot(4, 2, 7)
    ax.plot(ssbinse[:-1], np.cumsum(sshg) / sshg.sum(), color=colors[0])
    ax.plot(ssbinse[:-1], np.cumsum(sshe) / sshg.sum(), color=colors[1])
    ax.plot(ssbinse[:-1], np.abs(np.cumsum(sshe) - np.cumsum(sshg)) / sshg.sum(), color='k')
    
    
    sshg, ssbinsg = np.histogram(Qs[0], bins=numbins,range = [min(Qs[0]),max(Qs[0])])
    sshe, ssbinse = np.histogram(Qs[1], bins=numbins,range = [min(Qs[0]),max(Qs[0])])
    fid = np.abs(((np.cumsum(sshg) - np.cumsum(sshe)) / sshg.sum())).max()

    print("Single shot readout fidility from channel Q", i, " = ", fid)
    print('---------------------------')

    ax = fig.add_subplot(4, 2, 8)
    ax.plot(ssbinse[:-1], np.cumsum(sshg) / sshg.sum(), color=colors[0])
    ax.plot(ssbinse[:-1], np.cumsum(sshe) / sshg.sum(), color=colors[1])
    ax.plot(ssbinse[:-1], np.abs(np.cumsum(sshe) - np.cumsum(sshg)) / sshg.sum(), color='k')


    fig.tight_layout()
    plt.show()
    return (returnfid)
def histogram_simp(Is,Qs,ax,numbins=100):


    a_num = len(Is[0])
    

    colors = ['r', 'b', 'g','orange']
    labels = ['g', 'e', 'f','h']
    titles = ['-I', '-Q']


    x0g, y0g = np.mean(Is[0]), np.mean(Qs[0])
    x0e, y0e = np.mean(Is[1]), np.mean(Qs[1])
    phi = np.arctan((y0e - y0g) / (x0e - x0g))
   
    Isrot = [Is[ii] * np.cos(phi) + Qs[ii] * np.sin(phi) for ii in range(2)]
    Qsrot = [-Is[ii] * np.sin(phi) + Qs[ii] * np.cos(phi) for ii in range(2)]

    Is,Qs = Isrot,Qsrot
    
    x0g, y0g = np.mean(Is[0]), np.mean(Qs[0])
    x0e, y0e = np.mean(Is[1]), np.mean(Qs[1])
    phi = np.arctan((y0e - y0g) / (x0e - x0g))
    

    sshg, ssbinsg = np.histogram(Is[0], bins=numbins,range = [min(Is[0]),max(Is[0])])
    sshe, ssbinse = np.histogram(Is[1], bins=numbins,range = [min(Is[0]),max(Is[0])])
    fid = np.abs(((np.cumsum(sshg) - np.cumsum(sshe)) / sshg.sum())).max()
    
    ax.plot(ssbinse[:-1], np.cumsum(sshg) / sshg.sum(), color=colors[0])
    ax.plot(ssbinse[:-1], np.cumsum(sshe) / sshg.sum(), color=colors[1])
    ax.plot(ssbinse[:-1], np.abs(np.cumsum(sshe) - np.cumsum(sshg)) / sshg.sum(), color='k')
    
    
    return (fid)

# %%
def therm_exp_fit(x, a, b,c):
    return a * np.exp(-x/b)+c

# %% [markdown]
# # Experiments

# %% [markdown]
# ## First  tone

# %% [markdown]
# ### 1st tone

# %%
qm = qmm.open_qm(config)
job = qm.execute(T150.resspec()[0])
res = job.result_handles
res.wait_for_all_values()
I = res.I.fetch_all()
Q = res.Q.fetch_all()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-8c9470d3e17e> in <module>
# ----> 1 qm = qmm.open_qm(config)
#       2 job = qm.execute(T150.resspec()[0])
#       3 res = job.result_handles
#       4 res.wait_for_all_values()
#       5 I = res.I.fetch_all()
#
# d:\anaconda3\lib\site-packages\qm\QuantumMachinesManager.py in open_qm(self, config, close_other_machines)
#
# d:\anaconda3\lib\site-packages\qm\QuantumMachinesManager.py in _open_qm_pb(self, pb_config, close_other_machines)
#
# d:\anaconda3\lib\site-packages\qm\program\ConfigBuilder.py in convert_msg_to_config(config)
#       6
#       7 def convert_msg_to_config(config: QuaConfig) -> DictQuaConfig:
# ----> 8     msg_dict = config.to_dict()
#       9
#      10     if "v1Beta" in msg_dict:
#
# AttributeError: to_dict

# %%
print(I)

# %% [markdown]
# Around 7.31 GHz at ~1K

# %%
T150.plotIQ(I,Q,T150.resspec()[])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-e5989c255fca> in <module>
# ----> 1 T150.plotIQ(I,Q,T150.resspec()[:-2])
#
# ~\OneDrive - Rutgers University\GERSHENSON LAB - Documents\OurData\measMW\OPX_testing_10_23\OPXexperiments.py in plotIQ(self, I, Q, fvec)
#     277         ax = fig.add_subplot(111)
#     278
# --> 279         ax.plot(fvec,I,label='I')
#     280         ax.plot(fvec,Q,label='Q')
#     281         mags = np.sqrt(I**2+Q**2)
#
# ~\AppData\Roaming\Python\Python38\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
#    1604         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1605         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1606         for line in lines:
#    1607             self.add_line(line)
#
# ...

# %%
dir(T150)
# Out:
# ['IQ_blobs',
#  'IQ_blobs_f',
#  'IQ_blobs_wRabi',
#  'SNR',
#  'T1',
#  'T1_f',
#  'T1rho',
#  'T1rho_test',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'ef_T1',
#  'ef_rabi1d',
#  'ef_rabi2d',
#  'ef_ramsey',
#  'ef_spec',
#  'ef_spec_V',
#  'ef_spec_diff',
#  'ef_spec_temp',
#  'fh_spec',
#  'histogram',
#  'histogram_f',
#  'histogram_fid',
#  'histogram_simp_fid',
#  'multiple_spin_echo',
#  'plot2d',
#  'plotIQ',
#  'pumped_qubit_temp',
#  'qubit_temp',
#  'qubitspec',
#  'qubitspec2d',
#  'qubitspec_V',
#  'qubitspec_gauss',
#  'qubitspec_t',
#  'rabi1d',
#  'rabi1d_discriminate',
#  'rabi1d_dt',
# ...

# %%
bf.mock_meas((iq_array,zip(I,Q)),(fr_param,T150.resspec()[1]),label='1st tone')
# Out:
# Starting experimental run with id: 4.
# 4

# %% [markdown]
# ### 1st tone pi pulse

# %%
dur=2000
config['pulses']['readout_pulse']['length']=dur
config['integration_weights']['integW1']['cosine']=[1.0] * int(dur // 4)
config['integration_weights']['integW1']['sine']  =[0.0] * int(dur // 4)
config['integration_weights']['integW2']['cosine']=[0.0] * int(dur // 4)
config['integration_weights']['integW2']['sine']  =[1.0] * int(dur // 4)

# %%
qm = qmm.open_qm(config)
job = qm.execute(T151_1.resspec_pi()[0])
res = job.result_handles
res.wait_for_all_values()
I = res.I.fetch_all()
Q = res.Q.fetch_all()
# Out:
# 2022-02-06 21:10:09,459 - qm - INFO - Flags:
# 2022-02-06 21:10:09,460 - qm - INFO - Sending program to QOP
# 2022-02-06 21:10:09,539 - qm - INFO - Executing program

# %%
Ig=np.array(I)[1::2]
Ie=np.array(I)[::2] 
Qg=np.array(Q)[1::2]
Qe=np.array(Q)[::2] 

f,ax=plt.subplots(figsize=(8,6))

ax.plot(T151_1.resspec_pi()[1]/1e6,Ig-Ie,label='I diff')
ax.plot(T151_1.resspec_pi()[1]/1e6,Qg-Qe,label='Q diff')
#ax.plot(T112.resspec_pi()[1],Qe)

# ax.axvline(29459000.0/1e6)
# ax.axvline(29474000.0/1e6)
ax.plot(T151_1.resspec_pi()[1]/1e6,np.sqrt(Ig**2+Qg**2),label='g')
ax.plot(T151_1.resspec_pi()[1]/1e6,np.sqrt(Ie**2+Qe**2),label='e')
T151_1.plotIQ(Ig,Qg,T151_1.resspec_pi()[1])
T151_1.plotIQ(Ie,Qe,T151_1.resspec_pi()[1])

ax.set_xlabel('IF (MHz)',fontsize=16)
ax.set_ylabel('S21 (V)',fontsize=16)
ax.legend(fontsize=16)
# Out:
# frIF= 30361000.0 Q= 20890.0
# fr= 7360400000.0 None
# frIF= 30363000.0 Q= 20630.0
# fr= 7360400000.0 None
# C:\Users\tdinapoli\Desktop\QM OPX\T151_1_Neon_OPX\OPXexperiments.py:292: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   return (fig.show(),print('fr=',float('%.5g' % nu_res),print('frIF=',float('%.5g' % p[2]),'Q=',float('%.4g' % Qfac))))
# C:\Users\tdinapoli\Desktop\QM OPX\T151_1_Neon_OPX\OPXexperiments.py:292: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   return (fig.show(),print('fr=',float('%.5g' % nu_res),print('frIF=',float('%.5g' % p[2]),'Q=',float('%.4g' % Qfac))))

# %%
qm = qmm.open_qm(config)
job = qm.execute(T140.resspec_efpi()[0])
res = job.result_handles
res.wait_for_all_values()
I = res.I.fetch_all()
Q = res.Q.fetch_all()
# Out:
# 2021-12-10 16:23:30,331 - qm - INFO - Performing health check
# 2021-12-10 16:23:30,337 - qm - INFO - Health check passed
# 2021-12-10 16:23:31,605 - qm - INFO - Flags:
# 2021-12-10 16:23:31,606 - qm - INFO - Executing high level program

# %%
Ig=np.array(I)[1::2]
Ie=np.array(I)[::2] 
Qg=np.array(Q)[1::2]
Qe=np.array(Q)[::2] 

f,ax=plt.subplots(figsize=(8,6))

ax.plot(T140.resspec_efpi()[1]/1e6,Ig-Ie,label='I diff')
#ax.plot(T112.resspec_pi()[1],Ie)
ax.plot(T140.resspec_efpi()[1]/1e6,Qg-Qe,label='Q diff')
#ax.plot(T112.resspec_pi()[1],Qe)

# ax.axvline(29459000.0/1e6)
# ax.axvline(29474000.0/1e6)
ax.plot(T140.resspec_efpi()[1]/1e6,np.sqrt(Ig**2+Qg**2),label='g')
ax.plot(T140.resspec_efpi()[1]/1e6,np.sqrt(Ie**2+Qe**2),label='e')
T140.plotIQ(Ig,Qg,T140.resspec_efpi()[1])
T140.plotIQ(Ie,Qe,T140.resspec_efpi()[1])

ax.set_xlabel('IF (MHz)',fontsize=16)
ax.set_ylabel('S21 (V)',fontsize=16)
ax.legend(fontsize=16)
# Out:
# C:\Users\tdinapoli\Desktop\QM OPX\T140_1_Neon_OPX\OPXexperiments.py:292: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   return (fig.show(),print('fr=',float('%.5g' % nu_res),print('frIF=',float('%.5g' % p[2]),'Q=',float('%.4g' % Qfac))))
# frIF= 30243000.0 Q= 11870.0
# fr= 7360200000.0 None
# frIF= 30268000.0 Q= 11440.0
# fr= 7360300000.0 None
# C:\Users\tdinapoli\Desktop\QM OPX\T140_1_Neon_OPX\OPXexperiments.py:287: RuntimeWarning: invalid value encountered in sqrt
#   ax.plot(fvec,np.sqrt(lorfunc(p,fvec)),'r-')
# C:\Users\tdinapoli\Desktop\QM OPX\T140_1_Neon_OPX\OPXexperiments.py:292: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   return (fig.show(),print('fr=',float('%.5g' % nu_res),print('frIF=',float('%.5g' % p[2]),'Q=',float('%.4g' % Qfac))))

# %%
qm = qmm.open_qm(config)
job = qm.execute(T112.resspec_pi_fscan()[0])
res = job.result_handles
# Out:
# 2021-12-02 17:10:04,414 - qm - INFO - Flags:
# 2021-12-02 17:10:04,415 - qm - INFO - Executing high level program

# %%
I_hand=res.I
Q_hand=res.Q

I_hand.wait_for_values(1)
Q_hand.wait_for_values(1)

plt.figure()
while I_hand.is_processing():
    I=I_hand.fetch_all()
    Q=Q_hand.fetch_all()
    mag=np.sqrt(I**2+Q**2)
    ang=np.unwrap(np.angle(I+1j*Q))
    plt.pcolormesh(T112.resspec_pi_fscan()[2],T112.resspec_pi_fscan()[1],I.T[::2].T-I.T[1::2].T)
#     plt.show()
#     plt.pcolormesh(T112.resspec_pi_fscan()[2],T112.resspec_pi_fscan()[1],Q.T[::2].T-Q.T[1::2].T)
#     plt.show()
    #    plt.plot(fvec,ang/np.mean(ang)+0.04)
    display.display(plt.gcf())
    display.clear_output(wait=True)
    plt.pause(0.1)

# %% [markdown]
# ### Power scan

# %%
dur=2000
config['pulses']['readout_pulse']['length']=dur
config['integration_weights']['integW1']['cosine']=[1.0] * int(dur // 4)
config['integration_weights']['integW1']['sine']  =[0.0] * int(dur // 4)
config['integration_weights']['integW2']['cosine']=[0.0] * int(dur // 4)
config['integration_weights']['integW2']['sine']  =[1.0] * int(dur // 4)

# %%
dur
# Out:
# 2000

# %%
qm = qmm.open_qm(config)
job = qm.execute(T150.resspec_amp()[0])
res = job.result_handles
res.wait_for_all_values()
I = res.I.fetch_all()
Q = res.Q.fetch_all()
# Out:
# 2022-03-05 21:17:06,212 - qm - INFO - Flags:
# 2022-03-05 21:17:06,213 - qm - INFO - Sending program to QOP
# 2022-03-05 21:17:06,276 - qm - INFO - Executing program

# %%
T150.plot2d(I,Q,T150.resspec_amp()[2],T150.resspec_amp()[1])
# Out:
# C:\Users\tdinapoli\Desktop\QM OPX\T150_OPX\OPXexperiments.py:824: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   ax.pcolormesh(x1,x2,mags)
# <AxesSubplot:>

# %%
avec=T151_2.resspec_amp()[2]
fvec=T151_2.resspec_amp()[1]
mag=np.sqrt(I**2+Q**2).T
Qfaclst=[]
linewidth=[]
reslst=[]
f,ax=plt.subplots()
for i in range(len(avec)):
    p = fitlor(fvec,(mag[i]/np.max(mag[i],axis=0))**2,showfit=False)
    ax.plot(fvec,np.sqrt(lorfunc(p,fvec)),'r-',alpha=0.2)
    ax.plot(fvec,mag[i]/np.max(mag[i]))

    nu_res = p[2] +7.225e9
    Qfac = nu_res/p[3]/2
    Qfaclst=np.append(Qfaclst,Qfac)
    linewidth=np.append(linewidth,p[3])
    reslst=np.append(reslst,nu_res)
    
plt.plot(T151_2.resspec_amp()[1],np.sqrt(I**2+Q**2)/np.max(np.sqrt(I**2+Q**2),axis=0));
#plt.xlim(149.6e6,150e6)
# Out:
# <ipython-input-28-3b6513eebb10>:10: RuntimeWarning: invalid value encountered in sqrt
#   ax.plot(fvec,np.sqrt(lorfunc(p,fvec)),'r-',alpha=0.2)

# %%
f,ax=plt.subplots()

ax.plot(avec[:],reslst[:],'x')
print('dispersion= ',np.max(reslst)-np.min(reslst[1:]))
# Out:
# dispersion=  179294.63004875183

# %%
f,ax=plt.subplots()

#ax.plot(avec,Qfaclst,'x')
ax.plot(avec[1:],2*linewidth[1:]/1e6,'x')

# ax.set_xscale('log')
# ax.set_yscale('log')

ax.set_xlabel('amplitude of 2nd tone (14dBm)',size=16)
ax.set_ylabel('line width (MHz)',size=16)
# Out:
# Text(0, 0.5, 'line width (MHz)')

# %%
f,ax=plt.subplots()

ax.plot(avec[1:],Qfaclst[1:],'x')

# %%
bf.mock_meas((iq_array,np.stack((I,Q),axis=2)),(amplitude,T151.resspec_amp()[2]),x1=(fr_param,T151.resspec_amp()[1]),label='resspec')
# Out:
# Starting experimental run with id: 36.
# 36

# %%
f,ax=plt.subplots()

ax.plot(avec[1:],reslst[1:],'x')
print('dispersion= ',np.max(reslst)-np.min(reslst[1:]))

f,ax=plt.subplots()

#ax.plot(avec,Qfaclst,'x')
ax.plot(avec[1:],2*linewidth[1:]/1e6,'x')

# ax.set_xscale('log')
# ax.set_yscale('log')

ax.set_xlabel('amplitude of 2nd tone (14dBm)',size=16)
ax.set_ylabel('line width (MHz)',size=16)

f,ax=plt.subplots()

ax.plot(avec[1:],Qfaclst[1:],'x')
# Out:
# dispersion=  235500.63921260834

# %% [markdown]
# ### Qubit spec

# %%
I_all,Q_all,ts = [],[],[]

for i in range(200):
    qm = qmm.open_qm(config)
    job = qm.execute(T150.qubitspec()[0])
    res = job.result_handles
    res.wait_for_all_values()
    I = res.I.fetch_all()
    Q = res.Q.fetch_all()
    I_all.append(I)
    Q_all.append(Q)
    ts.append(time.time())
    print("elapsed time {:0.1f}".format(ts[i]-ts[0]))
# Out:
# 2022-03-21 11:50:06,481 - qm - INFO - Flags:
# 2022-03-21 11:50:06,497 - qm - INFO - Sending program to QOP
# 2022-03-21 11:50:06,602 - qm - INFO - Executing program
# elapsed time 0.0
# 2022-03-21 11:51:31,826 - qm - INFO - Flags:
# 2022-03-21 11:51:31,826 - qm - INFO - Sending program to QOP
# 2022-03-21 11:51:31,966 - qm - INFO - Executing program
# elapsed time 85.3
# 2022-03-21 11:52:56,884 - qm - INFO - Flags:
# 2022-03-21 11:52:56,884 - qm - INFO - Sending program to QOP
# 2022-03-21 11:52:56,965 - qm - INFO - Executing program
# elapsed time 170.3
# 2022-03-21 11:54:21,846 - qm - INFO - Flags:
# 2022-03-21 11:54:21,846 - qm - INFO - Sending program to QOP
# 2022-03-21 11:54:21,936 - qm - INFO - Executing program
# elapsed time 255.3
# 2022-03-21 11:55:46,739 - qm - INFO - Flags:
# 2022-03-21 11:55:46,739 - qm - INFO - Sending program to QOP
# 2022-03-21 11:55:46,817 - qm - INFO - Executing program
# ---------------------------------------------------------------------------
# ...

# %%
#40 mK on cooling
fvec=(T150.qubitspec()[1])*1e-9
f,ax=plt.subplots()
mags=np.sqrt(np.array(I_all)**2+np.array(Q_all)**2).T
ax.pcolormesh(ts,fvec,mags)
ax.set_ylabel('frequency (GHz)',fontsize=16)
ax.set_xlabel('time(s)',fontsize=16)

#ax.tick_params(size=8)
fvec=(T150.qubitspec()[1])*1e-9
f,ax=plt.subplots()
ax.plot(fvec,np.mean(mags,axis=1))
# Out:
# <ipython-input-74-e8adec10d612>:5: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   ax.pcolormesh(ts,fvec,mags)

# %%
#20mK
fvec=(T150.qubitspec()[1])*1e-9
f,ax=plt.subplots()
mags=np.sqrt(np.array(I_all)**2+np.array(Q_all)**2).T
ax.pcolormesh(ts,fvec,mags)
ax.set_ylabel('frequency (GHz)',fontsize=16)
ax.set_xlabel('time(s)',fontsize=16)

#ax.tick_params(size=8)
fvec=(T150.qubitspec()[1])*1e-9
f,ax=plt.subplots()
ax.plot(fvec,np.mean(mags,axis=1))
# Out:
# <ipython-input-112-f9c4b869291a>:5: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   ax.pcolormesh(ts,fvec,mags)

# %%
#20mK
fvec=(T150.qubitspec()[1])*1e-9
f,ax=plt.subplots()
mags=np.sqrt(np.array(I_all)**2+np.array(Q_all)**2).T
ax.pcolormesh(ts,fvec,mags)
ax.set_ylabel('frequency (GHz)',fontsize=16)
ax.set_xlabel('time(s)',fontsize=16)

#ax.tick_params(size=8)
fvec=(T150.qubitspec()[1])*1e-9
f,ax=plt.subplots()
ax.plot(fvec,np.mean(mags,axis=1))
# Out:
# <ipython-input-176-f9c4b869291a>:5: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   ax.pcolormesh(ts,fvec,mags)

# %%
fvec=(T150.qubitspec()[1])*1e-9
f,ax=plt.subplots()
mags=np.sqrt(np.array(I_all)**2+np.array(Q_all)**2).T
ax.pcolormesh(ts,fvec,mags)
ax.set_ylabel('frequency (GHz)',fontsize=16)
ax.set_xlabel('time(s)',fontsize=16)

#ax.tick_params(size=8)
fvec=(T150.qubitspec()[1])*1e-9
f,ax=plt.subplots()
ax.plot(fvec,np.mean(mags,axis=1))
# Out:
# <ipython-input-219-9e3dffd6f590>:4: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   ax.pcolormesh(ts,fvec,mags)

# %%
fvec=(T150.qubitspec()[1])*1e-9
f,ax=plt.subplots()
mags=np.sqrt(np.array(I_all)**2+np.array(Q_all)**2).T
ax.pcolormesh(ts,fvec,mags)
ax.set_ylabel('frequency (GHz)',fontsize=16)
ax.set_xlabel('time(s)',fontsize=16)

#ax.tick_params(size=8)
fvec=(T150.qubitspec()[1])*1e-9
f,ax=plt.subplots()
ax.plot(fvec,np.mean(mags,axis=1))
# Out:
# <ipython-input-173-9e3dffd6f590>:4: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   ax.pcolormesh(ts,fvec,mags)

# %%
#at 25mK after 6 day
fvec=(T151_2.qubitspec()[1])*1e-9
f,ax=plt.subplots()
mags=np.sqrt(np.array(I_all)**2+np.array(Q_all)**2).T
ax.pcolormesh(ts,fvec,mags)
#ax.set_xlabel('freqeuncy (GHz)',fontsize=16)
#ax.tick_params(size=8)
fvec=(T151_2.qubitspec()[1])*1e-9
f,ax=plt.subplots()
ax.plot(fvec,np.mean(mags,axis=1))
f,ax=plt.subplots()
# ax.plot(ts,mags[0].T)
# Out:
# <ipython-input-533-487b69c98b73>:5: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   ax.pcolormesh(ts,fvec,mags)

# %%
fvec=(T151_1.qubitspec()[1])*1e-9
f,ax=plt.subplots()
mags=np.sqrt(np.array(I_all)**2+np.array(Q_all)**2).T
ax.pcolormesh(ts,fvec,mags)
#ax.set_xlabel('freqeuncy (GHz)',fontsize=16)
#ax.tick_params(size=8)
fvec=(T151.qubitspec()[1])*1e-9
f,ax=plt.subplots()
ax.plot(fvec,np.mean(mags,axis=1))
f,ax=plt.subplots()
# ax.plot(ts,mags[0].T)
# Out:
# <ipython-input-351-e97641a51754>:4: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   ax.pcolormesh(ts,fvec,mags)

# %%
ts,fs,Is,Qs=bf.reshape_data(85,dscale=1)
# idx=12
# ts, fs, Ie, _, _, Qe = bf.xy_by_id(idx)

# scale = 50
# Is = np.reshape(Ie, (len(fs) // scale, scale))
# Qs = np.reshape(Qe, (len(fs) // scale, scale))
# ts = np.mean(np.reshape(ts, (len(fs) // scale, scale)), axis=0)
# fs = np.mean(np.reshape(fs, (len(fs) // scale, scale)), axis=1)

mags=np.sqrt(Is**2+Qs**2)
mags_norm=mags*0
mag_min=ts*0
f_min=ts*0
f_min1=ts*0
f_min_err=ts*0
f_min1_err=ts*0
for t in range(len(ts)):
    mags_norm[t]=mags[t]/np.mean(mags[t])
    
    p = fitlor(fs,-(mags_norm[t]/np.max(mags_norm[t],axis=0))**2,showfit=False)
    f_min[t]=p[2]
    f_min_err=p[3]
    

f,ax=plt.subplots(figsize=(10,5))

f_min_norm=(f_min-np.min(f_min))/(np.max(f_min)-np.min(f_min))
f_min1_norm=(f_min1-np.min(f_min1))/(np.max(f_min1)-np.min(f_min1))

ax1=ax.twinx()
ax.pcolormesh(ts,fs,mags_norm.T)
ax.plot(ts,f_min,color='r',alpha=0.5)
ax.fill_between(ts, (f_min-f_min_err), (f_min+f_min_err), color='r',alpha=0.2)
# ax.plot(ts,f_min1,color='r',alpha=0.5)
# ax.fill_between(ts, (f_min1-f_min1_err), (f_min1+f_min1_err), color='r',alpha=0.2)

ax.set_ylim(4.37,4.42)

ax1.set_yticks([0.52,0.72])
ax1.set_yticklabels(["0","1"],fontsize=14,color='r')
ax1.set_ylabel('ng',fontsize=14,color='r')
ax.set_xlabel('time (s)',fontsize=14)
ax.set_ylabel('frequency (GHz)',fontsize=14)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\qcodes\utils\deprecate.py:59: QCoDeSDeprecationWarning: The function <get_data_by_id> is deprecated. Use "dataset.get_parameter_data" as an alternative.
#   issue_deprecation_warning(f'{t} <{n}>', reason, alternative)
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:475: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# <ipython-input-236-450077aa10f2>:29: RuntimeWarning: invalid value encountered in true_divide
#   f_min1_norm=(f_min1-np.min(f_min1))/(np.max(f_min1)-np.min(f_min1))
# <ipython-input-236-450077aa10f2>:32: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
# ...

# %%
import statsmodels.api as sm
from statsmodels.graphics import tsaplots

#calculate autocorrelations
x=sm.tsa.acf(f_min)
fig = tsaplots.plot_acf(f_min,lags=len(ts)-1)
plt.show()

from scipy.fft import fft
y=fft(x)
print(y)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:657: FutureWarning: The default number of lags is changing from 40 tomin(int(10 * np.log10(nobs)), nobs - 1) after 0.12is released. Set the number of lags to an integer to  silence this warning.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:667: FutureWarning: fft=True will become the default after the release of the 0.12 release of statsmodels. To suppress this warning, explicitly set fft=False.
#   warnings.warn(
# [1.65194958-0.j         1.15773702-0.54767824j 1.15403844+0.02776302j
#  1.28630218-0.51858823j 1.39261538-0.78711083j 1.59817847-0.33412268j
#  0.89083135-0.32579066j 0.84327944-0.03917482j 1.26239221+0.00749632j
#  1.11462335+0.08268477j 0.83579805-1.18088363j 0.86484589-0.6359165j
#  0.78186033-0.50070159j 1.00557912-0.27049257j 0.63892279-0.14415172j
#  1.24688813-0.27695456j 0.73441436-0.35221972j 0.82163567-0.19353062j
# ...

# %%
from scipy.fft import fft, fftfreq
f,ax=plt.subplots(figsize=(10,8))
# Number of sample points
N =len(ts)
# sample spacing
T = ts[1]-ts[0]
x = ts
y = sm.tsa.acf(f_min,adjusted=True,nlags=len(ts)-1)
yf = fft(y)
xf = fftfreq(N, T)[:N//2]

ax.plot(xf, 2.0/N * np.abs(yf[0:N//2]))
ax.plot(xf,lorfunc_f(p,xf),'r-',label='T150')
ax.grid()
ax.loglog()
ax.set_xlabel('freq (Hz)',fontsize=16)
ax.set_ylabel('S(f)',fontsize=16)
ax.tick_params(axis="both", labelsize=16 )

plt.legend()

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:667: FutureWarning: fft=True will become the default after the release of the 0.12 release of statsmodels. To suppress this warning, explicitly set fft=False.
#   warnings.warn(

# %%
p = fitlor_f(xf,2.0/N * np.abs(yf[0:N//2]),showfit=True,fitparams=([0.1,0.1,0.001]))
print(p)
# Out:
# [-0.00746445  0.00050975  0.01264001]

# %%
from scipy.fft import fft, fftfreq
f,ax=plt.subplots(figsize=(10,8))
# Number of sample points
N =len(ts)
# sample spacing
T = ts[1]-ts[0]
x = ts
y = sm.tsa.acf(f_min,adjusted=True,nlags=len(ts)-1)
yf = fft(y)
xf = fftfreq(N, T)[:N//2]

ax.plot(xf, 2.0/N * np.abs(yf[0:N//2]))
ax.plot(xf,lorfunc_f(p,xf),'b--',label='T151 after irradiation')
ax.grid()
ax.loglog()
ax.set_xlabel('frequency (Hz)',fontsize=16)
ax.set_ylabel('$S_q(f)$',fontsize=16)
ax.tick_params(axis="both", labelsize=16 )


dfT151=pd.read_csv('T151_Sqvsf.csv')
ax.plot(dfT151['freqs'],dfT151['Sq'])
pold=[-0.00194339,0.00087667,0.00614139]
pnew=p
xflst=np.logspace(-5,-1)
ax.plot(xflst,lorfunc_f(pold,xflst),'r--',label='T151 before irradiation')
ax.set_xlim(1e-4,2e-2)
plt.legend(fontsize=14)
plt.title('PSD of charge noise of T151',fontsize=18)
plt.show()

plt.savefig('T151_before_after_irr_Sq.png')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:667: FutureWarning: fft=True will become the default after the release of the 0.12 release of statsmodels. To suppress this warning, explicitly set fft=False.
#   warnings.warn(

# %%
f,ax=plt.subplots(figsize=(10,8))

pold=[-0.00194339,0.00087667,0.00614139]
pnew=p
xflst=np.logspace(-4,-1.5)
ax.plot(xflst,lorfunc_f(pold,xflst),'r-',label='T151 pre irradiation')
ax.plot(xflst,lorfunc_f(pnew,xflst),'g-',label='T151 post irr.')
ax.plot(xflst,(lorfunc_f(pold,xflst)/lorfunc_f(pnew,xflst)),'b-',label='old/new')
ax.loglog()
ax.set_xlabel('freq (Hz)',fontsize=16)
ax.set_ylabel('S(f)',fontsize=16)
ax.tick_params(axis="both", labelsize=16 )

plt.legend(fontsize=14)

# %%
fs[30]
# Out:
# 4.385000000000064

# %%
qm = qmm.open_qm(config)
job = qm.execute(T151_1.qubitspec()[0])
res = job.result_handles
# res.wait_for_all_values()
# I = res.I.fetch_all()
# Q = res.Q.fetch_all()
# I_all.append(I)
# Q_all.append(Q)
# ts.append(time.time())
# print("elapsed time {:0.1f}".format(ts[i]-ts[0]))
# Out:
# 2022-02-06 23:14:10,588 - qm - INFO - Performing health check
# 2022-02-06 23:14:10,595 - qm - INFO - Health check passed
# 2022-02-06 23:14:11,373 - qm - INFO - Flags:
# 2022-02-06 23:14:11,374 - qm - INFO - Sending program to QOP
# 2022-02-06 23:14:11,412 - qm - INFO - Executing program

# %%
I_hand=res.I
Q_hand=res.Q

I_hand.wait_for_values(1)
Q_hand.wait_for_values(1)

plt.figure()
while I_hand.is_processing():
    I=I_hand.fetch_all()
    Q=Q_hand.fetch_all()
    f,ax=plt.subplots()
    mags=np.sqrt(I**2+Q**2)

    fvec=T151_1.qubitspec()[1]

    ax.plot(T151_1.qubitspec()[1],mags)
    display.display(plt.gcf())
    display.clear_output(wait=True)
    plt.pause(0.1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-444-564877c039dd> in <module>
#      12     mags=np.sqrt(I**2+Q**2)
#      13
# ---> 14     fvec=T151_1.qubitspec()[1]
#      15
#      16     ax.plot(T151_1.qubitspec()[1],mags)
#
# ~\Desktop\QM OPX\T151_1_Neon_OPX\OPXexperiments.py in qubitspec(self, *args)
#     370                             )
#     371                     save(I, I_stream)
# --> 372                     save(Q, Q_stream)
#     373
#     374
#
# C:\ProgramData\Anaconda3\lib\site-packages\qm\qua\_dsl.py in save(var, stream_or_tag)
#     563
#     564     body = _get_scope_as_blocks_body()
# --> 565     body.save(_unwrap_save_source(exp(var)), result_obj)
#     566
#     567
#
# C:\ProgramData\Anaconda3\lib\site-packages\qm\program\StatementsCollection.py in save(self, source, result)
#     215         statement = self._body.statements.add()
# ...

# %%
fvec=(T151.qubitspec()[1])*1e-9
f,ax=plt.subplots()
mags=np.sqrt(np.array(I_all)**2+np.array(Q_all)**2)
ax.plot(np.array(ts),mags.T[0],'-x')
ax.plot(np.array(ts),mags.T[1],'-x')
# ax.plot(np.array(ts),mags.T[0]*mags.T[1],'-x')
f,ax=plt.subplots()
ax.hist(mags.T[0],alpha=0.2,bins=10)
ax.hist(mags.T[1],alpha=0.2,bins=10)
print('Correlator is',np.mean(mags.T[0]*mags.T[1])-np.mean(mags.T[0])*np.mean(mags.T[1]))
# #ax.set_xlabel('freqeuncy (GHz)',fontsize=16)
# #ax.tick_params(size=8)
# fvec=(T151.qubitspec()[1])*1e-9
# f,ax=plt.subplots()
# ax.plot(fvec,np.mean(mags,axis=1))
# Out:
# Correlator is -7.347939036340828e-06

# %%
ts,fs,Is,Qs=bf.reshape_data(236)

# fig = plt.figure(num=1,figsize = (10,10))
# ax = fig.add_subplot(111)
mags=np.sqrt(Is**2+Qs**2)
mags_norm=mags*0
mag_min=ts*0
f_min=ts*0
f_min1=ts*0
f_min_err=ts*0
f_min1_err=ts*0
for t in range(len(ts)):
    mags_norm[t]=mags[t]/np.mean(mags[t])
    
    p = fitlor(fs[84:],-(mags_norm[t][84:]/np.max(mags_norm[t][84:],axis=0))**2,showfit=False)
    f_min[t]=p[2]
    f_min_err=p[3]
    p1 = fitlor(fs[:87],-(mags_norm[t][:87]/np.max(mags_norm[t][:87],axis=0))**2,showfit=False)
    f_min1[t]=p1[2]
    f_min1_err[t]=p1[3]
    
#     mag_min[t]=np.min(mags[t])
#     f_min[t]=fs[np.argmin(mags[t][84:])]

#     p = fitlor_2f(fs[70:100],-(mags_norm[t][70:100]/np.max(mags_norm[t][70:100],axis=0))**2,showfit=False)
#     f_min1[t]=p[2]
#     f_min[t]=p[6]

#ax.pcolormesh(fs,ts,mags_norm)
f,ax=plt.subplots()
# ax.plot(ts,mag_min)
f,ax=plt.subplots(figsize=(10,5))

f_min_norm=(f_min-np.min(f_min))/(np.max(f_min)-np.min(f_min))
f_min1_norm=(f_min1-np.min(f_min1))/(np.max(f_min1)-np.min(f_min1))

ax1=ax.twinx()
ax.pcolormesh(ts,fs,mags_norm.T)
ax.plot(ts,f_min,color='r',alpha=0.5)
ax.fill_between(ts, (f_min-f_min_err), (f_min+f_min_err), color='r',alpha=0.2)
ax.plot(ts,f_min1,color='r',alpha=0.5)
ax.fill_between(ts, (f_min1-f_min1_err), (f_min1+f_min1_err), color='r',alpha=0.2)

ax.set_ylim(4.43,4.455)

ax1.set_yticks([0.52,0.72])
ax1.set_yticklabels(["0","1"],fontsize=14,color='r')
ax1.set_ylabel('ng',fontsize=14,color='r')
ax.set_xlabel('time (s)',fontsize=14)
ax.set_ylabel('frequency (GHz)',fontsize=14)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\qcodes\utils\deprecate.py:59: QCoDeSDeprecationWarning: The function <get_data_by_id> is deprecated. Use "dataset.get_parameter_data" as an alternative.
#   issue_deprecation_warning(f'{t} <{n}>', reason, alternative)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1208-ec922090d6c0> in <module>
# ----> 1 ts,fs,Is,Qs=bf.reshape_data(236)
#       2
#       3 # fig = plt.figure(num=1,figsize = (10,10))
#       4 # ax = fig.add_subplot(111)
#       5 mags=np.sqrt(Is**2+Qs**2)
#
# C:\_Lib\python\gershlab\QCmeasurement.py in reshape_data(self, idx, **kwargs)
#     125         self.db_connect()
#     126
# --> 127         ts, fs, Ie, _, _, Qe = xy_by_id(idx)
#     128
#     129         scale = int((fs[-1] - fs[0]) / (fs[1] - fs[0])) + 1
#
# C:\_Lib\python\gershlab\JJ_data_processing.py in xy_by_id(idx)
#     253
# ...

# %%
#236
f,ax=plt.subplots()
# plt.plot(ts,f_min_norm)
# plt.plot(ts,f_min1_norm)

plt.plot(ts,(np.unwrap(np.arccos(f_min_norm)%2*np.pi)/(2*np.pi)))
plt.plot(ts,(np.unwrap(np.arccos(f_min1_norm)%2*np.pi)/(2*np.pi)))

#plt.plot(ts,np.arccos(f_min_norm)%2*np.pi)

plt.ylabel('Periods of ng')
plt.xlabel('time (s)')
# Out:
# Text(0.5, 0, 'time (s)')

# %% [markdown]
# #### Save

# %%
bf.mock_meas((mag_param,np.mean(mags,axis=1)),(fr_param,fvec),label='qubit spec 27 mK')
# Out:
# Starting experimental run with id: 84.
# 84

# %%
bf.mock_meas((iq_array,np.stack((I_all,Q_all),axis=2)),(fr_param,fvec),x1=(Time,np.array(ts)-ts[0]),label='qubit spec 27 mK 3000avgs')
# Out:
# Starting experimental run with id: 85.
# 85

# %% [markdown]
# ### Qubit spec 2d

# %%
qm = qmm.open_qm(config)
job = qm.execute(T150.qubitspec2d()[0])
res = job.result_handles
# res.wait_for_all_values()
# I = res.I.fetch_all()
# Q = res.Q.fetch_all()
# Out:
# 2022-03-10 10:32:56,724 - qm - INFO - Flags:
# 2022-03-10 10:32:56,725 - qm - INFO - Sending program to QOP
# 2022-03-10 10:32:56,800 - qm - INFO - Executing program

# %%
I_hand=res.I
Q_hand=res.Q

I_hand.wait_for_values(1)
Q_hand.wait_for_values(1)

plt.figure()
while I_hand.is_processing():
    I=I_hand.fetch_all()
    Q=Q_hand.fetch_all()
    mag=np.sqrt(I**2+Q**2)
    ang=np.unwrap(np.angle(I+1j*Q))
    T150.plot2d(I,Q,T150.qubitspec2d()[1],T150.qubitspec2d()[2])
  #    plt.plot(fvec,ang/np.mean(ang)+0.04)
    display.display(plt.gcf())
    display.clear_output(wait=True)
    plt.pause(0.1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-53-0405de329bbe> in <module>
#       6
#       7 plt.figure()
# ----> 8 while I_hand.is_processing():
#       9     I=I_hand.fetch_all()
#      10     Q=Q_hand.fetch_all()
#
# C:\ProgramData\Anaconda3\lib\site-packages\qm\_results_01.py in is_processing(self)
#     176
#     177     def is_processing(self) -> bool:
# --> 178         header = self._get_named_header()
#     179         return not (header.done or header.closed)
#     180
#
# C:\ProgramData\Anaconda3\lib\site-packages\qm\_results_01.py in _get_named_header(self, **kwargs)
#     240         if kwargs.get("flat_struct", False) is True:
#     241             request.flatFormat = True
# --> 242         response = self._service.GetJobNamedResultHeader(request)
#     243         dtype = _parse_dtype(response.simpleDType)
#     244
#
# ...

# %%
fvec=(T150.qubitspec2d()[1])*1e-9
avec=(T150.qubitspec2d()[2])

f,ax=plt.subplots()
for i in range(len(avec)):
    ax.plot(fvec,mag[i])
    
#ax.set_xlim(3.76,3.78)

# %%
f,ax=plt.subplots()
Qfaclst=[]
linewidth=[]
for i in range(len(avec)):
    p = fitlor(fvec,(-mag[i]**2),showfit=False)
    ax.plot(fvec,np.sqrt(-lorfunc(p,fvec)),'r-')
    ax.plot(fvec,mag[i])

    nu_res = p[2] + 7.22839697e9
    Qfac = nu_res/p[3]/2
    Qfaclst=np.append(Qfaclst,Qfac)
    linewidth=np.append(linewidth,p[3])
    
#ax.set_xlim(3.76,3.78)

# %%
f,ax=plt.subplots()

ax.plot(avec,Qfaclst,'x')
#ax.plot(avec[1:],2*linewidth[1:]/1e6,'x')

# ax.set_xscale('log')
# ax.set_yscale('log')

ax.set_xlabel('amplitude of 2nd tone (14dBm)',size=16)
ax.set_ylabel('line width (MHz)',size=16)
# Out:
# Text(0, 0.5, 'line width (MHz)')

# %%
bf.mock_meas((iq_array,np.stack((I,Q),axis=2)),(fr_param,fvec),x1=(amplitude, avec),label='qubit spec amp')
# Out:
# Starting experimental run with id: 27.
# 27

# %% [markdown]
# ### Fidelity plots

# %%
dmin=1500
dmax=3000
dd=500
dvec=np.arange(dmin,dmax,dd)
Itot=[]
Qtot=[]
for dur in dvec.tolist():
    config['pulses']['readout_pulse']['length']=dur
    config['integration_weights']['integW1']['cosine']=[1.0] * int(dur // 4)
    config['integration_weights']['integW1']['sine']  =[0.0] * int(dur // 4)
    config['integration_weights']['integW2']['cosine']=[0.0] * int(dur // 4)
    config['integration_weights']['integW2']['sine']  =[1.0] * int(dur // 4)
    qm=qmm.open_qm(config)
    job=qm.execute(T150.histogram()[0])
    res = job.result_handles
    res.wait_for_all_values()
    I = res.I.fetch_all()
    Q = res.Q.fetch_all()
    Itot=np.append(Itot,np.array(I))
    Qtot=np.append(Qtot,np.array(Q))
# Out:
# 2022-03-21 18:05:11,032 - qm - INFO - Performing health check
# 2022-03-21 18:05:11,041 - qm - INFO - Health check passed
# 2022-03-21 18:05:12,011 - qm - INFO - Flags:
# 2022-03-21 18:05:12,060 - qm - INFO - Sending program to QOP
# 2022-03-21 18:05:12,110 - qm - INFO - Executing program
# 2022-03-21 18:06:15,958 - qm - INFO - Flags:
# 2022-03-21 18:06:15,962 - qm - INFO - Sending program to QOP
# 2022-03-21 18:06:16,085 - qm - INFO - Executing program
# 2022-03-21 18:07:19,664 - qm - INFO - Flags:
# 2022-03-21 18:07:19,665 - qm - INFO - Sending program to QOP
# 2022-03-21 18:07:19,790 - qm - INFO - Executing program

# %%
avec=T150.histogram()[1]
avgs=int(T150.histogram()[2])
I=np.array(Itot).reshape(len(dvec),len(avec),2*avgs)
Q=np.array(Qtot).reshape(len(dvec),len(avec),2*avgs)

# %%
Ig=I[:,:,::2].T
Ie=I[:,:,1::2].T
Qg=Q[:,:,::2].T
Qe=Q[:,:,1::2].T

# %%
np.shape(Ig.T)
# Out:
# (3, 6, 1000)

# %%
f,ax=plt.subplots(nrows=len(dvec),ncols=len(avec)-1,figsize=(15,15))

fids = []
for i in range(len(avec)-1):
    for j in range(len(dvec)):
#         print([j,i])
        fid=T150.histogram_simp_fid([Ig.T[j,i],Ie.T[j,i]],[Qg.T[j,i],Qe.T[j,i]],ax=ax[j,i],numbins=100)
        ax[j,i].set_title('a = '+str(np.around(avec[i],3)) + ', d = '+str(np.around(dvec[j],2))+ 'fid = '+str(np.around(fid,3)))
#         ax[j,i].scatter(Ie.T[j,i],Qe.T[j,i],marker='.',alpha=0.1)
#         ax[j,i].scatter(Ig.T[j,i],Qg.T[j,i],marker='.',alpha=0.1)
        fids.append(fid)
plt.subplots_adjust(left=0.1, right=0.8, top=0.9, bottom=0.25)
plt.tight_layout()
plt.show()

# %%
f,ax=plt.subplots()

fvec=T151.histogram()[1]

fids_2 = np.array(fids).reshape(len(dvec),len(avec)-1).T

ax.pcolormesh(dvec,avec,fids_2,vmin=0,vmax=0.5)
ax.set_ylabel('ampl')
ax.set_xlabel('duration (ns)')
# Out:
# <ipython-input-519-b94e128e1dac>:7: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   ax.pcolormesh(dvec,avec,fids_2,vmin=0,vmax=0.5)
# Text(0.5, 0, 'duration (ns)')

# %%
dmin=2000
dmax=3000
dd=500
dvec=np.arange(dmin,dmax,dd)
Itot=[]
Qtot=[]
for dur in dvec.tolist():
    config['pulses']['readout_pulse']['length']=dur
    config['integration_weights']['integW1']['cosine']=[1.0] * int(dur // 4)
    config['integration_weights']['integW1']['sine']  =[0.0] * int(dur // 4)
    config['integration_weights']['integW2']['cosine']=[0.0] * int(dur // 4)
    config['integration_weights']['integW2']['sine']  =[1.0] * int(dur // 4)
    qm=qmm.open_qm(config)
    job=qm.execute(T151.histogram_f()[0])
    res = job.result_handles
    res.wait_for_all_values()
    I = res.I.fetch_all()
    Q = res.Q.fetch_all()
    Itot=np.append(Itot,np.array(I))
    Qtot=np.append(Qtot,np.array(Q))
# Out:
# 2022-01-26 12:15:47,479 - qm - INFO - Performing health check
# 2022-01-26 12:15:47,486 - qm - INFO - Health check passed
# 2022-01-26 12:15:49,064 - qm - INFO - Flags:
# 2022-01-26 12:15:49,067 - qm - INFO - Sending program to QOP
# 2022-01-26 12:15:49,115 - qm - INFO - Executing program
# 2022-01-26 12:16:02,679 - qm - INFO - Flags:
# 2022-01-26 12:16:02,696 - qm - INFO - Sending program to QOP
# 2022-01-26 12:16:02,800 - qm - INFO - Executing program

# %%
fvec=T151.histogram_f()[1]
avgs=int(T151.histogram_f()[2])
I=np.array(Itot).reshape(len(dvec),len(fvec),2*avgs)
Q=np.array(Qtot).reshape(len(dvec),len(fvec),2*avgs)

# %%
Ig=I[:,:,::2].T
Ie=I[:,:,1::2].T
Qg=Q[:,:,::2].T
Qe=Q[:,:,1::2].T

# %%
f,ax=plt.subplots(nrows=len(dvec),ncols=len(fvec)-1,figsize=(15,15))

fids = []
for i in range(len(fvec)-1):
    for j in range(len(dvec)):
#         print([j,i])
        fid=T151.histogram_simp_fid([Ig.T[j,i],Ie.T[j,i]],[Qg.T[j,i],Qe.T[j,i]],ax=ax[j,i],numbins=100)
        ax[j,i].set_title('f = '+str(np.around(fvec[i],3)) + ', d = '+str(np.around(dvec[j],2))+ 'fid = '+str(np.around(fid,3)))
#         ax[j,i].scatter(Ie.T[j,i],Qe.T[j,i],marker='.',alpha=0.1)
#         ax[j,i].scatter(Ig.T[j,i],Qg.T[j,i],marker='.',alpha=0.1)
        fids.append(fid)
plt.subplots_adjust(left=0.1, right=0.8, top=0.9, bottom=0.25)
plt.tight_layout()
plt.show()

# %%
f,ax=plt.subplots()

fvec=T151.histogram_f()[1]

fids_2 = np.array(fids).reshape(len(dvec),len(fvec)-1).T

ax.pcolormesh(dvec,fvec,fids_2,vmin=0,vmax=0.5)
ax.set_ylabel('frequency')
ax.set_xlabel('duration (ns)')
# Out:
# <ipython-input-533-83ea11dd622d>:7: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   ax.pcolormesh(dvec,fvec,fids_2,vmin=0,vmax=0.5)
# Text(0.5, 0, 'duration (ns)')

# %% [markdown]
# ### Histogram f qubit

# %%
dmin=2000
dmax=5000
dd=1000
dvec=np.arange(dmin,dmax,dd)
Itot=[]
Qtot=[]
for dur in dvec.tolist():
    config['pulses']['readout_pulse']['length']=dur
    config['integration_weights']['integW1']['cosine']=[1.0] * int(dur // 4)
    config['integration_weights']['integW1']['sine']  =[0.0] * int(dur // 4)
    config['integration_weights']['integW2']['cosine']=[0.0] * int(dur // 4)
    config['integration_weights']['integW2']['sine']  =[1.0] * int(dur // 4)
    qm=qmm.open_qm(config)
    job=qm.execute(T151.histogram_f()[0])
    res = job.result_handles
    res.wait_for_all_values()
    I = res.I.fetch_all()
    Q = res.Q.fetch_all()
    Itot=np.append(Itot,np.array(I))
    Qtot=np.append(Qtot,np.array(Q))
# Out:
# 2022-01-10 16:58:14,169 - qm - INFO - Performing health check
# 2022-01-10 16:58:14,176 - qm - INFO - Health check passed
# 2022-01-10 16:58:15,094 - qm - INFO - Flags:
# 2022-01-10 16:58:15,095 - qm - INFO - Sending program to QOP
# 2022-01-10 16:58:15,141 - qm - INFO - Executing program
# 2022-01-10 16:58:21,154 - qm - INFO - Flags:
# 2022-01-10 16:58:21,155 - qm - INFO - Sending program to QOP
# 2022-01-10 16:58:21,216 - qm - INFO - Executing program
# 2022-01-10 16:58:27,251 - qm - INFO - Flags:
# 2022-01-10 16:58:27,255 - qm - INFO - Sending program to QOP
# 2022-01-10 16:58:27,338 - qm - INFO - Executing program

# %%
fvec=T151.histogram_f()[1]
avgs=int(T151.histogram_f()[2])
I=np.array(Itot).reshape(len(dvec),2*len(fvec),avgs)
Q=np.array(Qtot).reshape(len(dvec),2*len(fvec),avgs)

# %%
np.shape(I[:,::2,:])
# Out:
# (3, 4, 10000)

# %%
Ig=I[:,::2 ,:].T
Ie=I[:,1::2,:].T
Qg=Q[:,::2 ,:].T
Qe=Q[:,1::2,:].T

# %%
f,ax=plt.subplots(nrows=len(dvec),ncols=len(fvec)-1,figsize=(15,15))

fids = []
for i in range(len(fvec)-1):
    for j in range(len(dvec)):
#         print([j,i])
        fid=T151.histogram_simp_fid([Ig.T[j,i],Ie.T[j,i]],[Qg.T[j,i],Qe.T[j,i]],ax=ax[j,i],numbins=100)
        ax[j,i].set_title('a = '+str(np.around(fvec[i],3)) + ', d = '+str(np.around(dvec[j],2))+ 'fid = '+str(np.around(fid,3)))
#         ax[j,i].scatter(Ie.T[j,i],Qe.T[j,i],marker='.',alpha=0.2)
#         ax[j,i].scatter(Ig.T[j,i],Qg.T[j,i],marker='.',alpha=0.2)
        fids.append(fid)
plt.subplots_adjust(left=0.1, right=0.8, top=0.9, bottom=0.25)
plt.tight_layout()
plt.show()

# %%
plt.plot(fids,'.')

# %% [markdown]
# #### blobs

# %%
qm = qmm.open_qm(config)
job = qm.execute(T151.IQ_blobs()[0])
res = job.result_handles
res.wait_for_all_values()
I = res.I.fetch_all()
Q = res.Q.fetch_all()
# Out:
# 2022-01-16 19:16:19,153 - qm - INFO - Performing health check
# 2022-01-16 19:16:19,164 - qm - INFO - Health check passed
# 2022-01-16 19:16:20,684 - qm - INFO - Flags:
# 2022-01-16 19:16:20,686 - qm - INFO - Sending program to QOP
# 2022-01-16 19:16:20,743 - qm - INFO - Executing program

# %%
Ig=I[1::2]
Ie=I[::2]
Qg=Q[1::2]
Qe=Q[::2]

f,ax=plt.subplots()
histogram_simp([Ig,Ie],[Qg,Qe],ax)
# Out:
# 0.03

# %%
import matplotlib as mpl

# %%
# plt.hist2d(I,Q,bins=20,norm=mpl.colors.LogNorm());
# #plt.hist2d(Ie,Qe,bins=20)

plt.plot(Ig,Qg,'.')
plt.plot(Ie,Qe,'.')

plt.plot(np.mean(Ig),np.mean(Qg),'x')
plt.plot(np.mean(Ie),np.mean(Qe),'x')

# %%
plt.hist2d(Ie,Qe,bins=20,norm=mpl.colors.LogNorm());

# %%
bf.mock_meas((iq_array,zip(I,Q)),(buffer,T151.IQ_blobs()[1]),label='IQ blobs')
# Out:
# Starting experimental run with id: 45.
# 45

# %%
Is,Qs=[],[]

for i in range(200):
    qm = qmm.open_qm(config)
    job = qm.execute(T151.IQ_blobs()[0])
    res = job.result_handles
    res.wait_for_all_values()
    I = res.I.fetch_all()
    Q = res.Q.fetch_all()
    Is.append(I)
    Qs.append(Q)
# Out:
# 2022-01-11 11:41:54,553 - qm - INFO - Flags:
# 2022-01-11 11:41:54,555 - qm - INFO - Sending program to QOP
# 2022-01-11 11:41:54,611 - qm - INFO - Executing program
# 2022-01-11 11:41:55,508 - qm - INFO - Flags:
# 2022-01-11 11:41:55,510 - qm - INFO - Sending program to QOP
# 2022-01-11 11:41:55,567 - qm - INFO - Executing program
# 2022-01-11 11:41:56,416 - qm - INFO - Flags:
# 2022-01-11 11:41:56,418 - qm - INFO - Sending program to QOP
# 2022-01-11 11:41:56,474 - qm - INFO - Executing program
# 2022-01-11 11:41:57,279 - qm - INFO - Flags:
# 2022-01-11 11:41:57,281 - qm - INFO - Sending program to QOP
# 2022-01-11 11:41:57,338 - qm - INFO - Executing program
# 2022-01-11 11:41:58,150 - qm - INFO - Flags:
# 2022-01-11 11:41:58,152 - qm - INFO - Sending program to QOP
# 2022-01-11 11:41:58,208 - qm - INFO - Executing program
# 2022-01-11 11:41:59,020 - qm - INFO - Flags:
# 2022-01-11 11:41:59,021 - qm - INFO - Sending program to QOP
# ...

# %%
Ig=np.array(Is).T[1::2].T
Ie=np.array(Is).T[::2].T
Qg=np.array(Qs).T[1::2].T
Qe=np.array(Qs).T[::2].T
plt.plot(np.mean(Ig,axis=1),np.mean(Qg,axis=1),'b.',alpha=0.2);
plt.plot(np.mean(Ie,axis=1),np.mean(Qe,axis=1),'r.',alpha=0.2);

f,ax=plt.subplots()
histogram_simp([np.mean(Ig,axis=1),np.mean(Ie,axis=1)],[np.mean(Qg,axis=1),np.mean(Qe,axis=1)],ax)
# Out:
# 0.375

# %%
bf.mock_meas((iq_array,zip(Is,Qs)),(buffer,T112.IQ_blobs()[1]),label='IQ blobs')
# Out:
# Starting experimental run with id: 244.
# 244

# %% [markdown]
# ### Rabi

# %%
qm = qmm.open_qm(config)
job = qm.execute(T150.rabi2d()[0])
res = job.result_handles
# Out:
# 2022-03-22 12:42:55,850 - qm - INFO - Flags:
# 2022-03-22 12:42:55,853 - qm - INFO - Sending program to QOP
# 2022-03-22 12:42:55,993 - qm - INFO - Executing program

# %%
I_hand=res.I
Q_hand=res.Q

I_hand.wait_for_values(1)
Q_hand.wait_for_values(1)

plt.figure()
while I_hand.is_processing():
    I=I_hand.fetch_all()
    Q=Q_hand.fetch_all()
    mag=np.sqrt(I**2+Q**2)
    ang=np.unwrap(np.angle(I+1j*Q))
    T150.plot2d(I,Q,T150.rabi2d()[2],T150.rabi2d()[1])
   # plt.pcolormesh(T151.rabi2d()[2],T151.rabi2d()[1],I)
    
    #    plt.plot(fvec,ang/np.mean(ang)+0.04)
    display.display(plt.gcf())
    display.clear_output(wait=True)
    plt.pause(0.1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-262-cc71ece6b4cd> in <module>
#      15
#      16     #    plt.plot(fvec,ang/np.mean(ang)+0.04)
# ---> 17     display.display(plt.gcf())
#      18     display.clear_output(wait=True)
#      19     plt.pause(0.1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
# ...

# %%
fvec=T151.rabi2d()[1]
times=T151.rabi2d()[2]
from scipy.fft import fft, fftfreq, fftshift

fftlst,fftIlst,fftQlst=[],[],[]
# number of signal points
N = len(times)
# sample spacing
T = times[1]-times[0]
x = times
for i in range(len(fvec)):
    y = np.sqrt(I**2+Q**2)[i]
    fftI=fft(I[i])
    fftQ=fft(Q[i])
    yf = fft(y)
    xf = fftfreq(N, T)
    xf = fftshift(xf)
    yplot = fftshift(yf)
    fftIplot = fftshift(fftI)
    fftQplot = fftshift(fftQ)


    plt.plot(xf, 1.0/N * np.abs(yplot))
    fftlst.append(1.0/N * np.abs(yplot))
    fftIlst.append(1.0/N * np.abs(fftIplot))
    fftQlst.append(1.0/N * np.abs(fftQplot))

    
plt.xlim(-0.01,0.01)
plt.ylim(0,0.001)
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-332-b876f375da13> in <module>
#      21
#      22
# ---> 23     plt.plot(xf, 1.0/N * np.abs(yplot))
#      24     fftlst.append(1.0/N * np.abs(yplot))
#      25     fftIlst.append(1.0/N * np.abs(fftIplot))
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
# ...

# %%
plt.pcolormesh(xf[N//2:],fvec,np.array(fftlst)[:,N//2:], vmax=0.5e-3)
# Out:
# <ipython-input-541-2fb19e6b93b7>:1: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh(xf[N//2:],fvec,np.array(fftlst)[:,N//2:], vmax=0.5e-3)

# %%
bf.mock_meas((fft_array,np.stack((np.array(fftIlst)[:,N//2:],np.array(fftQlst)[:,N//2:]),axis=2)),(fftfreq_param,xf[N//2:]),x1=(fr_param,fvec),label='rabi 2d fft no amp')
# Out:
# Starting experimental run with id: 218.
# 218

# %%
bf.pbi(71)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\qcodes\utils\deprecate.py:59: QCoDeSDeprecationWarning: The function <get_data_by_id> is deprecated. Use "dataset.get_parameter_data" as an alternative.
#   issue_deprecation_warning(f'{t} <{n}>', reason, alternative)
# <class 'matplotlib.colorbar.Colorbar'>
# C:\ProgramData\Anaconda3\lib\site-packages\qcodes\utils\deprecate.py:59: QCoDeSDeprecationWarning: The function <flatten_1D_data_for_plot> is deprecated. Use "ndarray.flatten()" as an alternative.
#   issue_deprecation_warning(f'{t} <{n}>', reason, alternative)
# <AxesSubplot:title={'center':'Run #71, Experiment rabi 2d fft_ (T151_OPX)'}, xlabel='Frequency (GHz)', ylabel='Frequency ($10^{-3}$ GHz)'>

# %%
bf.mock_meas((iq_array,np.stack((I,Q),axis=2)),(Time,T150.rabi2d()[2]),x1=(fr_param,T150.rabi2d()[1]),label='rabi 2d with amplifier')
# Out:
# Starting experimental run with id: 82.
# 82

# %%
fs,ts,Is,_,_,Qs=bf.xy_by_id(82)

f,ax=plt.subplots()
ax.plot(ts,np.sqrt(Is**2+Qs**2),'.')

ts_avg=np.mean(ts.reshape(40,25),axis=0)
mag_avg=np.mean(np.sqrt(Is**2+Qs**2).reshape(40,25),axis=0)
ax.plot(ts,np.sqrt(Is**2+Qs**2),'.')
ax.plot(ts_avg,mag_avg,'--x')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\qcodes\utils\deprecate.py:59: QCoDeSDeprecationWarning: The function <get_data_by_id> is deprecated. Use "dataset.get_parameter_data" as an alternative.
#   issue_deprecation_warning(f'{t} <{n}>', reason, alternative)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-164-34e4fa786326> in <module>
#       4 ax.plot(ts,np.sqrt(Is**2+Qs**2),'.')
#       5
# ----> 6 ts_avg=np.mean(ts.reshape(40,25),axis=0)
#       7 mag_avg=np.mean(np.sqrt(Is**2+Qs**2).reshape(40,25),axis=0)
#       8 ax.plot(ts,np.sqrt(Is**2+Qs**2),'.')
#
# ValueError: cannot reshape array of size 2000 into shape (40,25)

# %%
params, pcov = optimize.curve_fit(rabi_fit, ts_avg, mag_avg,
                                               bounds=([0.1e-5,200,0,0.005,0],
                                                       [1e-2,600,2e-2,0.02,10]))

plt.figure(figsize=(10, 8))
plt.scatter(ts_avg, mag_avg, label='Data')

times=np.linspace(0,1000,500)
plt.plot(times, rabi_fit(times, *params),
         label='Fitted function')

plt.legend(loc='best')
plt.xlabel('time (ns)')
plt.ylabel('S21 (V)')
plt.subplots_adjust(left=0.1, right=0.8, top=0.9, bottom=0.25)
plt.show()
perr = np.sqrt(np.diag(pcov))


#print(params)
print('T2={:0.0f}'.format(params[1]),'+/-{:0.0f}'.format(perr[1]),'ns')
print('rabi rate ={:0.4f}'.format(params[3]),'+/-{:0.4f}'.format(perr[3]),'GHz')
print('T_$\pi$={:0.1f}'.format(1/params[3]),'+/-{:0.1f}'.format(perr[3]/(params[3]**2)),'ns')
# Out:
# T2=263 +/-34 ns
# rabi rate =0.0085 +/-0.0002 GHz
# T_$\pi$=117.3 +/-2.2 ns

# %% [markdown]
# ### 1d

# %%
qm = qmm.open_qm(config)
job = qm.execute(T150.rabi1d()[0])
res = job.result_handles
# res.wait_for_all_values()
# I = res.I.fetch_all()
# Q = res.Q.fetch_all()
# Out:
# [autoreload of OPXexperiments failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 779, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 916, in get_code
#   File "<frozen importlib._bootstrap_external>", line 846, in source_to_code
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
# ...

# %%
I_hand=res.I
Q_hand=res.Q

I_hand.wait_for_values(1)
Q_hand.wait_for_values(1)

plt.figure()
while I_hand.is_processing():
    I=I_hand.fetch_all()
    Q=Q_hand.fetch_all()
    f,ax=plt.subplots()
    mags=np.sqrt(I**2+Q**2)[:-2]
    e_mags=np.sqrt(I[-2]**2+Q[-2]**2)
    g_mags=np.sqrt(I[-1]**2+Q[-1]**2)
    mags_norm=(g_mags-mags)/(g_mags-e_mags)
    times=T150.rabi1d()[1]

    ax.plot(T150.rabi1d()[1],mags_norm)
    display.display(plt.gcf())
    display.clear_output(wait=True)
    plt.pause(0.1)

# %%
bf.mock_meas((iq_array,zip(I,Q)),(Time,np.append(T150.rabi1d()[1],([0],[0]))),label=' rabi w 2 amp 2k avg 4.396GHz ')
# Out:
# Starting experimental run with id: 88.
# 88

# %%
ts,I,_,Q=bf.xy_by_id(88)

times=ts[:-2]
mags=np.sqrt(I**2+Q**2)[:-2]
e_mags=np.sqrt(I[-2]**2+Q[-2]**2)
g_mags=np.sqrt(I[-1]**2+Q[-1]**2)
mags_norm=(g_mags-mags)/(g_mags-e_mags)
params, pcov = optimize.curve_fit(rabi_fit, times, mags_norm,
                                               bounds=([0.4,100,0.3,0.01,0.0*np.pi],
                                                       [3.0,15000,1.0,0.03,2*np.pi]))

plt.figure(figsize=(10, 8))
plt.scatter(times, mags_norm, label='Data')

times=np.linspace(0,1000,1000)
plt.plot(times, rabi_fit(times, *params),
         label='Fitted function')
plt.xlabel('time (ns)',size=16)
plt.ylabel('$P_f$',size=16)
plt.legend(loc='best')

plt.subplots_adjust(left=0.1, right=0.8, top=0.9, bottom=0.25)
plt.show()


perr = np.sqrt(np.diag(pcov))
print(params)
print('T2*=',params[1]/1e3,'us +/-',perr[1]/1e3,'us')
print('rabi rate =',params[3])
print('$\pi$/$\Omega_R$ =',1/params[3],'+/-',perr[3],'ns')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\qcodes\utils\deprecate.py:59: QCoDeSDeprecationWarning: The function <get_data_by_id> is deprecated. Use "dataset.get_parameter_data" as an alternative.
#   issue_deprecation_warning(f'{t} <{n}>', reason, alternative)
# [5.33453330e-01 1.00000000e+02 1.00000000e+00 2.54845530e-02
#  8.28413935e-01]
# T2*= 0.10000000000000002 us +/- 0.07595406355818857 us
# rabi rate = 0.025484553024012254
# $\pi$/$\Omega_R$ = 39.23945611515227 +/- 0.00236885469945689 ns

# %%
ts[np.argmax(mags_norm)]
# Out:
# 224.0

# %%
bf.pbi(33)
# Out:
# <class 'NoneType'>
# C:\ProgramData\Anaconda3\lib\site-packages\qcodes\utils\deprecate.py:59: QCoDeSDeprecationWarning: The function <get_data_by_id> is deprecated. Use "dataset.get_parameter_data" as an alternative.
#   issue_deprecation_warning(f'{t} <{n}>', reason, alternative)
# <AxesSubplot:title={'center':'Run #33, Experiment  rabi w amp 2k avg 4.401GHz and 4.393GHz_ (T150_OPX)'}, xlabel='Time ($10^{3}$ ns)', ylabel='In phase amplitude (mV)'>

# %%
bf.mock_meas((fr_param,np.array(fftmax)*1e9),(Time,dtvec*4),label='rabi fft vs dt')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-622-6821f1b4783c> in <module>
# ----> 1 bf.mock_meas((fr_param,np.array(fftmax)*1e9),(Time,dtvec*4),label='rabi fft vs dt')
#
# NameError: name 'fftmax' is not defined

# %% [markdown]
# ### Ramsey

# %%
qm = qmm.open_qm(config)
job = qm.execute(T150.ramsey()[0])
res = job.result_handles
# res.wait_for_all_values()

# I = res.I.fetch_all()
# Q = res.Q.fetch_all()
# Out:
# 2022-03-09 18:00:59,000 - qm - INFO - Flags:
# 2022-03-09 18:00:59,001 - qm - INFO - Sending program to QOP
# 2022-03-09 18:00:59,073 - qm - INFO - Executing program

# %%
I_hand=res.I
Q_hand=res.Q

I_hand.wait_for_values(1)
Q_hand.wait_for_values(1)

plt.figure()
while I_hand.is_processing():
    I=I_hand.fetch_all()
    Q=Q_hand.fetch_all()    
    mags=np.sqrt(I**2+Q**2)[:-2]
    e_mags=np.sqrt(I[-2]**2+Q[-2]**2)
    g_mags=np.sqrt(I[-1]**2+Q[-1]**2)
    mags_norm=(g_mags-mags)/(g_mags-e_mags)
    times=T150.ramsey()[1]
    ang=np.unwrap(np.angle(I+1j*Q))
    plt.plot(times,Q[:-2])
    #plt.ylim(1.5e-3,1.56e-3)
    #    plt.plot(fvec,ang/np.mean(ang)+0.04)
    display.display(plt.gcf())
    display.clear_output(wait=True)
    plt.pause(0.1)

# %%
plt.plot(I,Q,'.')

# %%
bf.mock_meas((iq_array,np.stack((I,Q),axis=1)),(Time,np.append(T151.ramsey()[1],([0],[0]))),label='ramsey 4.952 GHz with amp.')
# Out:
# Starting experimental run with id: 144.
# 144

# %%
ts,Is,_,Qs=bf.xy_by_id(144)
mags=np.sqrt(Is**2+Qs**2)

times=np.array(ts)


params, pcov = optimize.curve_fit(ramsey_fit, times, mags,
                                               bounds=([3e-4,100,1e-3,0.0008,-np.pi-0.1],
                                                       [5e-2,3100,5e-1,0.04,np.pi+0.1]))
print(params)
plt.figure(figsize=(15, 8))
plt.plot(times, mags,'--o', label='Data')
tvec=np.linspace(0,5000,500)
plt.plot(tvec, ramsey_fit(tvec, *params),
         label='Fitted function',color='C1')

plt.legend(loc='best')

plt.ylabel('$P_e$',size=16)
plt.xlabel('time (ns)',size=16)
plt.subplots_adjust(left=0.1, right=0.8, top=0.9, bottom=0.25)
plt.show()

perr = np.sqrt(np.diag(pcov))
#print(params)
print('T2*={:0.2f}'.format(params[1]),' +/-',perr[1],'ns')
print('nu_Ramsey ={:0.2f}'.format(params[3]*1e3),'+/-{:0.2f}'.format(perr[3]*1e3),'MHz')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\qcodes\utils\deprecate.py:59: QCoDeSDeprecationWarning: The function <get_data_by_id> is deprecated. Use "dataset.get_parameter_data" as an alternative.
#   issue_deprecation_warning(f'{t} <{n}>', reason, alternative)
# [3.00000000e-04 1.00000000e+02 4.04428660e-03 1.98837514e-02
#  1.33735419e+00]
# T2*=100.00  +/- 150.30207977819109 ns
# nu_Ramsey =19.88 +/-1.62 MHz

# %%
qm = qmm.open_qm(config)
job = qm.execute(T112.ramsey2d()[0])
res = job.result_handles

# %%
I_hand=res.I
Q_hand=res.Q

I_hand.wait_for_values(1)
Q_hand.wait_for_values(1)

plt.figure()
while I_hand.is_processing():
    I=I_hand.fetch_all()
    Q=Q_hand.fetch_all()
    mag=np.sqrt(I**2+Q**2)
    ang=np.unwrap(np.angle(I+1j*Q))
    T112.plot2d(I,Q,T112.ramsey2d()[2],T112.ramsey2d()[1])
    #    plt.plot(fvec,ang/np.mean(ang)+0.04)
    display.display(plt.gcf())
    display.clear_output(wait=True)
    plt.pause(0.1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-161-07352bd63516> in <module>
#      13     T112.plot2d(I,Q,T112.ramsey2d()[2],T112.ramsey2d()[1])
#      14     #    plt.plot(fvec,ang/np.mean(ang)+0.04)
# ---> 15     display.display(plt.gcf())
#      16     display.clear_output(wait=True)
#      17     plt.pause(0.1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# ...

# %%
bf.mock_meas((iq_array,np.stack((I,Q),axis=2)),(Time,T112.ramsey2d()[2]),x1=(fr_param,T112.ramsey2d()[1]),label='ramsey 2d')
# Out:
# Starting experimental run with id: 355.
# 355

# %% [markdown]
# ### spin echo

# %%
qm = qmm.open_qm(config)
job = qm.execute(T150.spin_echo()[0])
res = job.result_handles
# Out:
# 2022-03-10 11:32:17,186 - qm - INFO - Performing health check
# 2022-03-10 11:32:17,192 - qm - INFO - Health check passed
# 2022-03-10 11:32:18,603 - qm - INFO - Flags:
# 2022-03-10 11:32:18,605 - qm - INFO - Sending program to QOP
# 2022-03-10 11:32:18,810 - qm - INFO - Executing program

# %%
I_hand=res.I
Q_hand=res.Q

I_hand.wait_for_values(1)
Q_hand.wait_for_values(1)

plt.figure()
while I_hand.is_processing():
    I=I_hand.fetch_all()
    Q=Q_hand.fetch_all()    
    mags=np.sqrt(I**2+Q**2)[:-2]
    e_mags=np.sqrt(I[-2]**2+Q[-2]**2)
    g_mags=np.sqrt(I[-1]**2+Q[-1]**2)
    mags_norm=(g_mags-mags)/(g_mags-e_mags)
    times=T150.spin_echo()[1]
    ang=np.unwrap(np.angle(I+1j*Q))
    plt.plot(times,mags_norm)
    #plt.ylim(1.5e-3,1.56e-3)
    #    plt.plot(fvec,ang/np.mean(ang)+0.04)
    display.display(plt.gcf())
    display.clear_output(wait=True)
    plt.pause(0.1)

# %%
bf.mock_meas((iq_array,np.stack((I,Q),axis=1)),(Time,np.append(T151_2.spin_echo()[1],([0],[0]))),label='spin echo 1d 8 pulses')
# Out:
# Starting experimental run with id: 28.
# 28

# %%
params, pcov = optimize.curve_fit(ramsey_fit, times, mags,
                                               bounds=([2e-6,200,1e-4,0.003,0],
                                                       [5e-6,2000,9e-4,0.006,10]))
print(params)
# Out:
# [4.91437813e-06 2.90780139e+02 7.98945592e-04 5.99999999e-03
#  9.86098052e+00]

# %%
ts,Is,_,Qs=bf.xy_by_id(28)

times=ts[:-2]
mags=np.sqrt(Is**2+Qs**2)[:-2]

params, pcov = optimize.curve_fit(exp_fit, times, mags,
                                               bounds=([-1e-2,1000,1e-4],
                                                       [1e-2,50000,9e-2]))
print(params)
plt.figure(figsize=(15, 8))
plt.plot(times, mags,'--o', label='Data')
tvec=np.linspace(0,200000,500)
plt.plot(tvec, exp_fit(tvec, *params),
         label='Fitted function',color='C1')

plt.legend(loc='best')

plt.ylabel('$P_e$',size=16)
plt.xlabel('time (ns)',size=16)
plt.subplots_adjust(left=0.1, right=0.8, top=0.9, bottom=0.25)
plt.show()

perr = np.sqrt(np.diag(pcov))
#print(params)
print('T2*_echo={:0.2f}'.format(params[1]),' +/-',perr[1],'ns')
# print('nu_Ramsey ={:0.2f}'.format(params[3]*1e3),'+/-{:0.2f}'.format(perr[3]*1e3),'MHz')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\qcodes\utils\deprecate.py:59: QCoDeSDeprecationWarning: The function <get_data_by_id> is deprecated. Use "dataset.get_parameter_data" as an alternative.
#   issue_deprecation_warning(f'{t} <{n}>', reason, alternative)
# [-1.56561409e-04  2.37903629e+04  8.13454427e-04]
# T2*_echo=23790.36  +/- 2429.2365408511573 ns

# %%
qm = qmm.open_qm(config)
job = qm.execute(T151_2.multiple_spin_echo()[0])
res = job.result_handles
res.wait_for_all_values()
I = res.I.fetch_all()['value']
# Q = res.Q.fetch_all()['value']
# Out:
# 2022-02-16 18:09:33,876 - qm - INFO - Flags:
# 2022-02-16 18:09:33,876 - qm - INFO - Sending program to QOP
# 2022-02-16 18:09:34,001 - qm - INFO - Executing program
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-211-e616d26192e8> in <module>
#       2 job = qm.execute(T151_1.multiple_spin_echo()[0])
#       3 res = job.result_handles
# ----> 4 res.wait_for_all_values()
#       5 I = res.I.fetch_all()['value']
#       6 # Q = res.Q.fetch_all()['value']
#
# C:\ProgramData\Anaconda3\lib\site-packages\qm\_results_01.py in wait_for_all_values(self, timeout)
#     742             if end is not None:
#     743                 time_remaining = max(0.0, end - time.time())
# --> 744             all_done = all_done and result.wait_for_all_values(time_remaining)
#     745             keys = keys[1:]
#     746         return all_done
#
# ...

# %%
print(I)

# %%
from qm import SimulationConfig,LoopbackInterface

# %%
simulate = True

if simulate:
    # simulation properties
    simulate_config = SimulationConfig(
        duration=20000, simulation_interface=LoopbackInterface(([("con1", 1, "con1", 1)]))
    )
    job = qmm.simulate(config, T151_1.multiple_spin_echo()[0], simulate_config)  # do simulation with qmm
    job.get_simulated_samples().con1.plot()  # visualize played pulses

    res_handle = job.result_handles

    res_handle.wait_for_all_values()

    I_all = res_handle.get('I').fetch_all()['value']
#     I = res_handle.get('I_st').fetch_all()
    print(I_all)
#     pr

# %%
with program() as prog:
    I = declare(fixed)
    I_st = declare_stream()
    v1 = declare(int)
    v2 = declare(int)
    with for_(v1, 0, v1 < 10, v1 + 1):
        wait(500, "qe1")
        with for_(v2, 0, v2 < v1, v2 + 1):
            play('const', 'qe1')
            wait(10)
        save(I, I_st)

    with stream_processing():
        I_st.buffer(10).save('I_st')
        I_st.save_all('I_st_all')


#######################
# Simulate or execute #
#######################

simulate = True

if simulate:
    # simulation properties
    simulate_config = SimulationConfig(
        duration=20000
    )
    job = qmm.simulate(config, prog, simulate_config)  # do simulation with qmm
    job.get_simulated_samples().con1.plot()  # visualize played pulses

    res_handle = job.result_handles

    res_handle.wait_for_all_values()

    I_all = res_handle.get('I_st_all').fetch_all()['value']
    I = res_handle.get('I_st').fetch_all()
    print(I)
    print(I_all)

# %% [markdown]
# ### Multiple spin echo

# %%
qm = qmm.open_qm(config)
job = qm.execute(T151_2.multiple_spin_echo()[0])
res = job.result_handles
# Out:
# 2022-02-21 11:45:16,899 - qm - INFO - Flags:
# 2022-02-21 11:45:16,903 - qm - INFO - Sending program to QOP
# 2022-02-21 11:45:16,989 - qm - INFO - Executing program

# %%
I_hand=res.I
Q_hand=res.Q

I_hand.wait_for_values(1)
Q_hand.wait_for_values(1)

plt.figure()
while I_hand.is_processing():
    I=I_hand.fetch_all()
    Q=Q_hand.fetch_all()
#     mag=np.sqrt(I**2+Q**2)
#     ang=np.unwrap(np.angle(I+1j*Q))
    T151_2.plot2d(I,Q,T151_2.multiple_spin_echo()[1],T151_2.multiple_spin_echo()[2])
   # plt.pcolormesh(T151.rabi2d()[2],T151.rabi2d()[1],I)
    
 #   plt.plot(T151_1.multiple_spin_echo()[1],mag)
    display.display(plt.gcf())
    display.clear_output(wait=True)
    plt.pause(0.1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-216-3e98d23b60f9> in <module>
#      17     display.display(plt.gcf())
#      18     display.clear_output(wait=True)
# ---> 19     plt.pause(0.1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in pause(interval)
#     435         if canvas.figure.stale:
#     436             canvas.draw_idle()
# --> 437         show(block=False)
#     438         canvas.start_event_loop(interval)
#     439     else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in show(*args, **kwargs)
#     351     """
#     352     _warn_if_gui_out_of_main_thread()
# --> 353     return _backend_mod.show(*args, **kwargs)
#     354
#     355
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      39     try:
# ...

# %%
ts,ns,Is,Qs=bf.reshape_data(33)

Nvec=ns
times=ts
mag=np.sqrt(Is**2+Qs**2)
T2lst,T2err=[],[]
f,ax=plt.subplots()
for i in range(len(Nvec)):
    ax.plot(times,mag.T[i])

    params, pcov = optimize.curve_fit(exp_fit, times, mag.T[i],bounds=([-0.02,1e2,0.0006],
                                                                    [0.0,1e6,0.001 ]))
    perr = np.sqrt(np.diag(pcov))
    ax.plot(times, exp_fit(times, *params),
             label='Fitted function')

    print('T2=',params[1],'+/-',perr[1])
    T2lst.append(params[1])
    T2err.append(perr[1])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\qcodes\utils\deprecate.py:59: QCoDeSDeprecationWarning: The function <get_data_by_id> is deprecated. Use "dataset.get_parameter_data" as an alternative.
#   issue_deprecation_warning(f'{t} <{n}>', reason, alternative)
# T2= 24078.262385256443 +/- 2509.786234029759
# T2= 67538.03355294564 +/- 7053.202781908502
# T2= 68155.56107409546 +/- 4591.883340882897
# T2= 82259.13195121525 +/- 5816.695335557903
# T2= 107568.56597886416 +/- 6230.436841679235
# T2= 114170.32936788556 +/- 8526.801987616414
# T2= 144797.12819675176 +/- 13625.335189341393
# T2= 110279.04545882666 +/- 7531.52863784928
# T2= 119352.99778766787 +/- 9728.265631569337

# %%
plt.errorbar(Nvec,T2lst,yerr=T2err)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.errorbar(Nvec,T2lst,yerr=T2err)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.errorbar(Nvec,T2lst,yerr=T2err)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
bf.mock_meas((iq_array,np.stack((I,Q),axis=2)),(buffer,T151_2.multiple_spin_echo()[1]),x1=(Time,T151_2.multiple_spin_echo()[2]),label='multiple spin_echo_4.196GHz and 4.200GHz')
# Out:
# Starting experimental run with id: 33.
# 33

# %%
bf.pbi(31)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\qcodes\utils\deprecate.py:59: QCoDeSDeprecationWarning: The function <get_data_by_id> is deprecated. Use "dataset.get_parameter_data" as an alternative.
#   issue_deprecation_warning(f'{t} <{n}>', reason, alternative)
# C:\ProgramData\Anaconda3\lib\site-packages\qcodes\utils\deprecate.py:59: QCoDeSDeprecationWarning: The function <flatten_1D_data_for_plot> is deprecated. Use "ndarray.flatten()" as an alternative.
#   issue_deprecation_warning(f'{t} <{n}>', reason, alternative)
# <class 'matplotlib.colorbar.Colorbar'>
# <AxesSubplot:title={'center':'Run #31, Experiment multiple spin_echo_4.196GHz and 4.200GHz_ (T151_2_Neon_OPX)'}, xlabel='Time ($10^{3}$ ns)', ylabel='buff'>

# %%
mags=np.sqrt(I**2+Q**2).T[0]

params, pcov = optimize.curve_fit(ramsey_fit, times, mags,
                                               bounds=([2e-4,1000,1e-4,0.002,0],
                                                       [2e-2,20000,9e-2,0.004,2*np.pi]))
print(params)
plt.figure(figsize=(15, 8))
plt.plot(times, mags,'--o', label='Data')
tvec=np.linspace(0,3000,500)
plt.plot(tvec, ramsey_fit(tvec, *params),
         label='Fitted function',color='C1')

plt.legend(loc='best')

plt.ylabel('$P_e$',size=16)
plt.xlabel('time (ns)',size=16)
plt.subplots_adjust(left=0.1, right=0.8, top=0.9, bottom=0.25)
plt.show()

perr = np.sqrt(np.diag(pcov))
#print(params)
print('T2*_echo={:0.2f}'.format(params[1]),' +/-',perr[1],'ns')
print('nu_Ramsey ={:0.2f}'.format(params[3]*1e3),'+/-{:0.2f}'.format(perr[3]*1e3),'MHz')
# Out:
# [1.63941552e-02 1.09567996e+04 8.19647250e-04 2.75017085e-03
#  2.88826339e+00]
# T2*_echo=10956.80  +/- 11998.214857268444 ns
# nu_Ramsey =2.75 +/-0.54 MHz

# %% [markdown]
# ### T1 with pulses

# %%
dur=5000
config['pulses']['readout_pulse']['length']=dur
config['integration_weights']['integW1']['cosine']=[1.0] * int(dur // 4)
config['integration_weights']['integW1']['sine']  =[0.0] * int(dur // 4)
config['integration_weights']['integW2']['cosine']=[0.0] * int(dur // 4)
config['integration_weights']['integW2']['sine']  =[1.0] * int(dur // 4)

# %%
dur
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-53f8f79c61b3> in <module>
# ----> 1 dur
#
# NameError: name 'dur' is not defined

# %%
qm = qmm.open_qm(config)
job = qm.execute(T150.T1()[0])
res = job.result_handles
# Out:
# 2022-03-21 13:47:00,458 - qm - INFO - Flags:
# 2022-03-21 13:47:00,461 - qm - INFO - Sending program to QOP
# 2022-03-21 13:47:00,563 - qm - INFO - Executing program

# %%
I_hand=res.I
Q_hand=res.Q

I_hand.wait_for_values(1)
Q_hand.wait_for_values(1)

plt.figure()
while I_hand.is_processing():
    I=I_hand.fetch_all()
    Q=Q_hand.fetch_all()
    mags=np.sqrt(I**2+Q**2)[:-2]
    e_mags=np.sqrt(I[-2]**2+Q[-2]**2)
    g_mags=np.sqrt(I[-1]**2+Q[-1]**2)
    mags_norm=(g_mags-mags)/(g_mags-e_mags)
    I_norm=(I[-1]-I[:-2])/(I[-1]-I[-2])
    times=T150.T1()[1]
    ang=np.unwrap(np.angle(I+1j*Q))
    plt.plot(times,mags_norm)
    #plt.ylim(1.5e-3,1.56e-3)
    #    plt.plot(fvec,ang/np.mean(ang)+0.04)
    display.display(plt.gcf())
    display.clear_output(wait=True)
    plt.pause(0.1)

# %%
I_all,Q_all,ts = [],[],[]
T1,T1err=[],[]
for i in range(20):
    qm = qmm.open_qm(config)
    job = qm.execute(T150.T1()[0])
    res = job.result_handles
    res.wait_for_all_values()
    I = res.I.fetch_all()
    Q = res.Q.fetch_all()
    I_all.append(I)
    Q_all.append(Q)
    ts.append(time.time())
    
    mags=np.sqrt(I**2+Q**2)[:-2]
    e_mags=np.sqrt(I[-2]**2+Q[-2]**2)
    g_mags=np.sqrt(I[-1]**2+Q[-1]**2)
    mags_norm=(g_mags-mags)/(g_mags-e_mags)
    times=T150.T1()[1]
    plt.plot(times,mags_norm)
    plt.show()
    params, pcov = optimize.curve_fit(exp_fit, times, mags_norm,bounds=([-10,0,-0.2],
                                                                        [10,1e5,0.2]))
    perr = np.sqrt(np.diag(pcov))
    T1.append(params[1])
    T1err.append(perr[1])
    print("elapsed time {:0.1f}".format(ts[i]-ts[0]))
    print(T1,T1err)
# Out:
# 2022-03-09 13:36:07,047 - qm - INFO - Flags:
# 2022-03-09 13:36:07,050 - qm - INFO - Sending program to QOP
# 2022-03-09 13:36:07,112 - qm - INFO - Executing program
# elapsed time 0.0
# [34587.548645584866] [1386.853481854419]
# 2022-03-09 13:37:03,938 - qm - INFO - Flags:
# 2022-03-09 13:37:03,939 - qm - INFO - Sending program to QOP
# 2022-03-09 13:37:04,015 - qm - INFO - Executing program
# elapsed time 57.0
# [34587.548645584866, 31575.6578506626] [1386.853481854419, 5966.024753889086]
# 2022-03-09 13:38:00,818 - qm - INFO - Flags:
# 2022-03-09 13:38:00,822 - qm - INFO - Sending program to QOP
# 2022-03-09 13:38:00,882 - qm - INFO - Executing program
# elapsed time 113.8
# [34587.548645584866, 31575.6578506626, 24394.964430001866] [1386.853481854419, 5966.024753889086, 4741.731795943263]
# 2022-03-09 13:38:57,589 - qm - INFO - Flags:
# 2022-03-09 13:38:57,590 - qm - INFO - Sending program to QOP
# 2022-03-09 13:38:57,651 - qm - INFO - Executing program
# elapsed time 170.5
# ...

# %%
plt.errorbar(range(len(T1)),T1,yerr=T1err)
# plt.ylim(0,5000)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
df20_1=pd.DataFrame({'temp':27,'T1':T1,'T1err':T1err})

# %%
df20_1.to_csv('T1_temp20_1_statistics.csv')

# %%
df20=pd.read_csv('T1statistics.csv')
df120=pd.read_csv('T1_temp120_statistics.csv')
df150=pd.read_csv('T1_temp150_statistics.csv')
df170=pd.read_csv('T1_temp170_statistics.csv')
df180=pd.read_csv('T1_temp180_statistics.csv')
df190=pd.read_csv('T1_temp190_statistics.csv')
df200=pd.read_csv('T1_temp200_statistics.csv')
df75=pd.read_csv('T1_temp75_statistics.csv')
df20_1=pd.read_csv('T1_temp20_1_statistics.csv')

# %%
dflist=[df20,df120,df150,df170,df180,df190,df200,df75,df20_1]
f,ax=plt.subplots(figsize=(10,8))
templst,T1lst=[],[]
# ax.set_ytick(fontsize=14)
for df in dflist:
    df=df.drop(df[df['T1err']>df['T1']/2.5].index)        
    ax.plot(df['temp'],df['T1']/1e3,marker='x',color='C0')
    ax.plot(df['temp'][0],df['T1'].mean()/1e3,marker='o',color='C1')
    T1lst.append(df['T1'].mean())
    templst.append(df['temp'][0])
ax.errorbar(dfold['temp'],dfold['T1']/1e3,yerr=dfold['T1err']/1e3,color='C1')
ax.set_ylabel('T1 (us)',fontsize=16)
ax.set_xlabel('temp (mK)',fontsize=16)
ax.set_yticklabels(labels=ax.get_yticks(),fontsize=16)
ax.set_xticklabels(labels=ax.get_xticks(),fontsize=16)
# Out:
# <ipython-input-311-a7f41839d4fb>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(labels=ax.get_yticks(),fontsize=16)
# <ipython-input-311-a7f41839d4fb>:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels=ax.get_xticks(),fontsize=16)
# [Text(0.0, 0, '0.0'),
#  Text(25.0, 0, '25.0'),
#  Text(50.0, 0, '50.0'),
#  Text(75.0, 0, '75.0'),
#  Text(100.0, 0, '100.0'),
#  Text(125.0, 0, '125.0'),
#  Text(150.0, 0, '150.0'),
#  Text(175.0, 0, '175.0'),
#  Text(200.0, 0, '200.0'),
#  Text(225.0, 0, '225.0')]

# %%
dfnew=pd.DataFrame({'temp':templst,'T1':T1lst})
dfnew=dfnew.sort_values(by='temp')
dfold['rate']=1e3/dfold['T1']-1e3/dfold['T1'].max()
dfnew['rate']=1e3/dfnew['T1']-1e3/dfnew['T1'].max()

params, pcov = optimize.curve_fit(qp_exp_fit, dfold['temp'], dfold['rate'],bounds=([.1,1000,0],
                                                                [100,1600,0.5]))
perr = np.sqrt(np.diag(pcov))

print(params)
temps=np.linspace(25,200)
f,ax=plt.subplots(figsize=(10,8))
ax.plot(dfold['temp'],dfold['rate'])
ax.plot(temps, qp_exp_fit(temps, *params),
       #  label='Fitted function',
        color='brown',
        ls='--',
        alpha=0.3)

params1, pcov1 = optimize.curve_fit(qp_exp_fit, dfnew['temp'], dfnew['rate'],bounds=([1,1000,0],
                                                                [1000,3000,0.5]))
perr1 = np.sqrt(np.diag(pcov))

print(params1)
ax.plot(dfnew['temp'],dfnew['rate'])
ax.plot(temps, qp_exp_fit(temps, *params1),
       #  label='Fitted function',
        color='brown',
        ls='--',
        alpha=0.3)

print('rate is ',params[0],'+/-',perr[0])
print('rate is ',params1[0],'+/-',perr1[0])

ax.set_ylabel('$\Gamma$1 (MHz)',fontsize=16)
ax.set_xlabel('temp (mK)',fontsize=16)
ax.set_yticklabels(labels=ax.get_yticks().round(2),fontsize=16)
ax.set_xticklabels(labels=ax.get_xticks(),fontsize=16)
# Out:
# [2.95343149e-01 1.31448076e+03 5.40599764e-20]
# [2.03552078e+01 2.23922068e+03 9.52454466e-03]
# rate is  0.29534314879485085 +/- 0.28963758245553367
# rate is  20.355207783765742 +/- 0.28963758245553367
# <ipython-input-297-6a166a794538>:37: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(labels=ax.get_yticks().round(2),fontsize=16)
# <ipython-input-297-6a166a794538>:38: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels=ax.get_xticks(),fontsize=16)
# [Text(0.0, 0, '0.0'),
#  Text(25.0, 0, '25.0'),
#  Text(50.0, 0, '50.0'),
#  Text(75.0, 0, '75.0'),
#  Text(100.0, 0, '100.0'),
#  Text(125.0, 0, '125.0'),
#  Text(150.0, 0, '150.0'),
#  Text(175.0, 0, '175.0'),
#  Text(200.0, 0, '200.0'),
#  Text(225.0, 0, '225.0')]

# %%
temps
# Out:
# array([ 25.        ,  28.57142857,  32.14285714,  35.71428571,
#         39.28571429,  42.85714286,  46.42857143,  50.        ,
#         53.57142857,  57.14285714,  60.71428571,  64.28571429,
#         67.85714286,  71.42857143,  75.        ,  78.57142857,
#         82.14285714,  85.71428571,  89.28571429,  92.85714286,
#         96.42857143, 100.        , 103.57142857, 107.14285714,
#        110.71428571, 114.28571429, 117.85714286, 121.42857143,
#        125.        , 128.57142857, 132.14285714, 135.71428571,
#        139.28571429, 142.85714286, 146.42857143, 150.        ,
#        153.57142857, 157.14285714, 160.71428571, 164.28571429,
#        167.85714286, 171.42857143, 175.        , 178.57142857,
#        182.14285714, 185.71428571, 189.28571429, 192.85714286,
#        196.42857143, 200.        ])

# %%
dfold.head()
# Out:
#     temp     T1  T1err  T2_rabi  T2err   rate
# 0   25.0  22.6k  897.4     4.0k   93.7  44.3u
# 1   80.0  18.9k  786.2     4.3k  130.8    NaN
# 2  100.0  21.7k  838.3     5.0k  139.4  46.1u
# 3  120.0  20.4k   1.2k     2.3k  141.0  48.9u
# 4  130.0  21.3k   1.4k     2.6k  156.6  47.0u

# %%
dfold=pd.read_csv('temp_table.csv') #drop 5,7,11,13
dfold=dfold.drop([5,7,11,13])

# %%
bf.mock_meas((iq_array,zip(I,Q)),(Time,T150.T1()[1]),label='T1 data 4.401 and 4.392 GHz 2us readout 20mK wamp')
# Out:
# Starting experimental run with id: 89.
# 89

# %%
ts,Is,_,Qs=bf.xy_by_id(89)
mags=np.sqrt(Is**2+Qs**2)
e_mags=np.sqrt(Is[0]**2+Qs[0]**2)
g_mags=np.sqrt(Is[-1]**2+Qs[-1]**2)
mags_norm=(g_mags-mags)/(g_mags-e_mags)
times=ts

params, pcov = optimize.curve_fit(exp_fit, times, mags_norm,bounds=([0,0,-0.2],
                                                                [1,1e5,0.06 ]))
perr = np.sqrt(np.diag(pcov))

f,ax=plt.subplots()
# ax.figure(figsize=(10, 8))
ax.scatter(times, mags_norm, label='Data')
ax.plot(times, exp_fit(times, *params),
         label='Fitted function')

ax.legend(loc='best')

plt.subplots_adjust(left=0.1, right=0.8, top=0.9, bottom=0.25)
plt.show()

print('T1=',params[1],'+/-',perr[1])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\qcodes\utils\deprecate.py:59: QCoDeSDeprecationWarning: The function <get_data_by_id> is deprecated. Use "dataset.get_parameter_data" as an alternative.
#   issue_deprecation_warning(f'{t} <{n}>', reason, alternative)
# T1= 18150.26607116651 +/- 1202.0750206818836

# %%
bf.mock_meas((iq_array,np.stack((I_all,Q_all),axis=2)),(Time,np.append(T150.T1()[1],[[0],[-1]])),x1=(Timesec,np.array(ts)-ts[0]),label='qubit spec 27 mK 1000avgs')
# Out:
# An exception occured in measurement with guid: aaaaaaaa-0000-0000-0000-017f6b1873cc;
# Traceback:
# Traceback (most recent call last):
#   File "C:\_Lib\python\gershlab\QCmeasurement.py", line 388, in mock_meas
#     Ydat = ydat.reshape(len(xdat) * len(x1dat) , 2)
# ValueError: cannot reshape array of size 4080 into shape (208080,2)
# Starting experimental run with id: 44.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-5a2c8a0b6674> in <module>
# ----> 1 bf.mock_meas((iq_array,np.stack((I_all,Q_all),axis=2)),(Time,np.append(T150.T1()[1],[[0],[-1]])),x1=(Timesec,np.array(ts)-ts[0]),label='qubit spec 27 mK 1000avgs')
#
# C:\_Lib\python\gershlab\QCmeasurement.py in mock_meas(self, y, x, x1, label)
#     386                 Xdat = Xdat.flatten()
#     387                 X1dat = X1dat.flatten()
# ...

# %%
times,ts,Is,Qs=bf.reshape_data(43)

for i in range(20):
    mags=np.sqrt(Is[i]**2+Qs[i]**2)
    e_mags=np.sqrt(Is[i][0]**2+ Qs[i][0]**2)
    g_mags=np.sqrt(Is[i][-1]**2+Qs[i][-1]**2)
    mags_norm=(g_mags-mags)/(g_mags-e_mags)
    times=ts

    params, pcov = optimize.curve_fit(exp_fit, times, mags_norm,bounds=([0,0,-0.2],
                                                                    [1,1e5,0.06 ]))
    perr = np.sqrt(np.diag(pcov))

    f,ax=plt.subplots()
    # ax.figure(figsize=(10, 8))
    ax.scatter(times, mags_norm, label='Data')
    ax.plot(times, exp_fit(times, *params),
             label='Fitted function')

    ax.legend(loc='best')

    plt.subplots_adjust(left=0.1, right=0.8, top=0.9, bottom=0.25)
    plt.show()

    print('T1=',params[1],'+/-',perr[1])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\qcodes\utils\deprecate.py:59: QCoDeSDeprecationWarning: The function <get_data_by_id> is deprecated. Use "dataset.get_parameter_data" as an alternative.
#   issue_deprecation_warning(f'{t} <{n}>', reason, alternative)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-416fca520d3f> in <module>
# ----> 1 times,ts,Is,Qs=bf.reshape_data(43)
#       2
#       3 for i in range(20):
#       4     mags=np.sqrt(Is[i]**2+Qs[i]**2)
#       5     e_mags=np.sqrt(Is[i][0]**2+ Qs[i][0]**2)
#
# C:\_Lib\python\gershlab\QCmeasurement.py in reshape_data(self, idx, dscale, **kwargs)
#     123         self.db_connect()
#     124
# --> 125         ts, fs, Ie, _, _, Qe = xy_by_id(idx)
#     126
#     127         scale = int((fs[-1]-fs[0])/(fs[1]-fs[0]))+dscale
#
# ValueError: not enough values to unpack (expected 6, got 4)

# %% [markdown]
# #### 2d t1

# %%
qm = qmm.open_qm(config)
job = qm.execute(T150.T1_f()[0])
res = job.result_handles
# Out:
# 2022-03-07 13:21:11,245 - qm - INFO - Performing health check
# 2022-03-07 13:21:11,254 - qm - INFO - Health check passed
# 2022-03-07 13:21:12,346 - qm - INFO - Flags:
# 2022-03-07 13:21:12,349 - qm - INFO - Sending program to QOP
# 2022-03-07 13:21:12,410 - qm - INFO - Executing program

# %%
I_hand=res.I
Q_hand=res.Q

I_hand.wait_for_values(1)
Q_hand.wait_for_values(1)

plt.figure()
while I_hand.is_processing():
    I=I_hand.fetch_all()
    Q=Q_hand.fetch_all()
    mags=np.sqrt(I**2+Q**2)
    times=T150.T1_f()[1]
    fvec= T150.T1_f()[2]
    ang=np.unwrap(np.angle(I+1j*Q))
    plt.pcolormesh(times,fvec,mags)
    #plt.ylim(1.5e-3,1.56e-3)
    #    plt.plot(fvec,ang/np.mean(ang)+0.04)
    display.display(plt.gcf())
    display.clear_output(wait=True)
    plt.pause(0.1)

# %%
fvec,times,I,Q=bf.reshape_data(28)

f,ax=plt.subplots(figsize=(10,8))
# times=np.mean(ts.reshape(30,25),axis=0)
# fvec=np.mean(fs.reshape(30,25),axis=1)
# I=Is.reshape(30,25)
# Q=Qs.reshape(30,25)
T1lst,T1lsterr=[],[]

for i in range(len(fvec)):
    params, pcov = optimize.curve_fit(exp_fit, times, Q[i],bounds=
                                      ([-0.5,-10000,-0.1],[0.5,12000,0.5]))
    perr = np.sqrt(np.diag(pcov))

#     ax.figure(figsize=(10, 8))


    ax.scatter(times, Q[i], label='Data')
    ax.plot(times, exp_fit(times, *params),
            label='Fitted function')


   # print('T1rho=',params[1],'+/-',perr[1])
   # print('ramsey rate',params[4])
    T1lst=np.append(T1lst,params[1])
    T1lsterr=np.append(T1lsterr,perr[1])
# ax.legend(loc='best')

plt.subplots_adjust(left=0.1, right=0.8, top=0.9, bottom=0.25)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\qcodes\utils\deprecate.py:59: QCoDeSDeprecationWarning: The function <get_data_by_id> is deprecated. Use "dataset.get_parameter_data" as an alternative.
#   issue_deprecation_warning(f'{t} <{n}>', reason, alternative)
# <ipython-input-126-5e5bd3f21036>:4: RuntimeWarning: overflow encountered in exp
#   return a * np.exp(-x/b)+c
# <ipython-input-126-5e5bd3f21036>:4: RuntimeWarning: overflow encountered in exp
#   return a * np.exp(-x/b)+c
# <ipython-input-126-5e5bd3f21036>:4: RuntimeWarning: overflow encountered in exp
#   return a * np.exp(-x/b)+c
# <ipython-input-126-5e5bd3f21036>:4: RuntimeWarning: overflow encountered in exp
#   return a * np.exp(-x/b)+c
# <ipython-input-126-5e5bd3f21036>:4: RuntimeWarning: overflow encountered in exp
#   return a * np.exp(-x/b)+c
# <ipython-input-126-5e5bd3f21036>:4: RuntimeWarning: overflow encountered in exp
#   return a * np.exp(-x/b)+c
# ...

# %%
plt.errorbar(fvec,T1lst,yerr=T1lsterr)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
bf.mock_meas((iq_array,np.stack((I,Q),axis=2)),(Time, times),x1=(fr_param,fvec),label='2d T1')
# Out:
# Starting experimental run with id: 28.
# 28

# %% [markdown]
# #### ef T1

# %%
qm = qmm.open_qm(config)
job = qm.execute(T151.ef_T1()[0])
res = job.result_handles
# Out:
# 2022-01-12 10:35:31,630 - qm - INFO - Performing health check
# 2022-01-12 10:35:31,637 - qm - INFO - Health check passed
# 2022-01-12 10:35:32,746 - qm - INFO - Flags:
# 2022-01-12 10:35:32,749 - qm - INFO - Sending program to QOP
# 2022-01-12 10:35:32,830 - qm - INFO - Executing program

# %%
I_hand=res.I
Q_hand=res.Q

I_hand.wait_for_values(1)
Q_hand.wait_for_values(1)

plt.figure()
while I_hand.is_processing():
    I=I_hand.fetch_all()
    Q=Q_hand.fetch_all()
    mags=np.sqrt(I**2+Q**2)[:-2]
    e_mags=np.sqrt(I[-2]**2+Q[-2]**2)
    g_mags=np.sqrt(I[-1]**2+Q[-1]**2)
    mags_norm=(g_mags-mags)/(g_mags-e_mags)
    times=T151.ef_T1()[1]
    ang=np.unwrap(np.angle(I+1j*Q))
    plt.plot(times,mags_norm)
    #plt.ylim(1.5e-3,1.56e-3)
    #    plt.plot(fvec,ang/np.mean(ang)+0.04)
    display.display(plt.gcf())
    display.clear_output(wait=True)
    plt.pause(0.1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-850-82015532e41f> in <module>
#      20     display.display(plt.gcf())
#      21     display.clear_output(wait=True)
# ---> 22     plt.pause(0.1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in pause(interval)
#     435         if canvas.figure.stale:
#     436             canvas.draw_idle()
# --> 437         show(block=False)
#     438         canvas.start_event_loop(interval)
#     439     else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in show(*args, **kwargs)
#     351     """
#     352     _warn_if_gui_out_of_main_thread()
# --> 353     return _backend_mod.show(*args, **kwargs)
#     354
#     355
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      39     try:
# ...

# %%
bf.mock_meas((iq_array,zip(I,Q)),(Time,T140.ef_T1()[1]),label=' ef T1 data 2us readout 27mK')
# Out:
# Starting experimental run with id: 129.
# 129

# %%
ts,Is,_,Qs=bf.xy_by_id(129)
mags=np.sqrt(Is**2+Qs**2)
times=ts

params, pcov = optimize.curve_fit(exp_fit, times, mags,bounds=([-1e-2,0,-10],[1e2,1e5,10]))
perr = np.sqrt(np.diag(pcov))

f,ax=plt.subplots()
# ax.figure(figsize=(10, 8))
ax.scatter(times, mags, label='Data')
ax.plot(times, exp_fit(times, *params),
         label='Fitted function')

ax.legend(loc='best')

plt.subplots_adjust(left=0.1, right=0.8, top=0.9, bottom=0.25)
plt.show()

print('T1=',params[1],'+/-',perr[1])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\qcodes\utils\deprecate.py:59: QCoDeSDeprecationWarning: The function <get_data_by_id> is deprecated. Use "dataset.get_parameter_data" as an alternative.
#   issue_deprecation_warning(f'{t} <{n}>', reason, alternative)
# T1= 8513.254439419648 +/- 10695.595188870191

# %% [markdown]
# #### Temp dependence

# %% [markdown]
# ### ef spectroscopy

# %%
I_all,Q_all,ts = [],[],[]

for i in range(100):
    qm = qmm.open_qm(config)
    job = qm.execute(T150.ef_spec(pi=False)[0])
    res = job.result_handles
    res.wait_for_all_values()
    I = res.I.fetch_all()
    Q = res.Q.fetch_all()
    I_all.append(I)
    Q_all.append(Q)
    ts.append(time.time())
    print("elapsed time {:0.1f}".format(ts[i]-ts[0]))
# Out:
# 2022-03-09 15:36:47,749 - qm - INFO - Flags:
# 2022-03-09 15:36:47,754 - qm - INFO - Sending program to QOP
# 2022-03-09 15:36:47,822 - qm - INFO - Executing program
# elapsed time 0.0
# 2022-03-09 15:36:50,807 - qm - INFO - Flags:
# 2022-03-09 15:36:50,809 - qm - INFO - Sending program to QOP
# 2022-03-09 15:36:50,853 - qm - INFO - Executing program
# elapsed time 3.0
# 2022-03-09 15:36:53,721 - qm - INFO - Flags:
# 2022-03-09 15:36:53,723 - qm - INFO - Sending program to QOP
# 2022-03-09 15:36:53,765 - qm - INFO - Executing program
# elapsed time 5.9
# 2022-03-09 15:36:56,657 - qm - INFO - Flags:
# 2022-03-09 15:36:56,659 - qm - INFO - Sending program to QOP
# 2022-03-09 15:36:56,701 - qm - INFO - Executing program
# elapsed time 8.9
# 2022-03-09 15:36:59,632 - qm - INFO - Flags:
# 2022-03-09 15:36:59,633 - qm - INFO - Sending program to QOP
# 2022-03-09 15:36:59,676 - qm - INFO - Executing program
# elapsed time 11.8
# 2022-03-09 15:37:02,631 - qm - INFO - Flags:
# ...

# %%
fvec=(T150.ef_spec()[1])*1e-9
f,ax=plt.subplots()
mags=np.sqrt(np.array(I_all)**2+np.array(Q_all)**2).T
ax.pcolormesh(ts,fvec,mags)
ax.set_ylabel('frequency (GHz)',fontsize=16)
ax.set_xlabel('time(s)',fontsize=16)

#ax.tick_params(size=8)
f,ax=plt.subplots()
ax.plot(fvec,np.mean(mags,axis=1))
# Out:
# <ipython-input-372-f3d1e4bc0c38>:4: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   ax.pcolormesh(ts,fvec,mags)

# %%
fvec=(T150.ef_spec()[1])*1e-9
f,ax=plt.subplots()
mags=np.sqrt(np.array(I_all)**2+np.array(Q_all)**2).T
ax.pcolormesh(ts,fvec,mags)
ax.set_ylabel('frequency (GHz)',fontsize=16)
ax.set_xlabel('time(s)',fontsize=16)

#ax.tick_params(size=8)
f,ax=plt.subplots()
ax.plot(fvec,np.mean(mags,axis=1))
# Out:
# <ipython-input-336-f3d1e4bc0c38>:4: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   ax.pcolormesh(ts,fvec,mags)

# %%
bf.mock_meas((iq_array,np.stack((I_all,Q_all),axis=2)),(fr_param,fvec),x1=(Time,np.array(ts)-ts[0]),label='qubit ef spec 27 mK 100avgs')
# Out:
# Starting experimental run with id: 46.
# 46

# %%
Pe=np.abs(Asig/(Aref+Asig))
Perr=Pe*np.sqrt((Asig/np.sqrt(200))**2+(Aref/np.sqrt(200))**2)
print(Pe,Perr)


T=-1/(np.log(Pe)*sci.k/sci.h/(4.441e9))
Terr=Perr/Pe*T
print("qubit temperature is <=",np.round(T*1e3,1),'mK +/-',np.round(Terr*1e3,1),'mK')
# Out:
# 0.044450093752353245 8.205775829761112e-07
# qubit temperature is <= 68.5 mK +/- 0.0 mK

# %% [markdown]
# ### ef spec at peak only

# %%
I_all,Q_all=[],[]
for i in range(1000):
    qm = qmm.open_qm(config)
    job = qm.execute(T151.ef_spec_temp()[0])
    res = job.result_handles
    res.wait_for_all_values()
    I = res.I.fetch_all()
    Q = res.Q.fetch_all()
    I_all.append(I)
    Q_all.append(Q)
# Out:
# 2022-01-28 12:55:17,988 - qm - INFO - Flags:
# 2022-01-28 12:55:17,992 - qm - INFO - Sending program to QOP
# 2022-01-28 12:55:18,087 - qm - INFO - Executing program
# 2022-01-28 12:55:19,277 - qm - INFO - Flags:
# 2022-01-28 12:55:19,278 - qm - INFO - Sending program to QOP
# 2022-01-28 12:55:19,372 - qm - INFO - Executing program
# 2022-01-28 12:55:20,547 - qm - INFO - Flags:
# 2022-01-28 12:55:20,549 - qm - INFO - Sending program to QOP
# 2022-01-28 12:55:20,611 - qm - INFO - Executing program
# 2022-01-28 12:55:21,765 - qm - INFO - Flags:
# 2022-01-28 12:55:21,769 - qm - INFO - Sending program to QOP
# 2022-01-28 12:55:21,866 - qm - INFO - Executing program
# 2022-01-28 12:55:22,970 - qm - INFO - Flags:
# 2022-01-28 12:55:22,974 - qm - INFO - Sending program to QOP
# 2022-01-28 12:55:23,046 - qm - INFO - Executing program
# 2022-01-28 12:55:24,199 - qm - INFO - Flags:
# 2022-01-28 12:55:24,200 - qm - INFO - Sending program to QOP
# ...

# %%
_,I_all,_,Q_all=bf.xy_by_id(251)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\qcodes\utils\deprecate.py:59: QCoDeSDeprecationWarning: The function <get_data_by_id> is deprecated. Use "dataset.get_parameter_data" as an alternative.
#   issue_deprecation_warning(f'{t} <{n}>', reason, alternative)

# %%
Q_all=np.reshape(Q_all,(1000,3))
I_all=np.reshape(I_all,(1000,3))

# %%
Is=np.mean(I_all[800:900],axis=0)
Qs=np.mean(Q_all[800:900],axis=0)
Istd=np.std(I_all[800:900],axis=0)
Qstd=np.std(Q_all[800:900],axis=0)

# %%
Is
# Out:
# array([-0.00023248, -0.00021553, -0.00012607])

# %%
Is=np.reshape(Is,(T151.ef_spec_temp()[1],3))
Qs=np.reshape(Qs,(T151.ef_spec_temp()[1],3))
Istd=np.reshape(Istd,(T151.ef_spec_temp()[1],3))
Qstd=np.reshape(Qstd,(T151.ef_spec_temp()[1],3))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1327-b997f0e5951f> in <module>
# ----> 1 Is=np.reshape(Is,(T151.ef_spec_temp()[1],3))
#       2 Qs=np.reshape(Qs,(T151.ef_spec_temp()[1],3))
#       3 Istd=np.reshape(Istd,(T151.ef_spec_temp()[1],3))
#       4 Qstd=np.reshape(Qstd,(T151.ef_spec_temp()[1],3))
#
# <__array_function__ internals> in reshape(*args, **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in reshape(a, newshape, order)
#     297            [5, 6]])
#     298     """
# --> 299     return _wrapfunc(a, 'reshape', newshape, order=order)
#     300
#     301
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      56
#      57     try:
# ---> 58         return bound(*args, **kwds)
#      59     except TypeError:
# ...

# %%
Is=np.mean(Is[800:900],axis=0)
Qs=np.mean(Qs[800:900],axis=0)
Istd=np.mean(Istd[800:900],axis=0)
Qstd=np.mean(Qstd[800:900],axis=0)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
plt.plot(Is,Qs,'x')

# %%
mags=np.sqrt(Is**2+Qs**2)
mags_std=np.sqrt(Istd**2+Qstd**2)

# %%
mags_std
# Out:
# array([0.00748882, 0.0074521 , 0.00709169])

# %%
print('Qubit temp is ',mags_std[2]/(mags[0]-mags[2]))
# Out:
# Qubit temp is  -5.86983381716185

# %%
fvec=(T151.ef_spec_diff()[1])
f,ax=plt.subplots()
ax.plot(fvec,np.mean(mags_all,axis=0))

# %% [markdown]
# No pi pulse

# %%
fig = plt.figure(figsize = (10,5))
ax = fig.add_subplot(111)
mags_all = []
fvec=T151.ef_spec()[1]
for ii,I in enumerate(I_all):
    Q = Q_all[ii]
    mags = np.sqrt(I**2+Q**2)
    mags_all.append(mags-mags[0])
    
ax.pcolormesh((np.array(ts)-ts[0])/3600,fvec/1e6,np.array(mags_all).T)
ax.set_xlabel('Time (hrs)')
ax.set_ylabel('Frequency (MHz)')
# Out:
# <ipython-input-787-9921b6b07268>:10: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   ax.pcolormesh((np.array(ts)-ts[0])/3600,fvec/1e6,np.array(mags_all).T)
# Text(0, 0.5, 'Frequency (MHz)')

# %%
fvec=(T151.ef_spec()[1])
f,ax=plt.subplots()
ax.plot(fvec,np.mean(mags_all,axis=0))

# %% [markdown]
# pi pulse

# %%
bf.mock_meas((iq_array,np.stack((I_all,Q_all),axis=2)),(fr_param,fvec),x1=(Time,np.array(ts)-ts[0]),label='ef qubit spec difference')
# Out:
# Starting experimental run with id: 232.
# 232

# %%
bf.mock_meas((iq_array,np.stack((Ie,Qe),axis=2)),(fr_param,fvec),x1=(Time,np.array(ts)-ts[0]),label='ef qubit spec excited')
bf.mock_meas((iq_array,np.stack((Ig,Qg),axis=2)),(fr_param,fvec),x1=(Time,np.array(ts)-ts[0]),label='ef qubit spec ground')
# Out:
# Starting experimental run with id: 233.
# Starting experimental run with id: 234.
# 234

# %%
bf.mock_meas((iq_array,np.stack((I_all,Q_all),axis=2)),(buffer,np.arange(3)),x1=(buffer,np.arange(1000)),label='ef qubit spec temp')
# Out:
# Starting experimental run with id: 252.
# 252

# %% [markdown]
# ### ef rabi 2d

# %%
qm = qmm.open_qm(config)
job = qm.execute(T150.ef_rabi2d()[0])
res = job.result_handles
# Out:
# 2022-03-21 10:24:31,924 - qm - INFO - Flags:
# 2022-03-21 10:24:31,924 - qm - INFO - Sending program to QOP
# 2022-03-21 10:24:32,025 - qm - INFO - Executing program

# %%
I_hand=res.I
Q_hand=res.Q

I_hand.wait_for_values(1)
Q_hand.wait_for_values(1)

plt.figure()
while I_hand.is_processing():
    I=I_hand.fetch_all()
    Q=Q_hand.fetch_all()
    mag=np.sqrt(I**2+Q**2)
    ang=np.unwrap(np.angle(I+1j*Q))
    T150.plot2d(I,Q,T150.ef_rabi2d()[2],T150.ef_rabi2d()[1])
    display.display(plt.gcf())
    display.clear_output(wait=True)
    plt.pause(0.1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-177-508bcb09883b> in <module>
#      14     display.display(plt.gcf())
#      15     display.clear_output(wait=True)
# ---> 16     plt.pause(0.1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in pause(interval)
#     435         if canvas.figure.stale:
#     436             canvas.draw_idle()
# --> 437         show(block=False)
#     438         canvas.start_event_loop(interval)
#     439     else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in show(*args, **kwargs)
#     351     """
#     352     _warn_if_gui_out_of_main_thread()
# --> 353     return _backend_mod.show(*args, **kwargs)
#     354
#     355
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      39     try:
# ...

# %%
fvec=T151.ef_rabi2d()[1]
times=T151.ef_rabi2d()[2]

fftlst,fftIlst,fftQlst=[],[],[]
# number of signal points
N = len(times)
# sample spacing
T = times[1]-times[0]
x = times
for i in range(len(fvec)):
    y = np.sqrt(I**2+Q**2)[i]
    fftI=fft(I[i])
    fftQ=fft(Q[i])
    yf = fft(y)
    xf = fftfreq(N, T)
    xf = fftshift(xf)
    yplot = fftshift(yf)
    fftIplot = fftshift(fftI)
    fftQplot = fftshift(fftQ)


    plt.plot(xf, 1.0/N * np.abs(yplot))
    fftlst.append(1.0/N * np.abs(yplot))
    fftIlst.append(1.0/N * np.abs(fftIplot))
    fftQlst.append(1.0/N * np.abs(fftQplot))

    
plt.xlim(-0.01,0.01)
plt.ylim(0,0.001)
plt.grid()
plt.show()

# %%
plt.pcolormesh(xf,fvec,np.array(fftlst), vmax=0.5e-3)
#plt.ylim(4.42e9,4.48e9)
# Out:
# <ipython-input-585-c267087415d1>:1: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh(xf,fvec,np.array(fftlst), vmax=0.5e-3)

# %%
bf.pbi(84,vmax=0.5e-3)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\qcodes\utils\deprecate.py:59: QCoDeSDeprecationWarning: The function <get_data_by_id> is deprecated. Use "dataset.get_parameter_data" as an alternative.
#   issue_deprecation_warning(f'{t} <{n}>', reason, alternative)
# C:\ProgramData\Anaconda3\lib\site-packages\qcodes\utils\deprecate.py:59: QCoDeSDeprecationWarning: The function <flatten_1D_data_for_plot> is deprecated. Use "ndarray.flatten()" as an alternative.
#   issue_deprecation_warning(f'{t} <{n}>', reason, alternative)
# C:\ProgramData\Anaconda3\lib\site-packages\qcodes\dataset\data_export.py:182: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(rows)
# <class 'matplotlib.colorbar.Colorbar'>
# ...

# %%
plt.pcolormesh(xf,fvec,np.array(fftlst), vmax=0.5e-3)
#plt.ylim(4.42e9,4.48e9)
# Out:
# <ipython-input-254-c267087415d1>:1: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh(xf,fvec,np.array(fftlst), vmax=0.5e-3)

# %%
bf.mock_meas((fft_array,np.stack((np.array(fftIlst),np.array(fftQlst)),axis=2)),
             (fftfreq_param,xf),x1=(fr_param,fvec),label='ef rabi 2d fft')
# Out:
# Starting experimental run with id: 128.
# 128

# %%
fs,xfs,Is,_,_,Qs=bf.xy_by_id(78)
Is=np.reshape(Is,(200,250))
Qs=np.reshape(Is,(200,250))
xfs=np.reshape(xfs,(200,250))[0]
fs=np.reshape(fs,(200,250))

Asig=np.sqrt(Is**2+Qs**2)[50]

fs,xfs,Is,_,_,Qs=bf.xy_by_id(79)
Is=np.reshape(Is,(200,250))
Qs=np.reshape(Is,(200,250))
xfs=np.reshape(xfs,(200,250))[0]
fs=np.reshape(fs,(200,250))

Aref=np.sqrt(Is**2+Qs**2)[50]

Pe=Asig/(Asig+Aref)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\qcodes\utils\deprecate.py:59: QCoDeSDeprecationWarning: The function <get_data_by_id> is deprecated. Use "dataset.get_parameter_data" as an alternative.
#   issue_deprecation_warning(f'{t} <{n}>', reason, alternative)
# C:\ProgramData\Anaconda3\lib\site-packages\qcodes\utils\deprecate.py:59: QCoDeSDeprecationWarning: The function <get_data_by_id> is deprecated. Use "dataset.get_parameter_data" as an alternative.
#   issue_deprecation_warning(f'{t} <{n}>', reason, alternative)

# %%
bf.mock_meas((iq_array,np.stack((I,Q),axis=2)),(Time,T151.ef_rabi2d()[2]),x1=(fr_param,T151.ef_rabi2d()[1]),label='ef rabi 2d')
# Out:
# 2022-01-24 08:03:15,045 - qm - INFO - Performing health check
# 2022-01-24 08:03:15,052 - qm - INFO - Health check passed
# Starting experimental run with id: 195.
# 195

# %%
fs,ts,Is,_,_,Qs=bf.xy_by_id(27)

f,ax=plt.subplots()
ax.plot(ts,np.sqrt(Is**2+Qs**2),'.')


ts_avg=np.mean(ts.reshape(20,50),axis=0)
mag_avg=np.mean(np.sqrt(Is**2+Qs**2).reshape(20,50),axis=0)
ax.plot(ts,np.sqrt(Is**2+Qs**2),'.')
ax.plot(ts_avg,mag_avg,'--x')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\qcodes\utils\deprecate.py:59: QCoDeSDeprecationWarning: The function <get_data_by_id> is deprecated. Use "dataset.get_parameter_data" as an alternative.
#   issue_deprecation_warning(f'{t} <{n}>', reason, alternative)

# %%
params, pcov = optimize.curve_fit(ef_rabi_fit, ts_avg, mag_avg,
                                               bounds=([0.1e-5,100,0,0.005,0,100,-0.1],
                                                       [1e-2,600,2e-2,0.02,10,1000,100]))

plt.figure(figsize=(10, 8))
plt.scatter(ts_avg, mag_avg, label='Data')

times=np.linspace(0,800,200)
plt.plot(times, ef_rabi_fit(times, *params),
         label='Fitted function')

plt.legend(loc='best')
plt.xlabel('time (ns)')
plt.ylabel('S21 (V)')
plt.subplots_adjust(left=0.1, right=0.8, top=0.9, bottom=0.25)
plt.show()
perr = np.sqrt(np.diag(pcov))


#print(params)
print('T2={:0.0f}'.format(params[1]),'+/-{:0.0f}'.format(perr[1]),'ns')
print('rabi rate ={:0.4f}'.format(params[3]),'+/-{:0.4f}'.format(perr[3]),'GHz')
print('T_$\pi$={:0.1f}'.format(1/params[3]),'+/-{:0.1f}'.format(perr[3]/(params[3]**2)),'ns')
# Out:
# T2=100 +/-17 ns
# rabi rate =0.0159 +/-0.0006 GHz
# T_$\pi$=63.0 +/-2.4 ns

# %% [markdown]
# ### ef rabi 1d

# %%
dt=12//4
qm = qmm.open_qm(config)
job = qm.execute(T151.ef_rabi1d(dt=dt)[0])
res = job.result_handles
# Out:
# 2022-01-26 16:04:52,624 - qm - INFO - Performing health check
# 2022-01-26 16:04:52,631 - qm - INFO - Health check passed
# 2022-01-26 16:04:53,966 - qm - INFO - Flags:
# 2022-01-26 16:04:53,969 - qm - INFO - Sending program to QOP
# 2022-01-26 16:04:54,047 - qm - INFO - Executing program

# %%
I_hand=res.I
Q_hand=res.Q

I_hand.wait_for_values(1)
Q_hand.wait_for_values(1)

plt.figure()
while I_hand.is_processing():
    I=I_hand.fetch_all()
    Q=Q_hand.fetch_all()
    f,ax=plt.subplots()
    mags=np.sqrt(I**2+Q**2)[:-2]
    e_mags=np.sqrt(I[-2]**2+Q[-2]**2)
    g_mags=np.sqrt(I[-1]**2+Q[-1]**2)
    mags_norm=(g_mags-mags)/(g_mags-e_mags)
    times=T151.ef_rabi1d(dt=dt)[1]

  #  ax.plot(T151.ef_rabi1d(dt=dt)[1],I[:-2])
    ax.plot(T151.ef_rabi1d(dt=dt)[1],Q[:-2])
    display.display(plt.gcf())
    display.clear_output(wait=True)

    plt.pause(0.1)

# %%
I_all,Q_all,times_all=[],[],[]
dtvec=np.arange(20//4,120//4,8//4)
for i,dt in enumerate(dtvec):
    dtint=dt.item()
    qm = qmm.open_qm(config)
    job = qm.execute(T151.ef_rabi1d(dt=dtint)[0])
    res = job.result_handles
    res.wait_for_all_values()
    times_all.append(T151.ef_rabi1d(dt=dtint)[1])
    I = res.I.fetch_all()
    Q = res.Q.fetch_all()
    I_all.append(I)
    Q_all.append(Q)
# Out:
# 2022-01-24 11:25:16,498 - qm - INFO - Flags:
# 2022-01-24 11:25:16,500 - qm - INFO - Sending program to QOP
# 2022-01-24 11:25:16,621 - qm - INFO - Executing program
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-241-8d38dc489982> in <module>
#       6     job = qm.execute(T151.ef_rabi1d(dt=dtint)[0])
#       7     res = job.result_handles
# ----> 8     res.wait_for_all_values()
#       9     times_all.append(T151.ef_rabi1d(dt=dtint)[1])
#      10     I = res.I.fetch_all()
#
# C:\ProgramData\Anaconda3\lib\site-packages\qm\_results_01.py in wait_for_all_values(self, timeout)
#     742             if end is not None:
#     743                 time_remaining = max(0.0, end - time.time())
# --> 744             all_done = all_done and result.wait_for_all_values(time_remaining)
#     745             keys = keys[1:]
#     746         return all_done
#
# ...

# %%
for i in range(len(I_all)):
    plt.plot(times_all[i],I_all[i][:-2])

# %%
bf.mock_meas((iq_array,zip(I,Q)),(Time,np.append(times,([0],[0]))),label='ef rabi 4.441GHz')
# Out:
# Starting experimental run with id: 222.
# 222

# %%
times=T151.ef_rabi1d(dt=dt)[1]

params, pcov = optimize.curve_fit(ef_rabi_fit, times, mags,
                                                bounds=([0.1e-5,100,0,0.008,0,100,-0.1],
                                                        [1e-2,3000,2e-2,0.025,10,1000,100]))

plt.figure(figsize=(10, 8))
plt.scatter(times, mags, label='Data')
times_plot=np.linspace(0,5000,400)
plt.plot(times_plot, ef_rabi_fit(times_plot, *params),
         label='Fitted function')

plt.legend(loc='best')
plt.xlabel('time (ns)')
plt.ylabel('P_f')
plt.subplots_adjust(left=0.1, right=0.8, top=0.9, bottom=0.25)
plt.show()
perr = np.sqrt(np.diag(pcov))


#print(params)
print('T2={:0.0f}'.format(params[1]),'+/-{:0.0f}'.format(perr[1]),'ns')
print('T2_e={:0.0f}'.format(params[-2]),'+/-{:0.0f}'.format(perr[-2]),'ns')
print('rabi rate ={:0.4f}'.format(params[3]),'+/-{:0.4f}'.format(perr[3]),'GHz')
print('T_$\pi$={:0.1f}'.format(1/params[3]),'+/-{:0.1f}'.format(perr[3]/(params[3]**2)),'ns')
print('Amplitude={:0.5f}'.format(params[0]))
# Out:
# T2=1356 +/-140 ns
# T2_e=227 +/-100 ns
# rabi rate =0.0119 +/-0.0000 GHz
# T_$\pi$=83.7 +/-0.2 ns
# Amplitude=0.00141

# %% [markdown]
# ### ef ramsey

# %%
qm = qmm.open_qm(config)
job = qm.execute(T151.ef_ramsey()[0])
res = job.result_handles
# Out:
# 2022-01-26 16:31:14,023 - qm - INFO - Performing health check
# 2022-01-26 16:31:14,035 - qm - INFO - Health check passed
# 2022-01-26 16:31:15,338 - qm - INFO - Flags:
# 2022-01-26 16:31:15,339 - qm - INFO - Sending program to QOP
# 2022-01-26 16:31:15,730 - qm - INFO - Executing program

# %%
I_hand=res.I
Q_hand=res.Q

I_hand.wait_for_values(1)
Q_hand.wait_for_values(1)

plt.figure()
while I_hand.is_processing():
    I=I_hand.fetch_all()
    Q=Q_hand.fetch_all()    
    mags=np.sqrt(I**2+Q**2)[:-2]
    e_mags=np.sqrt(I[-2]**2+Q[-2]**2)
    g_mags=np.sqrt(I[-1]**2+Q[-1]**2)
    mags_norm=(g_mags-mags)/(g_mags-e_mags)
    times=T151.ef_ramsey()[1]
    ang=np.unwrap(np.angle(I+1j*Q))
    plt.plot(times,mags_norm)
    #plt.ylim(1.5e-3,1.56e-3)
    #    plt.plot(fvec,ang/np.mean(ang)+0.04)
    display.display(plt.gcf())
    display.clear_output(wait=True)
    plt.pause(0.1)

# %% [markdown]
# ### Qubit Temp

# %%
qm = qmm.open_qm(config)
job = qm.execute(T150.qubit_temp()[0])
res = job.result_handles
# Out:
# 2022-03-10 10:17:35,093 - qm - INFO - Flags:
# 2022-03-10 10:17:35,096 - qm - INFO - Sending program to QOP
# 2022-03-10 10:17:35,215 - qm - INFO - Executing program

# %%
I_hand=res.I
Q_hand=res.Q

I_hand.wait_for_values(1)
Q_hand.wait_for_values(1)
times=T150.qubit_temp()[1]
plt.figure()
while I_hand.is_processing():
    I=I_hand.fetch_all()
    Q=Q_hand.fetch_all()
    
    Ig=np.array(I)[1::2]
    Ie=np.array(I)[::2] 
    Qg=np.array(Q)[1::2]
    Qe=np.array(Q)[::2] 
    mags_e=np.sqrt(Ie**2+Qe**2)
    mags_g=np.sqrt(Ig**2+Qg**2)
    
    plt.plot(times,mags_e,label='reference')
    plt.plot(times,mags_g,label='signal')

  #  plt.ylabel('$P_e$',size=16)
    plt.xlabel('time(ns)',size=16)

    plt.subplots_adjust(left=0.1, right=0.8, top=0.9, bottom=0.25)
    display.display(plt.gcf())
    display.clear_output(wait=True)
    plt.pause(0.1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-47-e1f7def9d965> in <module>
#      26     display.display(plt.gcf())
#      27     display.clear_output(wait=True)
# ---> 28     plt.pause(0.1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in pause(interval)
#     436             canvas.draw_idle()
#     437         show(block=False)
# --> 438         canvas.start_event_loop(interval)
#     439     else:
#     440         time.sleep(interval)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in start_event_loop(self, timeout)
#    2406         while self._looping and counter * timestep < timeout:
#    2407             self.flush_events()
# -> 2408             time.sleep(timestep)
#    2409             counter += 1
#    2410
#
# KeyboardInterrupt:

# %%
# ts,Is,_,Qs=bf.xy_by_id(201)
# mags_e=np.sqrt(Is**2+Qs**2)
# ts,Is,_,Qs=bf.xy_by_id(200)
# mags_g=np.sqrt(Is**2+Qs**2)

# times=np.array(ts)


refmags=np.array(mags_e)
sigmags=np.array(mags_g)
params, pcov = optimize.curve_fit(ef_rabi_fit, times, refmags,
                                                bounds=([12e-4,100,0,0.001,3,100,0],
                                                        [2e-2,5000,3e-1,0.015,7,2000,1e-2]))

perr = np.sqrt(np.diag(pcov))
times1=np.linspace(0,times[-1],1000)
f,ax=plt.subplots(figsize=(10, 8))
ax.scatter(times, refmags, label='reference')
ax.plot(times1, ef_rabi_fit(times1, *params),color='C3')


plt.subplots_adjust(left=0.1, right=0.8, top=0.9, bottom=0.25)
print(params)
print('Amplitude ref',params[0])
aref=params[0]
areferr=perr[0]
params, pcov_1 = optimize.curve_fit(ef_rabi_fit, times, sigmags,
                                                bounds=([12e-4,100,0,0.001,3,30,0],
                                                        [2e-2,5000,3e-1,0.0011,7,2000,1e-2]))

perr_1 = np.sqrt(np.diag(pcov_1))

ax.scatter(times, sigmags, label='signal')
ax.plot(times1, ef_rabi_fit(times1, *params),color='C2')

#print('Amplitude sig',sigmags[np.where(times==500)]-sigmags[np.where(times==260)])

asig=params[0]
asigerr=perr_1[0]
#asig=(sigmags[np.where(times==504)]-sigmags[np.where(times==264)])/2
ax.legend(loc='best')
print(params)
Pe=asig/(aref+asig)
Perr=np.sqrt((asigerr/asig)**2+(areferr/aref)**2)*Pe
print('Pe=',np.round(Pe,3),'+/-',np.round(Perr,3))

ax.set_xlabel('times (ns)')
ax.set_ylabel('S21(V)')
T=-1/(np.log(Pe)*sci.k/sci.h/(4.44e9))
Terr=Perr/Pe*T
print("qubit temperature is <=",np.round(T*1e3,1),'mK +/-',np.round(Terr*1e3,1),'mK')
#print('$\pi$/$\Omega_R$ =',1/params[3],'+/-',perr[3],'ns')
# Out:
# [1.20000000e-03 1.00000000e+02 2.56470153e-03 1.00000298e-03
#  5.99730269e+00 1.00000000e+02 1.13560920e-03]
# Amplitude ref 0.0012000000000000001
# [1.20051491e-03 1.00007623e+02 2.53711504e-03 1.00000000e-03
#  6.99994011e+00 9.22962111e+01 6.02765812e-04]
# Pe= 0.5 +/- 192.461
# qubit temperature is <= 307.5 mK +/- 118343.6 mK

# %%
bf.mock_meas((iq_array,zip(Ig,Qg)),(Time,times),label=' signal qubit 4.441GHz ef temp 24mK bath thermalized 2k avgs')
bf.mock_meas((iq_array,zip(Ie,Qe)),(Time,times),label=' reference qubit temp 4.441GHz ef 24mK bath thermalized 2k avgs')
# Out:
# Starting experimental run with id: 227.
# Starting experimental run with id: 228.
# 228

# %% [markdown]
# #### Qubit temp calibration

# %%
qm = qmm.open_qm(config)
job = qm.execute(T140.pumped_qubit_temp()[0])
res = job.result_handles
# Out:
# 2021-12-13 12:04:59,060 - qm - INFO - Performing health check
# 2021-12-13 12:04:59,067 - qm - INFO - Health check passed
# 2021-12-13 12:05:00,081 - qm - INFO - Flags:
# 2021-12-13 12:05:00,086 - qm - INFO - Executing high level program

# %%
I_hand=res.I
Q_hand=res.Q

I_hand.wait_for_values(1)
Q_hand.wait_for_values(1)

plt.figure()
while I_hand.is_processing():
    I=I_hand.fetch_all()
    Q=Q_hand.fetch_all()
    mag=np.sqrt(I**2+Q**2)
    ang=np.unwrap(np.angle(I+1j*Q))
    T140.plot2d(I.T[1::2].T,Q.T[1::2].T,T140.pumped_qubit_temp()[1],T140.pumped_qubit_temp()[2])
    #    plt.plot(fvec,ang/np.mean(ang)+0.04)
    display.display(plt.gcf())
    display.clear_output(wait=True)
    plt.pause(0.1)

# %%
times=(T140.pumped_qubit_temp()[1])
tpulse=(T140.pumped_qubit_temp()[2])

f,ax=plt.subplots()
for i in range(len(tpulse)):
    ax.plot(times,mag.T[1::2].T[i])
    
#ax.set_xlim(3.76,3.78)

# %%
Pvec,Perrvec=[],[]

tempvec,temperrvec=[],[]
f,ax=plt.subplots()
for i in range(len(tpulse)):
    params, pcov = optimize.curve_fit(ef_rabi_fit, times,  mag.T[::2].T[0],
                                                bounds=([0.1e-5,10,0,0.011,3,10,1e-4],
                                                        [1e-2,2000,3e-1,0.0111,7,2000,1e-3]))
    perr = np.sqrt(np.diag(pcov))
    times1=np.linspace(0,times[-1],1000)
    ax.scatter(times, mag.T[::2].T[0], label='reference')
    # ax.plot(times1, ef_rabi_fit(times1, *params),color='C3')
    params, pcov_1 = optimize.curve_fit(ef_rabi_fit, times, mag.T[1::2].T[i],
                                                    bounds=([0.1e-5,100,0,0.0028,4.0,3000,-1e-3],
                                                            [1e-2,2000,3e-1,0.003,6.0,10000,2e-3]))

    perr_1 = np.sqrt(np.diag(pcov_1))

    ax.scatter(times, mag.T[1::2].T[i], label=int(tpulse[i]))
    ax.plot(times1, ef_rabi_fit(times1, *params),color='C2')
    print(params[0])
    asig=params[0]
    asigerr=perr_1[0]
    #asig=(sigmags[np.where(times==504)]-sigmags[np.where(times==264)])/2
    ax.legend(loc='best')
    print(params)
    Pe=asig/(aref+asig)
    Perr=np.sqrt((asigerr/asig)**2+(areferr/aref)**2)*Pe
    print('Pe=',np.round(Pe,3),'+/-',np.round(Perr,3))

    ax.set_xlabel('times (ns)')
    ax.set_ylabel('S21(V)')
    #ax.set_ylim(0.000895,0.00091)
    T=-1/(np.log(Pe)*sci.k/sci.h/(4.555e9))
    Terr=Perr/Pe*T
    print("qubit temperature is <=",np.round(T*1e3,1),'mK +/-',np.round(Terr*1e3,1),'mK')
    tempvec.append(T)
    temperrvec.append(Terr)
    Pvec.append(Pe)
    Perrvec.append(Perr)
    print('$\pi$/$\Omega_R$ =',1/params[3],'+/-',perr[3],'ns')
ax.legend()
# Out:
# 2.7068284821746753e-05
# [ 2.70682848e-05  1.63070955e+03  5.42226646e-04  2.90053100e-03
#   6.00000000e+00  9.99919563e+03 -7.17501244e-07]
# Pe= 0.038 +/- 0.022
# qubit temperature is <= 66.9 mK +/- 37.9 mK
# $\pi$/$\Omega_R$ = 344.7644589813583 +/- 0.01674693362000093 ns
# 2.4755073173068563e-05
# [ 2.47550732e-05  1.21893187e+03  5.34293970e-04  2.99921234e-03
#   5.35191125e+00  3.01318718e+03 -2.10745270e-05]
# Pe= 0.035 +/- 0.02
# qubit temperature is <= 65.2 mK +/- 37.6 mK
# $\pi$/$\Omega_R$ = 333.4208739318538 +/- 0.01674693362000093 ns
# 3.7286899336571273e-05
# [ 3.72868993e-05  1.98744779e+03  5.22201914e-04  2.99994101e-03
#   5.57232296e+00  9.98986454e+03 -3.85815763e-05]
# Pe= 0.052 +/- 0.019
# qubit temperature is <= 73.8 mK +/- 27.0 mK
# $\pi$/$\Omega_R$ = 333.3398880830463 +/- 0.01674693362000093 ns
# 2.903098641083135e-05
# [ 2.90309864e-05  1.64120671e+03  5.23382627e-04  2.90394910e-03
#   5.29715191e+00  3.01875533e+03 -2.98066266e-05]
# Pe= 0.041 +/- 0.02
# ...

# %%
f,ax=plt.subplots()
ax.errorbar(tpulse[:-2]/335,Pvec[:-2],yerr=Perrvec[:-2])
ax.plot(tpulse[:-2]/335,tpulse[:-2]/335)
ax.set_xlabel('pulse fraction of pi')
# Out:
# Text(0.5, 0, 'pulse fraction of pi')

# %%
bf.mock_meas((iq_array,np.stack((I.T[::2].T,Q.T[::2].T),axis=1)),(amplitude, tpulse),x1=(Time,times),label='ref pulsed qubit temp')
bf.mock_meas((iq_array,np.stack((I.T[1::2].T,Q.T[1::2].T),axis=1)),(amplitude, tpulse),x1=(Time,times),label='sig pulsed qubit temp')
# Out:
# Starting experimental run with id: 122.
# Starting experimental run with id: 123.
# 123

# %% [markdown]
# ### T1rho

# %%
qm = qmm.open_qm(config)
job = qm.execute(T151_1.T1rho()[0])
res = job.result_handles
# Out:
# 2022-02-16 14:38:01,442 - qm - INFO - Performing health check
# 2022-02-16 14:38:01,448 - qm - INFO - Health check passed
# 2022-02-16 14:38:02,315 - qm - INFO - Flags:
# 2022-02-16 14:38:02,315 - qm - INFO - Sending program to QOP
# 2022-02-16 14:38:02,412 - qm - INFO - Executing program

# %%
I_hand=res.I
Q_hand=res.Q

I_hand.wait_for_values(1)
Q_hand.wait_for_values(1)

plt.figure()
while I_hand.is_processing():
    I=I_hand.fetch_all()
    Q=Q_hand.fetch_all()
    mag=np.sqrt(I**2+Q**2)
    ang=np.unwrap(np.angle(I+1j*Q))
    T151_1.plot2d(I.T[::2].T,Q.T[::2].T,  T151_1.T1rho()[2],T151_1.T1rho()[1])
    T151_1.plot2d(I.T[1::2].T,Q.T[1::2].T,T151_1.T1rho()[2],T151_1.T1rho()[1])
    #    plt.plot(fvec,ang/np.mean(ang)+0.04)
    display.display(plt.gcf())
    display.clear_output(wait=True)
    plt.pause(0.1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-67-f11afd44d5f1> in <module>
#      11     mag=np.sqrt(I**2+Q**2)
#      12     ang=np.unwrap(np.angle(I+1j*Q))
# ---> 13     T151_1.plot2d(I.T[::2].T,Q.T[::2].T,  T151_1.T1rho()[2],T151_1.T1rho()[1])
#      14     T151_1.plot2d(I.T[1::2].T,Q.T[1::2].T,T151_1.T1rho()[2],T151_1.T1rho()[1])
#      15     #    plt.plot(fvec,ang/np.mean(ang)+0.04)
#
# ~\Desktop\QM OPX\T151_1_Neon_OPX\OPXexperiments.py in T1rho(self, *args)
#    2038             ###############
#    2039             update_frequency("resonator",30.5e6)
# -> 2040             update_frequency("qubit",386e6)
#    2041             update_frequency("qubit_multi",381e6)
#    2042
#
# C:\ProgramData\Anaconda3\lib\site-packages\qm\qua\_dsl.py in update_frequency(element, new_frequency, units, keep_phase)
#     218     """
# ...

# %%
plt.plot(T151_1.T1rho_test()[2],np.sqrt(I.T[::2]**2+Q.T[::2]**2))
# Out:
# 2022-02-14 17:52:03,947 - qm - INFO - Performing health check
# 2022-02-14 17:52:03,947 - qm - INFO - Health check passed
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1483-d95071ad01e1> in <module>
# ----> 1 plt.plot(T151_1.T1rho_test()[2],np.sqrt(I.T[::2]**2+Q.T[::2]**2))
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
# ...

# %%
f,ax=plt.subplots(figsize=(10,10))
times=T151.T1rho()[2]
avec= T151.T1rho()[1]
T1rholst,T1rholsterr=[],[]
flst,flsterr=[],[]


for i in range(len(avec)):
    params, pcov = optimize.curve_fit(ramsey_fit, times, mag[i][::2],bounds=
                                      ([0.0001,100,0.00001,0.001/4,2],[0.02,10000,0.01,0.03/4,7]))
    perr = np.sqrt(np.diag(pcov))

    # ax.figure(figsize=(10, 8))


    ax.scatter(times, mag[i][::2], label='Data')
    ax.plot(times, ramsey_fit(times, *params),
            label='Fitted function')


   # print('T1rho=',params[1],'+/-',perr[1])
    print('ramsey rate',params[3])
    flst=np.append(flst,params[3])
    flsterr=np.append(flsterr,perr[3])
    T1rholst=np.append(T1rholst,params[1])
    T1rholsterr=np.append(T1rholsterr,perr[1])
#ax.legend(loc='best')

plt.subplots_adjust(left=0.1, right=0.8, top=0.9, bottom=0.25)
plt.show()
# Out:
# ramsey rate 0.0010340767584530544
# ramsey rate 0.002823598837197631
# ramsey rate 0.002370415940165005
# ramsey rate 0.002585054188060984
# ramsey rate 0.004368405123758304
# ramsey rate 0.0031264025220583817

# %%
plt.errorbar(avec*2.7,T1rholst,yerr=T1rholsterr)
plt.xlabel('f (MHz) ')
plt.ylabel('T1rhon (ns)')
# Out:
# Text(0, 0.5, 'T1rhon (ns)')

# %%
Pi_phi=1/T1rholst-1/(2*15e3)
plt.plot(avec*2.7,Pi_phi)
plt.xscale('log')
plt.yscale('log')
plt.plot(avec*2.7,5e-5/avec,'--',color='gray')
plt.xlabel('f (MHz) ')
plt.ylabel('PSD(f)')
# Out:
# <ipython-input-1489-810208c550b9>:5: RuntimeWarning: divide by zero encountered in true_divide
#   plt.plot(avec*2.7,5e-5/avec,'--',color='gray')
# Text(0, 0.5, 'PSD(f)')

# %%
plt.errorbar(avec*2.7,flst,yerr=flsterr)

plt.xlabel('f (MHz) ')
plt.ylabel('f ramsey')
# Out:
# Text(0, 0.5, 'f ramsey')

# %%
bf.mock_meas((iq_array,np.stack((I.T[::2].T,Q.T[::2].T),axis=2)),  (Time,T151.T1rho()[2]),x1=(amplitude, T151.T1rho()[1]),label='T1rho ')
bf.mock_meas((iq_array,np.stack((I.T[1::2].T,Q.T[1::2].T),axis=2)),(Time,T151.T1rho()[2]),x1=(amplitude, T151.T1rho()[1]),label='T1 for T1rho ')
# Out:
# Starting experimental run with id: 246.
# Starting experimental run with id: 247.
# 247

# %% [markdown]
# ### fh spec

# %%
I_all,Q_all,ts = [],[],[]

for i in range(50):
    qm = qmm.open_qm(config)
    job = qm.execute(T140.fh_spec(pi=True)[0])
    res = job.result_handles
    res.wait_for_all_values()
    I = res.I.fetch_all()
    Q = res.Q.fetch_all()
    I_all.append(I)
    Q_all.append(Q)
    ts.append(time.time())
# Out:
# 2021-12-10 16:13:39,907 - qm - INFO - Performing health check
# 2021-12-10 16:13:39,914 - qm - INFO - Health check passed
# 2021-12-10 16:13:40,578 - qm - INFO - Flags:
# 2021-12-10 16:13:40,579 - qm - INFO - Executing high level program
# 2021-12-10 16:13:56,100 - qm - INFO - Flags:
# 2021-12-10 16:13:56,101 - qm - INFO - Executing high level program
# 2021-12-10 16:14:11,686 - qm - INFO - Flags:
# 2021-12-10 16:14:11,687 - qm - INFO - Executing high level program
# 2021-12-10 16:14:27,210 - qm - INFO - Flags:
# 2021-12-10 16:14:27,211 - qm - INFO - Executing high level program
# 2021-12-10 16:14:42,719 - qm - INFO - Flags:
# 2021-12-10 16:14:42,722 - qm - INFO - Executing high level program
# 2021-12-10 16:14:58,229 - qm - INFO - Flags:
# 2021-12-10 16:14:58,230 - qm - INFO - Executing high level program
# 2021-12-10 16:15:13,731 - qm - INFO - Flags:
# 2021-12-10 16:15:13,732 - qm - INFO - Executing high level program
# 2021-12-10 16:15:29,296 - qm - INFO - Flags:
# ...

# %%
fig = plt.figure(figsize = (10,5))
ax = fig.add_subplot(111)
mags_all = []
fvec=T140.fh_spec()[1]
for ii,I in enumerate(I_all):
    Q = Q_all[ii]
    mags = np.sqrt(I**2+Q**2)
    mags_all.append(mags-mags[0])
    
ax.pcolormesh((np.array(ts)-ts[0])/3600,fvec/1e6,np.array(mags_all).T)
ax.set_xlabel('Time (hrs)')
ax.set_ylabel('Frequency (MHz)')
# Out:
# <ipython-input-998-25c98999bc08>:10: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   ax.pcolormesh((np.array(ts)-ts[0])/3600,fvec/1e6,np.array(mags_all).T)
# Text(0, 0.5, 'Frequency (MHz)')

# %%
fvec=(T140.fh_spec()[1]+4.7e9)*1e-9
f,ax=plt.subplots()
ax.plot(fvec,np.mean(mags_all,axis=0))

# %%
dur=2000
config['pulses']['readout_pulse']['length']=dur
config['integration_weights']['integW1']['cosine']=[1.0] * int(dur // 4)
config['integration_weights']['integW1']['sine']  =[0.0] * int(dur // 4)
config['integration_weights']['integW2']['cosine']=[0.0] * int(dur // 4)
config['integration_weights']['integW2']['sine']  =[1.0] * int(dur // 4)

# %%
qm = qmm.open_qm(config)
job = qm.execute(T151.IQ_blobs()[0])
res = job.result_handles
res.wait_for_all_values()
I = res.I.fetch_all()
Q = res.Q.fetch_all()
# Out:
# 2022-01-26 12:02:25,976 - qm - INFO - Performing health check
# 2022-01-26 12:02:25,983 - qm - INFO - Health check passed
# 2022-01-26 12:02:26,925 - qm - INFO - Flags:
# 2022-01-26 12:02:26,929 - qm - INFO - Sending program to QOP
# 2022-01-26 12:02:26,981 - qm - INFO - Executing program

# %% [markdown]
# ### Temp Loop

# %%
temp_lst=np.array([1,2,3,4])

# %%
df=pd.DataFrame(columns=['temp','T1','T1err','T2_rabi','T2err'])

# %%
df.append({'temp':1,'T1':2,'T1err':3},ignore_index=True)
# Out:
#   temp T1 T1err
# 0    1  2     3

# %%
# LS370 = Model_372(name = 'LS370inputCh', address = 'GPIB::12::INSTR', terminator='\n')

# %%
# from qcodes.instrument_drivers.Lakeshore.Model_372 import Model_372

# %%
temp=190

# %%
qm = qmm.open_qm(config)
job = qm.execute(T150.T1()[0])
res = job.result_handles

I_hand=res.I
Q_hand=res.Q

I_hand.wait_for_values(1)
Q_hand.wait_for_values(1)

plt.figure()
while I_hand.is_processing():
    I=I_hand.fetch_all()
    Q=Q_hand.fetch_all()
    mags=np.sqrt(I**2+Q**2)[:-2]
    e_mags=np.sqrt(I[-2]**2+Q[-2]**2)
    g_mags=np.sqrt(I[-1]**2+Q[-1]**2)
    mags_norm=(g_mags-mags)/(g_mags-e_mags)
    I_norm=(I[-1]-I[:-2])/(I[-1]-I[-2])
    times=T150.T1()[1]
    ang=np.unwrap(np.angle(I+1j*Q))
    plt.plot(times,mags_norm)
    #plt.ylim(1.5e-3,1.56e-3)
    #    plt.plot(fvec,ang/np.mean(ang)+0.04)
    display.display(plt.gcf())
    display.clear_output(wait=True)
    plt.pause(0.1)

idx=bf.mock_meas((iq_array,zip(I,Q)),(Time,T150.T1()[1]),label='T1 data 4.389GHz 3us readout Temp={:0.1f}'.format(temp))
# Out:
# Starting experimental run with id: 81.

# %%
ts,Is,_,Qs=bf.xy_by_id(idx)
mags=np.sqrt(Is**2+Qs**2)
e_mags=np.sqrt(Is[0]**2+Qs[0]**2)
g_mags=np.sqrt(Is[-1]**2+Qs[-1]**2)
mags_norm=(g_mags-mags)/(g_mags-e_mags)+0.05
times=ts

params, pcov = optimize.curve_fit(exp_fit, times, mags_norm,bounds=([-1,0,0.04],
                                                                [1,1e5,0.5]))
perr = np.sqrt(np.diag(pcov))

f,ax=plt.subplots()
# ax.figure(figsize=(10, 8))
ax.scatter(times, mags_norm, label='Data')
ax.plot(times, exp_fit(times, *params),
         label='Fitted function')

ax.legend(loc='best')

plt.subplots_adjust(left=0.1, right=0.8, top=0.9, bottom=0.25)
plt.show()

print('T1=',params[1],'+/-',perr[1])
T1=params[1]
T1_err=perr[1]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\qcodes\utils\deprecate.py:59: QCoDeSDeprecationWarning: The function <get_data_by_id> is deprecated. Use "dataset.get_parameter_data" as an alternative.
#   issue_deprecation_warning(f'{t} <{n}>', reason, alternative)
# T1= 6198.883805668 +/- 1296.659731891725

# %%
qm = qmm.open_qm(config)
job = qm.execute(T150.rabi1d()[0])
res = job.result_handles

I_hand=res.I
Q_hand=res.Q

I_hand.wait_for_values(1)
Q_hand.wait_for_values(1)

plt.figure()
while I_hand.is_processing():
    I=I_hand.fetch_all()
    Q=Q_hand.fetch_all()
    f,ax=plt.subplots()
    mags=np.sqrt(I**2+Q**2)[:-2]
    e_mags=np.sqrt(I[-2]**2+Q[-2]**2)
    g_mags=np.sqrt(I[-1]**2+Q[-1]**2)
    mags_norm=(g_mags-mags)/(g_mags-e_mags)
    times=T150.rabi1d()[1]

    ax.plot(T150.rabi1d()[1],mags_norm)
    display.display(plt.gcf())
    display.clear_output(wait=True)
    plt.pause(0.1)

idx=bf.mock_meas((iq_array,zip(I,Q)),(Time,np.append(T150.rabi1d()[1],([0],[0]))),label=' rabi with no amp 2k avg 4.389GHz Temp={:0.3f}'.format(temp))
# Out:
# Starting experimental run with id: 79.

# %%
ts,I,_,Q=bf.xy_by_id(idx)

times=ts[:-2]
mags=np.sqrt(I**2+Q**2)[:-2]
e_mags=np.sqrt(I[-2]**2+Q[-2]**2)
g_mags=np.sqrt(I[-1]**2+Q[-1]**2)
mags_norm=(g_mags-mags)/(g_mags-e_mags)
params, pcov = optimize.curve_fit(rabi_fit, times, mags_norm,
                                               bounds=([0.4,100,0.3,0.005,0],
                                                       [4.0,15000,1.4,0.008,2*np.pi]))

plt.figure(figsize=(10, 8))
plt.scatter(times[:100], mags_norm[:100], label='Data')

times=np.linspace(0,3000,1000)
plt.plot(times, rabi_fit(times, *params),
         label='Fitted function')
plt.xlabel('time (ns)',size=16)
plt.ylabel('$P_f$',size=16)
plt.legend(loc='best')

plt.subplots_adjust(left=0.1, right=0.8, top=0.9, bottom=0.25)
plt.show()


perr = np.sqrt(np.diag(pcov))
print(params)
print('T2*=',params[1]/1e3,'us +/-',perr[1]/1e3,'us')
print('rabi rate =',params[3])
print('$\pi$/$\Omega_R$ =',1/params[3],'+/-',perr[3],'ns')

T2=params[1]
T2_err=perr[1]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\qcodes\utils\deprecate.py:59: QCoDeSDeprecationWarning: The function <get_data_by_id> is deprecated. Use "dataset.get_parameter_data" as an alternative.
#   issue_deprecation_warning(f'{t} <{n}>', reason, alternative)
# [1.01632243e+00 5.84201627e+02 1.15900839e+00 7.02647807e-03
#  1.66942457e+00]
# T2*= 0.5842016269827153 us +/- 0.13360805647439072 us
# rabi rate = 0.007026478066263087
# $\pi$/$\Omega_R$ = 142.3188104437979 +/- 0.00012609244606174422 ns

# %%
df=df.append({'temp':temp,'T1':T1,'T1err':T1_err,'T2_rabi':T2,'T2err':T2_err},ignore_index=True)

# %%
df
# Out:
#     temp     T1  T1err  T2_rabi  T2err
# 0   27.0  19.8k  882.2    882.2   56.1
# 1   75.0  20.9k  879.2    898.1   99.1
# 2  130.0  18.4k  893.2     1.1k  179.7
# 3  140.0  18.9k  914.9    564.4   91.5
# 4  150.0  13.2k   2.3k    795.9  138.8
# 5  160.0  16.3k   1.5k    735.5  118.3
# 6  170.0  12.5k   1.0k    773.7  162.6
# 7  180.0   6.2k   1.3k    584.2  133.6

# %%
df1=df1.sort_values(by=['temp'])

# %%
df.to_csv('temp_table_T150.csv',index=False)

# %%
f,ax=plt.subplots(figsize=(10,8))

ax.errorbar(df['temp'],df['T1'],yerr=df['T1err'],label='T1',ls='--')
ax.errorbar(df['temp'],df['T2_rabi'],yerr=df['T2err'],label='$T2^*_{rabi}$',ls='--')
#plt.yscale('log')
ax.set_ylabel('time(ns)',fontsize=16)
ax.set_xlabel('T(mK)',fontsize=16)
ax.tick_params(axis="both", labelsize=16 )
# ax.set_yscale('log')
plt.title('$T_1$ and $T^*_{2,rabi}$ vs. temperature',fontsize=20)
plt.legend(fontsize=14)
# plt.savefig('T150_coherence_times.png')


ax.errorbar(dfT151['temp'],dfT151['T1'],yerr=dfT151['T1err'],label='T1',ls='--')
ax.errorbar(dfT151['temp'],dfT151['T2_rabi'],yerr=dfT151['T2err'],label='$T2^*_{rabi}$',ls='--')
#plt.yscale('log')
ax.set_ylabel('time(ns)',fontsize=16)
ax.set_xlabel('T(mK)',fontsize=16)
ax.tick_params(axis="both", labelsize=16 )
# ax.set_yscale('log')
plt.title('$T_1$ and $T^*_{2,rabi}$ vs. temperature',fontsize=20)
plt.legend(fontsize=14)
# plt.savefig('T150_coherence_times.png')

# %%
dfT151=pd.read_csv('temp_table.csv')

# %%
# f,ax=plt.subplots(figsize=(10,8))
# Out:
# No handles with labels found to put in legend.

# %%
df1['T2']=1/(1/df1['T2_rabi']-1/2/df1['T1'])

f,ax=plt.subplots()
ax.plot(df1['temp'],1/df1['T2'],'x')
# ax.set_yscale('log')

params, pcov = optimize.curve_fit(boltz_fit, df1['temp'], 1/df1['T2'],bounds=([0.2e-3,1],
                                                                [0.7e-3,400]))
perr = np.sqrt(np.diag(pcov))
ax.plot(temps, boltz_fit(temps, *params),
         label='Fitted function',color='red',ls='--')

print(params)
# Out:
# [6.99999854e-04 1.00429595e+00]

# %%
1/df1['T2']
# Out:
# 0     228.1u
# 17    204.3u
# 1     176.7u
# 2     418.7u
# 3     357.5u
# 5     671.0u
# 7     506.6u
# 8       3.2m
# 9     222.1u
# 10    451.2u
# 13    390.8u
# 14    594.5u
# 15     11.7m
# 16      2.9m
# Name: T2, dtype: float64

# %%
dfT151
# Out:
#    temp     T1  T1err    rate
# 0    25  14872    145     0.0
# 1   200   1319     96  690.9u

# %%
(1/1200-1/2/14872)
# Out:
# 0.0007997131074054151

# %%
7.26e9*sci.h/sci.k
# Out:
# 0.3484250471263876

# %%
temps=np.linspace(25,200,100)

# %%
dfT140_irr=pd.read_csv('T140_irr.csv')
dfT140=pd.read_csv('T140_no_irr.csv')

# %%
dfT151=pd.DataFrame({'temp':[25,200],'T1':[14872,1319],'T1err':[145,96]})

# %%
df1['T1'].max()
# Out:
# 22560.874594217286

# %%
df1['rate']=1e3/df1['T1']-1e3/df1['T1'].max()
dfT151['rate']=1e3/dfT151['T1']-1e3/dfT151['T1'].max()
dfT140['rate']=1e3/dfT140['T1']-1e3/dfT140['T1'].max()
dfT140_irr['rate']=1e3/dfT140_irr['T1']-1e3/dfT140_irr['T1'].max()
f,ax=plt.subplots(figsize=(10,8))


params, pcov = optimize.curve_fit(qp_exp_fit, df1['temp'], df1['rate'],bounds=([1e-8,0,0.0],
                                                                [10,3000,0.01]))
perr = np.sqrt(np.diag(pcov))
ax.plot(temps, qp_exp_fit(temps, *params),
     #    label='Fitted function',
        color='C1',
        ls='--',
        alpha=0.3)
print(params)

params, pcov = optimize.curve_fit(qp_exp_fit, dfT140['T_bath'], dfT140['rate'],bounds=([1e-8,0,0.0],
                                                                [10,3000,0.01]))
perr = np.sqrt(np.diag(pcov))
ax.plot(temps, qp_exp_fit(temps, *params),
        #label='Fitted function',
        color='red',
        ls='--',
        alpha=0.3)
print(params)
params, pcov = optimize.curve_fit(qp_exp_fit, dfT140_irr['T_bath'], dfT140_irr['rate'],bounds=([1e-8,0,0],
                                                                [10,1000,0.5]))
perr = np.sqrt(np.diag(pcov))

print(params)

ax.plot(temps, qp_exp_fit(temps, *params),
       #  label='Fitted function',
        color='brown',
        ls='--',
        alpha=0.3)

ax.errorbar(dfT151['temp'],dfT151['rate'],yerr=dfT151['rate']*dfT151['T1err']/dfT151['T1'],label='T151 before irr',ls='')
ax.errorbar(df1['temp'],df1['rate'],yerr=df1['rate']*df1['T1err']/df1['T1'],label='T151 irr')
ax.errorbar(dfT140['T_bath'],dfT140['rate'],yerr=dfT140['rate']*dfT140['T1err']/dfT140['T1'],label='T140 before irr')
ax.errorbar(dfT140_irr['T_bath'],dfT140_irr['rate'],yerr=dfT140_irr['rate']*dfT140_irr['T1err']/dfT140_irr['T1'],label="T140 irr")

ax.legend(fontsize=16)
#ax.set_yscale('log')  

ax.set_ylabel('Decay rate (1/MHz)',fontsize=16)
ax.set_xlabel('T (mK)',fontsize=16)
ax.tick_params(axis="both", labelsize=16 )
plt.title('$\Gamma_\phi$ vs temperature',fontsize=20)
plt.legend(fontsize=14)

plt.savefig('T151_1_dephasing_time.png')
# Out:
# [8.73677089e+00 1.27371880e+03 1.11949662e-17]
# [1.00000000e+01 1.21256011e+03 6.71611633e-03]
# [1.55939789e+00 1.00000000e+03 1.11099465e-07]

# %% [markdown]
# Delta is 1.32 K!

# %%
df1
# Out:
#      temp     T1  T1err  T2_rabi  T2err    rate
# 0    25.0  22.6k  897.4     4.0k   93.7   44.3u
# 17   80.0  18.9k  786.2     4.3k  130.8   52.9u
# 1   100.0  21.7k  838.3     5.0k  139.4   46.1u
# 2   120.0  20.4k   1.2k     2.3k  141.0   48.9u
# 3   130.0  21.3k   1.4k     2.6k  156.6   47.0u
# 5   140.0  21.5k   1.4k     1.4k  205.6   46.5u
# 7   150.0  16.4k   1.1k     1.9k  153.8   60.9u
# 8   150.0  21.5k   1.9k    314.5   48.6   46.4u
# 9   150.0  18.1k   1.2k     4.0k  221.9   55.3u
# 10  160.0  13.0k   1.2k     2.0k  183.2   77.2u
# 13  175.0   7.9k   1.2k     2.2k  356.9  125.9u
# 14  180.0   6.6k   1.2k     1.5k  225.0  152.0u
# 15  190.0   4.4k   1.9k     84.8   37.6  225.1u
# 16  200.0   4.3k  990.8    332.6   71.8  233.8u

# %%
(1/1.5e-6-1/4e-6)
# Out:
# 416666.6666666666

# %% [markdown]
# Photon shot noise dephasing rate is
# Gamma=n_eq*kappa

# %% [markdown]
# # Octave Testing

# %%
"""
octave_introduction.py: shows the basic commands to control the octave's clock, synthesizers, up-converters, triggers,
down-converters and calibration
"""

from qm.QuantumMachinesManager import QuantumMachinesManager
from qm.octave import *
from qm.octave.octave_manager import ClockMode
from qm.qua import *
import os
import time
import matplotlib.pyplot as plt
#from qualang_tools.units import unit

# Flags to switch between different modes defined below
check_up_converters = False
check_triggers = False
check_down_converters = False
calibration = False

#################################
# Step 0 : Octave configuration #
#################################
opx_ip = "192.168.88.252"
opx_port = 9510
octave_ip = "192.168.88.254"
octave_port = 80
con = "con1"
octave = "octave1"
# The elements used to test the ports of the Octave
elements = ["qe1", "qe2", "qe3", "qe4", "qe5"]
IF = 50e6  # The IF frequency
LO = 6e9  # The LO frequency
# The configuration used here
config = {
    "version": 1,
    "controllers": {
        con: {
            "analog_outputs": {
                1: {"offset": 0.0},
                2: {"offset": 0.0},
                3: {"offset": 0.0},
                4: {"offset": 0.0},
                5: {"offset": 0.0},
                6: {"offset": 0.0},
                7: {"offset": 0.0},
                8: {"offset": 0.0},
                9: {"offset": 0.0},
                10: {"offset": 0.0},
            },
            "digital_outputs": {
                1: {},
                2: {},
                3: {},
                4: {},
                5: {},
            },
            "analog_inputs": {
                1: {"offset": +0.0},
                2: {"offset": +0.0},
            },
        }
    },
    "elements": {
        "qe1": {
            "mixInputs": {
                "I": (con, 1),
                "Q": (con, 2),
                "lo_frequency": LO,
                "mixer": f"octave_{octave}_1",  # a fixed name, do not change.
            },
            "intermediate_frequency": IF,
            "operations": {
                "cw": "const",
                "cw_wo_trig": "const_wo_trig",
                "readout": "readout_pulse",
            },
            "digitalInputs": {
                "switch": {
                    "port": (con, 1),
                    "delay": 136,
                    "buffer": 0,
                },
            },
            "outputs": {
                "out1": (con, 1),
                "out2": (con, 2),
            },
            "time_of_flight": 24,
            "smearing": 0,
        },
        "qe2": {
            "mixInputs": {
                "I": (con, 3),
                "Q": (con, 4),
                "lo_frequency": LO,
                "mixer": f"octave_{octave}_2",  # a fixed name, do not change.
            },
            "intermediate_frequency": IF,
            "operations": {
                "cw": "const",
                "cw_wo_trig": "const_wo_trig",
                "readout": "readout_pulse",
            },
            "digitalInputs": {
                "switch": {
                    "port": (con, 2),
                    "delay": 136,
                    "buffer": 0,
                },
            },
            "outputs": {
                "out1": (con, 1),
                "out2": (con, 2),
            },
            "time_of_flight": 24,
            "smearing": 0,
        },
        "qe3": {
            "mixInputs": {
                "I": (con, 5),
                "Q": (con, 6),
                "lo_frequency": LO,
                "mixer": f"octave_{octave}_3",  # a fixed name, do not change.
            },
            "intermediate_frequency": IF,
            "operations": {
                "cw": "const",
                "cw_wo_trig": "const_wo_trig",
            },
            "digitalInputs": {
                "switch": {
                    "port": (con, 3),
                    "delay": 136,
                    "buffer": 0,
                },
            },
        },
        "qe4": {
            "mixInputs": {
                "I": (con, 7),
                "Q": (con, 8),
                "lo_frequency": LO,
                "mixer": f"octave_{octave}_4",  # a fixed name, do not change.
            },
            "intermediate_frequency": IF,
            "operations": {
                "cw": "const",
                "cw_wo_trig": "const_wo_trig",
            },
            "digitalInputs": {
                "switch": {
                    "port": (con, 4),
                    "delay": 136,
                    "buffer": 0,
                },
            },
        },
        "qe5": {
            "mixInputs": {
                "I": (con, 9),
                "Q": (con, 10),
                "lo_frequency": LO,
                "mixer": f"octave_{octave}_5",  # a fixed name, do not change.
            },
            "intermediate_frequency": IF,
            "operations": {
                "cw": "const",
                "cw_wo_trig": "const_wo_trig",
            },
            "digitalInputs": {
                "switch": {
                    "port": (con, 5),
                    "delay": 136,
                    "buffer": 0,
                },
            },
        },
    },
    "pulses": {
        "const": {
            "operation": "control",
            "length": 1000,
            "waveforms": {
                "I": "const_wf",
                "Q": "zero_wf",
            },
            "digital_marker": "ON",
        },
        "const_wo_trig": {
            "operation": "control",
            "length": 1000,
            "waveforms": {
                "I": "const_wf",
                "Q": "zero_wf",
            },
        },
        "readout_pulse": {
            "operation": "measurement",
            "length": 1000,
            "waveforms": {
                "I": "readout_wf",
                "Q": "zero_wf",
            },
            "integration_weights": {
                "cos": "cosine_weights",
                "sin": "sine_weights",
                "minus_sin": "minus_sine_weights",
            },
            "digital_marker": "ON",
        },
    },
    "waveforms": {
        "zero_wf": {
            "type": "constant",
            "sample": 0.0,
        },
        "const_wf": {
            "type": "constant",
            "sample": 0.125,
        },
        "readout_wf": {
            "type": "constant",
            "sample": 0.125,
        },
    },
    "digital_waveforms": {
        "ON": {"samples": [(1, 0)]},
        "OFF": {"samples": [(0, 0)]},
    },
    "integration_weights": {
        "cosine_weights": {
            "cosine": [(1.0, 1000)],
            "sine": [(0.0, 1000)],
        },
        "sine_weights": {
            "cosine": [(0.0, 1000)],
            "sine": [(1.0, 1000)],
        },
        "minus_sine_weights": {
            "cosine": [(0.0, 1000)],
            "sine": [(-1.0, 1000)],
        },
    },
    "mixers": {
        f"octave_{octave}_1": [
            {
                "intermediate_frequency": IF,
                "lo_frequency": LO,
                "correction": (1, 0, 0, 1),
            },
        ],
        f"octave_{octave}_2": [
            {
                "intermediate_frequency": IF,
                "lo_frequency": LO,
                "correction": (1, 0, 0, 1),
            },
        ],
        f"octave_{octave}_3": [
            {
                "intermediate_frequency": IF,
                "lo_frequency": LO,
                "correction": (1, 0, 0, 1),
            },
        ],
        f"octave_{octave}_4": [
            {
                "intermediate_frequency": IF,
                "lo_frequency": LO,
                "correction": (1, 0, 0, 1),
            },
        ],
        f"octave_{octave}_5": [
            {
                "intermediate_frequency": IF,
                "lo_frequency": LO,
                "correction": (1, 0, 0, 1),
            },
        ],
    },
}

# Create the octave config object
octave_config = QmOctaveConfig()
# Specify where to store the outcome of the calibration (correction matrix, offsets...)
octave_config.set_calibration_db(os.getcwd())
# Add an Octave called 'octave1' with the specified IP and port
octave_config.add_device_info(octave, octave_ip, octave_port)
# Define the connectivity between our Octave to the OPX(s) ports. The 'default'
# connectivity is as follows:
#    +- OCTAVE (octavfqoe1) --------------------------------------------------------+
#    |                                      I1    I2    I3    I4    I5           |
#    |             o    o    o    o    o     o<+   o<+   o<+   o<+   o<+     o   |
#    |   o    o                           QM   |     |     |     |     |         |
#    |             o    o    o    o    o   +>o | +>o | +>o | +>o | +>o |     o   |
#    |                                     |Q1 | |Q2 | |Q3 | |Q4 | |Q5 |         |
#    +-------------------------------------|---|-|---|-|---|-|---|-|---|---------+
#                                          |   | |   | |   | |   | |   |
#                                          |   | |   | |   | |   | |   |
#    +- OPX (con1) ------------------------|---|-|---|-|---|-|---|-|---|---------+
#    |                                     | 1 | | 3 | | 5 | | 7 | | 9 |         |
#    |     o     o     o     o     o    |  | o<+ | o<+ | o<+ | o<+ | o<+ |   o   |
#    |                                     |     |     |     |     |             |
#    |     o     o     o     o     o    |  +>o   +>o   +>o   +>o   +>o   |   o   |
#    |                                       2     4     6     8    10           |
#    +---------------------------------------------------------------------------+
octave_config.set_opx_octave_mapping([(con, octave)])
# The last command is equivalent to
# octave_config.add_opx_octave_port_mapping({
#     ('con1',  1) : ('octave1', 'I1'),
#     ('con1',  2) : ('octave1', 'Q1'),
#     ('con1',  3) : ('octave1', 'I2'),
#     ('con1',  4) : ('octave1', 'Q2'),
#     ('con1',  5) : ('octave1', 'I3'),
#     ('con1',  6) : ('octave1', 'Q3'),
#     ('con1',  7) : ('octave1', 'I4'),
#     ('con1',  8) : ('octave1', 'Q4'),
#     ('con1',  9) : ('octave1', 'I5'),
#     ('con1', 10) : ('octave1', 'Q5'),
# })

# Open the QuantumMachineManager for the OPX and Octave
qmm = QuantumMachinesManager(host=opx_ip, port=opx_port, octave=octave_config)
# Open a quantum machine to calibrate the ports or play signals
qm = qmm.open_qm(config)

# Simple test program that plays a continuous wave through all ports
with program() as hello_octave:
    with infinite_loop_():
        for el in elements:
            play("cw", el)

###########################
# Step 1 : clock settings #
###########################
external_clock = False
if external_clock:
    # Change to the relevant external frequency
    qm.octave.set_clock(octave, clock_mode=ClockMode.External_10MHz)
else:
    qm.octave.set_clock(octave, clock_mode=ClockMode.Internal)
# You can connect clock out from rear panel to a spectrum analyzer  to see the 1GHz signal

#########################################
# Step 2 : set LO, RF gain, and RF mode #
#########################################
external_LO = False
# For external LO only:
if external_LO:
    # OctaveLOSource.LO1,2,3,4,5 to use an external LO source connected to the corresponding ports in the rear panel.
    qm.octave.set_lo_source(elements[1], OctaveLOSource.LO2)
    qm.octave.set_rf_output_gain(elements[1], 0)  # can set the gain from -10dB to 20dB
    qm.octave.set_rf_output_mode(elements[1], RFOutputMode.on)  # set the behaviour of the RF switch to be 'on'.
# For internal LO only:
else:
    for el in elements:
        qm.octave.set_lo_source(el, OctaveLOSource.Internal)  # Use the internal synthetizer to generate the LO.
        qm.octave.set_lo_frequency(el, LO)  # assign the LO inside the octave to element
        qm.octave.set_rf_output_gain(el, 0)  # can set the gain from -10dB to 20dB
        qm.octave.set_rf_output_mode(el, RFOutputMode.on)  # set the behaviour of the RF switch to be 'on'.
        # 'RFOutputMode' can be : on, off, trig_normal or trig_inverse
        # You can check the internal LOs by connecting the ports synth1, 2 and 3 to a spectrum analyzer.

#######################################
# Step 3 : checking the up-converters #
#######################################
if check_up_converters:
    print("-" * 37 + " Checking up-converters")
    job = qm.execute(hello_octave)
    time.sleep(60)  # The program will run for 1 minute
    job.halt()
    # You can connect RF1, RF2, RF3, RF4, RF5 to a spectrum analyzer and check the 3 peaks before calibration:
    # 1. LO-IF, 2. LO, 3. LO+IF
# Out:
# 2023-11-08 13:14:26,677 - qm - INFO     - Performing health check
# 2023-11-08 13:14:26,686 - qm - INFO     - Health check passed
# C:\Users\measPC\AppData\Local\Temp\ipykernel_1852\1599568912.py:308: DeprecationWarning: OctaveConfig.set_opx_octave_mapping is deprecated as of 1.1.0 and will be removed in 1.2.0, The port mapping was moved to the config. Please set the mapping there
#   octave_config.set_opx_octave_mapping([(con, octave)])
# d:\anaconda3\lib\site-packages\qm\octave\octave_config.py:342: DeprecationWarning: Setting port mapping was moved to the config, please move your mapping there
#   conns = self.get_opx_octave_port_mapping()
# d:\anaconda3\lib\site-packages\qm\octave\octave_config.py:342: DeprecationWarning: Setting port mapping was moved to the config, please move your mapping there
#   conns = self.get_opx_octave_port_mapping()
# ...

# %%
"""
octave_introduction.py: shows the basic commands to control the octave's clock, synthesizers, up-converters, triggers,
down-converters and calibration
"""

from qm.QuantumMachinesManager import QuantumMachinesManager
from qm.octave import *
from qm.octave.octave_manager import ClockMode
from qm.qua import *
import os
import time
import matplotlib.pyplot as plt
#from qualang_tools.units import unit

# Flags to switch between different modes defined below
check_up_converters = True
check_triggers = False
check_down_converters = False
calibration = False

#################################
# Step 0 : Octave configuration #
#################################
opx_ip = "192.168.88.252"
opx_port = 9510
octave_ip = "192.168.88.254"
octave_port = 80
con = "con1"
octave = "octave1"
# The elements used to test the ports of the Octave
elements = ["qe1", "qe2", "qe3", "qe4", "qe5"]
IF = 50e6  # The IF frequency
LO = 6e9  # The LO frequency
# The configuration used here
config = {
    "version": 1,
    "controllers": {
        con: {
            "analog_outputs": {
                1: {"offset": 0.0},
                2: {"offset": 0.0},
                3: {"offset": 0.0},
                4: {"offset": 0.0},
                5: {"offset": 0.0},
                6: {"offset": 0.0},
                7: {"offset": 0.0},
                8: {"offset": 0.0},
                9: {"offset": 0.0},
                10: {"offset": 0.0},
            },
            "digital_outputs": {
                1: {},
                2: {},
                3: {},
                4: {},
                5: {},
            },
            "analog_inputs": {
                1: {"offset": +0.0},
                2: {"offset": +0.0},
            },
        }
    },
    "elements": {
        "qe1": {
            "mixInputs": {
                "I": (con, 1),
                "Q": (con, 2),
                "lo_frequency": LO,
                "mixer": f"octave_{octave}_1",  # a fixed name, do not change.
            },
            "intermediate_frequency": IF,
            "operations": {
                "cw": "const",
                "cw_wo_trig": "const_wo_trig",
                "readout": "readout_pulse",
            },
            "digitalInputs": {
                "switch": {
                    "port": (con, 1),
                    "delay": 136,
                    "buffer": 0,
                },
            },
            "outputs": {
                "out1": (con, 1),
                "out2": (con, 2),
            },
            "time_of_flight": 24,
            "smearing": 0,
        },
        "qe2": {
            "mixInputs": {
                "I": (con, 3),
                "Q": (con, 4),
                "lo_frequency": LO,
                "mixer": f"octave_{octave}_2",  # a fixed name, do not change.
            },
            "intermediate_frequency": IF,
            "operations": {
                "cw": "const",
                "cw_wo_trig": "const_wo_trig",
                "readout": "readout_pulse",
            },
            "digitalInputs": {
                "switch": {
                    "port": (con, 2),
                    "delay": 136,
                    "buffer": 0,
                },
            },
            "outputs": {
                "out1": (con, 1),
                "out2": (con, 2),
            },
            "time_of_flight": 24,
            "smearing": 0,
        },
        "qe3": {
            "mixInputs": {
                "I": (con, 5),
                "Q": (con, 6),
                "lo_frequency": LO,
                "mixer": f"octave_{octave}_3",  # a fixed name, do not change.
            },
            "intermediate_frequency": IF,
            "operations": {
                "cw": "const",
                "cw_wo_trig": "const_wo_trig",
            },
            "digitalInputs": {
                "switch": {
                    "port": (con, 3),
                    "delay": 136,
                    "buffer": 0,
                },
            },
        },
        "qe4": {
            "mixInputs": {
                "I": (con, 7),
                "Q": (con, 8),
                "lo_frequency": LO,
                "mixer": f"octave_{octave}_4",  # a fixed name, do not change.
            },
            "intermediate_frequency": IF,
            "operations": {
                "cw": "const",
                "cw_wo_trig": "const_wo_trig",
            },
            "digitalInputs": {
                "switch": {
                    "port": (con, 4),
                    "delay": 136,
                    "buffer": 0,
                },
            },
        },
        "qe5": {
            "mixInputs": {
                "I": (con, 9),
                "Q": (con, 10),
                "lo_frequency": LO,
                "mixer": f"octave_{octave}_5",  # a fixed name, do not change.
            },
            "intermediate_frequency": IF,
            "operations": {
                "cw": "const",
                "cw_wo_trig": "const_wo_trig",
            },
            "digitalInputs": {
                "switch": {
                    "port": (con, 5),
                    "delay": 136,
                    "buffer": 0,
                },
            },
        },
    },
    "pulses": {
        "const": {
            "operation": "control",
            "length": 1000,
            "waveforms": {
                "I": "const_wf",
                "Q": "zero_wf",
            },
            "digital_marker": "ON",
        },
        "const_wo_trig": {
            "operation": "control",
            "length": 1000,
            "waveforms": {
                "I": "const_wf",
                "Q": "zero_wf",
            },
        },
        "readout_pulse": {
            "operation": "measurement",
            "length": 1000,
            "waveforms": {
                "I": "readout_wf",
                "Q": "zero_wf",
            },
            "integration_weights": {
                "cos": "cosine_weights",
                "sin": "sine_weights",
                "minus_sin": "minus_sine_weights",
            },
            "digital_marker": "ON",
        },
    },
    "waveforms": {
        "zero_wf": {
            "type": "constant",
            "sample": 0.0,
        },
        "const_wf": {
            "type": "constant",
            "sample": 0.125,
        },
        "readout_wf": {
            "type": "constant",
            "sample": 0.125,
        },
    },
    "digital_waveforms": {
        "ON": {"samples": [(1, 0)]},
        "OFF": {"samples": [(0, 0)]},
    },
    "integration_weights": {
        "cosine_weights": {
            "cosine": [(1.0, 1000)],
            "sine": [(0.0, 1000)],
        },
        "sine_weights": {
            "cosine": [(0.0, 1000)],
            "sine": [(1.0, 1000)],
        },
        "minus_sine_weights": {
            "cosine": [(0.0, 1000)],
            "sine": [(-1.0, 1000)],
        },
    },
    "mixers": {
        f"octave_{octave}_1": [
            {
                "intermediate_frequency": IF,
                "lo_frequency": LO,
                "correction": (1, 0, 0, 1),
            },
        ],
        f"octave_{octave}_2": [
            {
                "intermediate_frequency": IF,
                "lo_frequency": LO,
                "correction": (1, 0, 0, 1),
            },
        ],
        f"octave_{octave}_3": [
            {
                "intermediate_frequency": IF,
                "lo_frequency": LO,
                "correction": (1, 0, 0, 1),
            },
        ],
        f"octave_{octave}_4": [
            {
                "intermediate_frequency": IF,
                "lo_frequency": LO,
                "correction": (1, 0, 0, 1),
            },
        ],
        f"octave_{octave}_5": [
            {
                "intermediate_frequency": IF,
                "lo_frequency": LO,
                "correction": (1, 0, 0, 1),
            },
        ],
    },
}

# Create the octave config object
octave_config = QmOctaveConfig()
# Specify where to store the outcome of the calibration (correction matrix, offsets...)
octave_config.set_calibration_db(os.getcwd())
# Add an Octave called 'octave1' with the specified IP and port
octave_config.add_device_info(octave, octave_ip, octave_port)
# Define the connectivity between our Octave to the OPX(s) ports. The 'default'
# connectivity is as follows:
#    +- OCTAVE (octave1) --------------------------------------------------------+
#    |                                      I1    I2    I3    I4    I5           |
#    |             o    o    o    o    o     o<+   o<+   o<+   o<+   o<+     o   |
#    |   o    o                           QM   |     |     |     |     |         |
#    |             o    o    o    o    o   +>o | +>o | +>o | +>o | +>o |     o   |
#    |                                     |Q1 | |Q2 | |Q3 | |Q4 | |Q5 |         |
#    +-------------------------------------|---|-|---|-|---|-|---|-|---|---------+
#                                          |   | |   | |   | |   | |   |
#                                          |   | |   | |   | |   | |   |
#    +- OPX (con1) ------------------------|---|-|---|-|---|-|---|-|---|---------+
#    |                                     | 1 | | 3 | | 5 | | 7 | | 9 |         |
#    |     o     o     o     o     o    |  | o<+ | o<+ | o<+ | o<+ | o<+ |   o   |
#    |                                     |     |     |     |     |             |
#    |     o     o     o     o     o    |  +>o   +>o   +>o   +>o   +>o   |   o   |
#    |                                       2     4     6     8    10           |
#    +---------------------------------------------------------------------------+
octave_config.set_opx_octave_mapping([(con, octave)])
# The last command is equivalent to
# octave_config.add_opx_octave_port_mapping({
#     ('con1',  1) : ('octave1', 'I1'),
#     ('con1',  2) : ('octave1', 'Q1'),
#     ('con1',  3) : ('octave1', 'I2'),
#     ('con1',  4) : ('octave1', 'Q2'),
#     ('con1',  5) : ('octave1', 'I3'),
#     ('con1',  6) : ('octave1', 'Q3'),
#     ('con1',  7) : ('octave1', 'I4'),
#     ('con1',  8) : ('octave1', 'Q4'),
#     ('con1',  9) : ('octave1', 'I5'),
#     ('con1', 10) : ('octave1', 'Q5'),
# })

# Open the QuantumMachineManager for the OPX and Octave
qmm = QuantumMachinesManager(host=opx_ip, port=opx_port, octave=octave_config)
# Open a quantum machine to calibrate the ports or play signals
qm = qmm.open_qm(config)

# Simple test program that plays a continuous wave through all ports
with program() as hello_octave:
    with infinite_loop_():
        for el in elements:
            play("cw", el)

###########################
# Step 1 : clock settings #
###########################
external_clock = False
if external_clock:
    # Change to the relevant external frequency
    qm.octave.set_clock(octave, clock_mode=ClockMode.External_10MHz)
else:
    qm.octave.set_clock(octave, clock_mode=ClockMode.Internal)
# You can connect clock out from rear panel to a spectrum analyzer  to see the 1GHz signal

#########################################
# Step 2 : set LO, RF gain, and RF mode #
#########################################
external_LO = False
# For external LO only:
if external_LO:
    # OctaveLOSource.LO1,2,3,4,5 to use an external LO source connected to the corresponding ports in the rear panel.
    qm.octave.set_lo_source(elements[1], OctaveLOSource.LO2)
    qm.octave.set_rf_output_gain(elements[1], 0)  # can set the gain from -10dB to 20dB
    qm.octave.set_rf_output_mode(elements[1], RFOutputMode.on)  # set the behaviour of the RF switch to be 'on'.
# For internal LO only:
else:
    for el in elements:
        qm.octave.set_lo_source(el, OctaveLOSource.Internal)  # Use the internal synthetizer to generate the LO.
        qm.octave.set_lo_frequency(el, LO)  # assign the LO inside the octave to element
        qm.octave.set_rf_output_gain(el, 0)  # can set the gain from -10dB to 20dB
        qm.octave.set_rf_output_mode(el, RFOutputMode.on)  # set the behaviour of the RF switch to be 'on'.
        # 'RFOutputMode' can be : on, off, trig_normal or trig_inverse
        # You can check the internal LOs by connecting the ports synth1, 2 and 3 to a spectrum analyzer.

#######################################
# Step 3 : checking the up-converters #
#######################################
if check_up_converters:
    print("-" * 37 + " Checking up-converters")
    job = qm.execute(hello_octave)
    time.sleep(60)  # The program will run for 1 minute
    job.halt()
    # You can connect RF1, RF2, RF3, RF4, RF5 to a spectrum analyzer and check the 3 peaks before calibration:
    # 1. LO-IF, 2. LO, 3. LO+IF
# Out:
# <ipython-input-27-dcd27a5b3b40>:308: DeprecationWarning: OctaveConfig.set_opx_octave_mapping is deprecated as of 1.1.0 and will be removed in 1.2.0, The port mapping was moved to the config. Please set the mapping there
#   octave_config.set_opx_octave_mapping([(con, octave)])
# Exception in thread Thread-11:
# Traceback (most recent call last):
#   File "d:\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "d:\anaconda3\lib\site-packages\qm\run_async.py", line 32, in run
#   File "d:\anaconda3\lib\asyncio\runners.py", line 43, in run
#     return loop.run_until_complete(main)
#   File "d:\anaconda3\lib\asyncio\base_events.py", line 616, in run_until_complete
#     return future.result()
#   File "d:\anaconda3\lib\site-packages\qua\client.py", line 22, in get_server_info
#     response = await service.get_info()
#   File "d:\anaconda3\lib\site-packages\qua\grpc\io\qualang\api\v1.py", line 33, in get_info
#     return await self._unary_unary(
# ...

# %%
from qualang_tools.units import unit
import matplotlib as plt
##################################
# Step 4 : checking the triggers #
##################################
if check_triggers:
    print("-" * 37 + " Checking triggers")
    # Connect RF1, RF2, RF3, RF4, RF5 to a spectrum analyzer and check that you get a signal for 4sec then don't get a signal fo 4 sec and so on.
    for el in elements:
        # set the behaviour of the RF switch to be on only when triggered
        qm.octave.set_rf_output_mode(el, RFOutputMode.trig_normal)

    with program() as hello_octave_trigger:
        with infinite_loop_():
            for el in elements:
                play("cw", el, duration=1e9)
                play("cw_wo_trig", el, duration=1e9)
    job = qm.execute(hello_octave_trigger)
    time.sleep(60)  #  The program will run for 1 minute
    job.halt()

#########################################
# Step 5 : checking the down-converters #
#########################################
if check_down_converters:
    print("-" * 37 + " Checking down-converters")
    # Connect RF1 -> RF1In, RF2 -> RF2In
    # Connect IFOUT1 -> AI1 , IFOUT2 -> AI2
    check_down_converter_1 = True
    check_down_converter_2 = False
    u = unit()
    if check_down_converter_1:
        # Reduce the Octave gain to avoid saturating the OPX ADC
        qm.octave.set_rf_output_gain(elements[0], -10)
        # Set the Octave down-conversion port to be RF1In1 for the first element "qe1"
        qm.octave.set_qua_element_octave_rf_in_port(elements[0], octave, 1)
        # Set the source of the down-conversion LO to be internal (only for RF1In1)
        qm.octave.set_downconversion(
            elements[0], lo_source=RFInputLOSource.Internal, if_mode_i=IFMode.direct, if_mode_q=IFMode.direct
        )
        with program() as hello_octave_readout_1:
            raw_ADC_1 = declare_stream(adc_trace=True)
            measure("readout", elements[0], raw_ADC_1)
            with stream_processing():
                raw_ADC_1.input1().save("adc_1")
                raw_ADC_1.input2().save("adc_2")
        # Execute the program
        job = qm.execute(hello_octave_readout_1)
        res = job.result_handles
        res.wait_for_all_values()
        # Plot the results
        fig, (ax1, ax2) = plt.subplots(1, 2)
        fig.suptitle("Inputs from down conversion 1")
        adc_1 = u.raw2volts(res.get("adc_1").fetch_all())
        ax1.plot(adc_1, label="Input 1")
        ax1.set_title("amp VS time Input 1")
        ax1.set_xlabel("Time [ns]")
        ax1.set_ylabel("Signal amplitude [V]")

        adc_2 = u.raw2volts(res.get("adc_2").fetch_all())
        ax2.plot(adc_2, label="Input 2")
        ax2.set_title("amp VS time Input 2")
        ax2.set_xlabel("Time [ns]")
        ax2.set_ylabel("Signal amplitude [V]")
        plt.tight_layout()

    if check_down_converter_2:
        # Reduce the Octave gain to avoid saturating the OPX ADC
        qm.octave.set_rf_output_gain(elements[1], -10)
        # Set the Octave down-conversion port to be RF1In2 for the second element "qe2"
        qm.octave.set_qua_element_octave_rf_in_port(elements[1], octave, 2)
        # Set the source of the down-conversion LO to be external from the port Dmd2LO in the rear panel
        qm.octave.set_downconversion(
            elements[1], lo_source=RFInputLOSource.Dmd2LO, if_mode_i=IFMode.direct, if_mode_q=IFMode.direct
        )
        with program() as hello_octave_readout_2:
            raw_ADC_2 = declare_stream(adc_trace=True)
            measure("readout", elements[1], raw_ADC_2)
            with stream_processing():
                raw_ADC_2.input1().save("adc_1")
                raw_ADC_2.input2().save("adc_2")
        # Execute the program
        job = qm.execute(hello_octave_readout_2)
        res = job.result_handles
        res.wait_for_all_values()
        # Plot the results
        fig, (ax1, ax2) = plt.subplots(1, 2)
        fig.suptitle("Inputs from down conversion 2")
        adc_1 = u.raw2volts(res.get("adc_1").fetch_all())
        ax1.plot(adc_1, label="Input 1")
        ax1.set_title("amp VS time Input 1")
        ax1.set_xlabel("Time [ns]")
        ax1.set_ylabel("Signal amplitude [V]")

        adc_2 = u.raw2volts(res.get("adc_2").fetch_all())
        ax2.plot(adc_2, label="Input 2")
        ax2.set_title("amp VS time Input 2")
        ax2.set_xlabel("Time [ns]")
        ax2.set_ylabel("Signal amplitude [V]")
        plt.tight_layout()

#################################
# Step 6 : checking calibration #
#################################
if calibration:
    print("-" * 37 + " Play before calibration")
    # Step 5.1: Connect RF1 and run these lines in order to see the uncalibrated signal first
    job = qm.execute(hello_octave)
    time.sleep(10)  # The program will run for 10 seconds
    job.halt()
    # Step 5.2: Run this in order to calibrate
    for i in range(len(elements)):
        print("-" * 37 + f" Calibrates {elements[i]}")
        qm.octave.calibrate_element(elements[i], [(LO, IF)])  # can provide many pairs of LO & IFs.
        qm = qmm.open_qm(config)
    # Step 5.3: Run these and look at the spectrum analyzer and check if you get 1 peak at LO+IF (i.e. 6.05GHz)
    print("-" * 37 + " Play after calibration")
    job = qm.execute(hello_octave)
    time.sleep(30)  # The program will run for 30 seconds
    job.halt()
# Out:
# ------------------------------------- Checking triggers
# C:\Users\measPC\AppData\Local\Temp\ipykernel_1852\3800563651.py:11: DeprecationWarning: QuantumMachine.octave is deprecated since "1.1.0" and will be removed in "1.2.0". Use ElementWithOctave instead. For further details, see elements API.
#   qm.octave.set_rf_output_mode(el, RFOutputMode.trig_normal)
# C:\Users\measPC\AppData\Local\Temp\ipykernel_1852\3800563651.py:11: DeprecationWarning: QuantumMachine.octave is deprecated since "1.1.0" and will be removed in "1.2.0". Use ElementWithOctave instead. For further details, see elements API.
#   qm.octave.set_rf_output_mode(el, RFOutputMode.trig_normal)
# 2023-11-06 14:42:54,316 - qm - INFO     - Sending program to QOP for compilation
# 2023-11-06 14:42:54,390 - qm - INFO     - Executing program

# %% [markdown]
# # Octave Introduction

# %%
"""
octave_introduction.py: shows the basic commands to control the octave's clock, synthesizers, up-converters, triggers,
down-converters and calibration
"""

from qm.QuantumMachinesManager import QuantumMachinesManager
from qm.octave import *
from qm.octave.octave_manager import ClockMode
from qm.qua import *
import os
import time
import matplotlib.pyplot as plt
from qualang_tools.units import unit

# Flags to switch between different modes defined below
check_up_converters = False
check_triggers = False
check_down_converters = False
calibration = False

#################################
# Step 0 : Octave configuration #
#################################
opx_ip = "192.168.88.252"
opx_port = 9510
octave_ip = "192.168.88.254"
octave_port = 80
con = "con1"
octave = "octave1"
# The elements used to test the ports of the Octave
elements = ["qe1", "qe2", "qe3", "qe4", "qe5"]
IF = 50e6  # The IF frequency
LO = 4e9  # The LO frequency <= changed to 3GHz for testing => Rob
minute = 1e3
# The configuration used here
config = {
    "version": 1,
    "controllers": {
        con: {
            "analog_outputs": {
                1: {"offset": 0.0},
                2: {"offset": 0.0},
                3: {"offset": 0.0},
                4: {"offset": 0.0},
                5: {"offset": 0.0},
                6: {"offset": 0.0},
                7: {"offset": 0.0},
                8: {"offset": 0.0},
                9: {"offset": 0.0},
                10: {"offset": 0.0},
            },
            "digital_outputs": {
                1: {},
                2: {},
                3: {},
                4: {},
                5: {},
            },
            "analog_inputs": {
                1: {"offset": +0.0},
                2: {"offset": +0.0},
            },
        }
    },
    "elements": {
        "qe1": {
            "mixInputs": {
                "I": (con, 1),
                "Q": (con, 2),
                "lo_frequency": LO,
                "mixer": f"octave_{octave}_1",  # a fixed name, do not change.
            },
            "intermediate_frequency": IF,
            "operations": {
                "cw": "const",
                "cw_wo_trig": "const_wo_trig",
                "readout": "readout_pulse",
            },
            "digitalInputs": {
                "switch": {
                    "port": (con, 1),
                    "delay": 136,
                    "buffer": 0,
                },
            },
            "outputs": {
                "out1": (con, 1),
                "out2": (con, 2),
            },
            "time_of_flight": 24,#224,
            "smearing": 0,#50,
        },
        "qe2": {
            "mixInputs": {
                "I": (con, 3),
                "Q": (con, 4),
                "lo_frequency": LO,
                "mixer": f"octave_{octave}_2",  # a fixed name, do not change.
            },
            "intermediate_frequency": IF,
            "operations": {
                "cw": "const",
                "cw_wo_trig": "const_wo_trig",
                "readout": "readout_pulse",
            },
            "digitalInputs": {
                "switch": {
                    "port": (con, 2),
                    "delay": 136,
                    "buffer": 0,
                },
            },
            "outputs": {
                "out1": (con, 1),
                "out2": (con, 2),
            },
            "time_of_flight": 24,
            "smearing": 0,
        },
        "qe3": {
            "mixInputs": {
                "I": (con, 5),
                "Q": (con, 6),
                "lo_frequency": LO,
                "mixer": f"octave_{octave}_3",  # a fixed name, do not change.
            },
            "intermediate_frequency": IF,
            "operations": {
                "cw": "const",
                "cw_wo_trig": "const_wo_trig",
            },
            "digitalInputs": {
                "switch": {
                    "port": (con, 3),
                    "delay": 136,
                    "buffer": 0,
                },
            },
        },
        "qe4": {
            "mixInputs": {
                "I": (con, 7),
                "Q": (con, 8),
                "lo_frequency": LO,
                "mixer": f"octave_{octave}_4",  # a fixed name, do not change.
            },
            "intermediate_frequency": IF,
            "operations": {
                "cw": "const",
                "cw_wo_trig": "const_wo_trig",
            },
            "digitalInputs": {
                "switch": {
                    "port": (con, 4),
                    "delay": 136,
                    "buffer": 0,
                },
            },
        },
        "qe5": {
            "mixInputs": {
                "I": (con, 9),
                "Q": (con, 10),
                "lo_frequency": LO,
                "mixer": f"octave_{octave}_5",  # a fixed name, do not change.
            },
            "intermediate_frequency": IF,
            "operations": {
                "cw": "const",
                "cw_wo_trig": "const_wo_trig",
            },
            "digitalInputs": {
                "switch": {
                    "port": (con, 5),
                    "delay": 136,
                    "buffer": 0,
                },
            },
        },
    },
    "pulses": {
        "const": {
            "operation": "control",
            "length": 1000,
            "waveforms": {
                "I": "const_wf",
                "Q": "zero_wf",
            },
            "digital_marker": "ON",
        },
        "const_wo_trig": {
            "operation": "control",
            "length": 1000,
            "waveforms": {
                "I": "const_wf",
                "Q": "zero_wf",
            },
        },
        "readout_pulse": {
            "operation": "measurement",
            "length": 1000, #1000, in nanoseconds #minute,# was set to 1000, currently minute = 1e3 => Rob
            "waveforms": {
                "I": "readout_wf",
                "Q": "zero_wf",
            },
            "integration_weights": {
                "cos": "cosine_weights",
                "sin": "sine_weights",
                "minus_sin": "minus_sine_weights",
            },
            "digital_marker": "ON",
        },
    },
    "waveforms": {
        "zero_wf": {
            "type": "constant",
            "sample": 0.0,
        },
        "const_wf": {
            "type": "constant",
            "sample": 0.032,#0.125,
        },
        "readout_wf": {
            "type": "constant",
            "sample": 0.01, # sampling rate of DAC in 100 nanoseconds #Voltage for 'readout' in measure statement for the down-converters check
        },
    },
    "digital_waveforms": {
        "ON": {"samples": [(1, 0)]},
        "OFF": {"samples": [(0, 0)]},
    },
    "integration_weights": {
        "cosine_weights": {
            "cosine": [(1.0, 1000)],
            "sine": [(0.0, 1000)],
        },
        "sine_weights": {
            "cosine": [(0.0, 1000)],
            "sine": [(1.0, 1000)],
        },
        "minus_sine_weights": {
            "cosine": [(0.0, 1000)],
            "sine": [(-1.0, 1000)],
        },
    },
    "mixers": {
        f"octave_{octave}_1": [
            {
                "intermediate_frequency": IF,
                "lo_frequency": LO,
                "correction": (1, 0, 0, 1),
            },
        ],
        f"octave_{octave}_2": [
            {
                "intermediate_frequency": IF,
                "lo_frequency": LO,
                "correction": (1, 0, 0, 1),
            },
        ],
        f"octave_{octave}_3": [
            {
                "intermediate_frequency": IF,
                "lo_frequency": LO,
                "correction": (1, 0, 0, 1),
            },
        ],
        f"octave_{octave}_4": [
            {
                "intermediate_frequency": IF,
                "lo_frequency": LO,
                "correction": (1, 0, 0, 1),
            },
        ],
        f"octave_{octave}_5": [
            {
                "intermediate_frequency": IF,
                "lo_frequency": LO,
                "correction": (1, 0, 0, 1),
            },
        ],
    },
}

# Create the octave config object
octave_config = QmOctaveConfig()
# Specify where to store the outcome of the calibration (correction matrix, offsets...)
octave_config.set_calibration_db(os.getcwd())
# Add an Octave called 'octave1' with the specified IP and port
octave_config.add_device_info(octave, octave_ip, octave_port)
# Define the connectivity between our Octave to the OPX(s) ports. The 'default'
# connectivity is as follows:
#    +- OCTAVE (octave1) --------------------------------------------------------+
#    |                                      I1    I2    I3    I4    I5           |
#    |             o    o    o    o    o     o<+   o<+   o<+   o<+   o<+     o   |
#    |   o    o                           QM   |     |     |     |     |         |
#    |             o    o    o    o    o   +>o | +>o | +>o | +>o | +>o |     o   |
#    |                                     |Q1 | |Q2 | |Q3 | |Q4 | |Q5 |         |
#    +-------------------------------------|---|-|---|-|---|-|---|-|---|---------+
#                                          |   | |   | |   | |   | |   |
#                                          |   | |   | |   | |   | |   |
#    +- OPX (con1) ------------------------|---|-|---|-|---|-|---|-|---|---------+
#    |                                     | 1 | | 3 | | 5 | | 7 | | 9 |         |
#    |     o     o     o     o     o    |  | o<+ | o<+ | o<+ | o<+ | o<+ |   o   |
#    |                                     |     |     |     |     |             |
#    |     o     o     o     o     o    |  +>o   +>o   +>o   +>o   +>o   |   o   |
#    |                                       2     4     6     8    10           |
#    +---------------------------------------------------------------------------+
octave_config.set_opx_octave_mapping([(con, octave)])
# The last command is equivalent to
# octave_config.add_opx_octave_port_mapping({
#     ('con1',  1) : ('octave1', 'I1'),
#     ('con1',  2) : ('octave1', 'Q1'),
#     ('con1',  3) : ('octave1', 'I2'),
#     ('con1',  4) : ('octave1', 'Q2'),
#     ('con1',  5) : ('octave1', 'I3'),
#     ('con1',  6) : ('octave1', 'Q3'),
#     ('con1',  7) : ('octave1', 'I4'),
#     ('con1',  8) : ('octave1', 'Q4'),
#     ('con1',  9) : ('octave1', 'I5'),
#     ('con1', 10) : ('octave1', 'Q5'),
# })

# Open the QuantumMachineManager for the OPX and Octave
qmm = QuantumMachinesManager(host=opx_ip, port=opx_port, octave=octave_config)
# Open a quantum machine to calibrate the ports or play signals
qm = qmm.open_qm(config)

# Messing with the elements list for understanding the waveforms => ROB
#elements = ["qe1", "qe2", "qe3", "qe4", "qe5"]
elements = ["qe1","qe2"]

# Simple test program that plays a continuous wave through all ports
with program() as hello_octave:
    with infinite_loop_():
        for el in elements:
            play("cw", el)
# Out:
# 2023-11-13 11:36:36,034 - qm - INFO     - Performing health check
# 2023-11-13 11:36:36,045 - qm - INFO     - Health check passed
# C:\Users\measPC\AppData\Local\Temp\ipykernel_1852\471082627.py:309: DeprecationWarning: OctaveConfig.set_opx_octave_mapping is deprecated as of 1.1.0 and will be removed in 1.2.0, The port mapping was moved to the config. Please set the mapping there
#   octave_config.set_opx_octave_mapping([(con, octave)])
# d:\anaconda3\lib\site-packages\qm\octave\octave_config.py:342: DeprecationWarning: Setting port mapping was moved to the config, please move your mapping there
#   conns = self.get_opx_octave_port_mapping()
# d:\anaconda3\lib\site-packages\qm\octave\octave_config.py:342: DeprecationWarning: Setting port mapping was moved to the config, please move your mapping there
#   conns = self.get_opx_octave_port_mapping()
# ...

# %%
###########################
# Step 1 : clock settings #
###########################
external_clock = False
if external_clock:
    # Change to the relevant external frequency
    qm.octave.set_clock(octave, clock_mode=ClockMode.External_10MHz)
else:
    qm.octave.set_clock(octave, clock_mode=ClockMode.Internal)
# You can connect clock out from rear panel to a spectrum analyzer  to see the 1GHz signal

#########################################
# Step 2 : set LO, RF gain, and RF mode #
#########################################
external_LO = False
# For external LO only:
if external_LO:
    # OctaveLOSource.LO1,2,3,4,5 to use an external LO source connected to the corresponding ports in the rear panel.
    qm.octave.set_lo_source(elements[1], OctaveLOSource.LO2)
    qm.octave.set_rf_output_gain(elements[1], 0)  # can set the gain from -10dB to 20dB
    qm.octave.set_rf_output_mode(elements[1], RFOutputMode.on)  # set the behaviour of the RF switch to be 'on'.
# For internal LO only:
else:
    for el in elements:
        qm.octave.set_lo_source(el, OctaveLOSource.Internal)  # Use the internal synthetizer to generate the LO.
        qm.octave.set_lo_frequency(el, LO)  # assign the LO inside the octave to element
        qm.octave.set_rf_output_gain(el, 0)  # can set the gain from -10dB to 20dB
        qm.octave.set_rf_output_mode(el, RFOutputMode.on)  # set the behaviour of the RF switch to be 'on'.
        # 'RFOutputMode' can be : on, off, trig_normal or trig_inverse
        # You can check the internal LOs by connecting the ports synth1, 2 and 3 to a spectrum analyzer.

#######################################
# Step 3 : checking the up-converters #
#######################################
if check_up_converters:
    print("-" * 37 + " Checking up-converters")
    job = qm.execute(hello_octave)
    time.sleep(60)  # The program will run for 1 minute
    job.halt()
    # You can connect RF1, RF2, RF3, RF4, RF5 to a spectrum analyzer and check the 3 peaks before calibration:
    # 1. LO-IF, 2. LO, 3. LO+IF
# Out:
# C:\Users\measPC\AppData\Local\Temp\ipykernel_1852\2656363315.py:9: DeprecationWarning: QuantumMachine.octave is deprecated since "1.1.0" and will be removed in "1.2.0". Use ElementWithOctave instead. For further details, see elements API.
#   qm.octave.set_clock(octave, clock_mode=ClockMode.Internal)
# C:\Users\measPC\AppData\Local\Temp\ipykernel_1852\2656363315.py:25: DeprecationWarning: QuantumMachine.octave is deprecated since "1.1.0" and will be removed in "1.2.0". Use ElementWithOctave instead. For further details, see elements API.
#   qm.octave.set_lo_source(el, OctaveLOSource.Internal)  # Use the internal synthetizer to generate the LO.
# C:\Users\measPC\AppData\Local\Temp\ipykernel_1852\2656363315.py:26: DeprecationWarning: QuantumMachine.octave is deprecated since "1.1.0" and will be removed in "1.2.0". Use ElementWithOctave instead. For further details, see elements API.
#   qm.octave.set_lo_frequency(el, LO)  # assign the LO inside the octave to element
# ...

# %%
# Cell split so we could run only the trigger check

check_triggers = False
##################################
# Step 4 : checking the triggers #
##################################
if check_triggers:
    print("-" * 37 + " Checking triggers")
    # Connect RF1, RF2, RF3, RF4, RF5 to a spectrum analyzer and check that you get a signal for 4sec then don't get a signal fo 4 sec and so on.
    for el in elements:
        # set the behaviour of the RF switch to be on only when triggered
        qm.octave.set_rf_output_mode(el, RFOutputMode.trig_normal)
    with program() as hello_octave_trigger:
        with infinite_loop_():
            for el in elements:
                play("cw", el, duration=1e9)
                play("cw_wo_trig", el, duration=1e9)
    job = qm.execute(hello_octave_trigger)
    time.sleep(60)  #  The program will run for 1 minute
    job.halt()

# %%
elements[0]
# Out:
# 'qe1'

# %%
import matplotlib.pyplot as plt
# Cell split so we could run only the check_triggers
calibration = False #remmeber to comment out -Taha
check_down_converters = True # THIS HAS BEEN CHANGED TO TRUE FROM ORIGINAL VALUE - ROB
#########################################
# Step 5 : checking the down-converters #
#########################################
for el in elements:# -- Taha edit
    # set the behaviour of the RF switch to be on only when triggered
    qm.octave.set_rf_output_mode(el, RFOutputMode.on)
if check_down_converters:
    print("-" * 37 + " Checking down-converters")
    # Connect RF1 -> RF1In, RF2 -> RF2In
    # Connect IFOUT1 -> AI1 , IFOUT2 -> AI2
    check_down_converter_1 = True
    check_down_converter_2 = False
    u = unit()
    if check_down_converter_1:
        # Reduce the Octave gain to avoid saturating the OPX ADC
        qm.octave.set_rf_output_gain(elements[0], -10)
        # Set the Octave down-conversion port to be RF1In1 for the first element "qe1"
        qm.octave.set_qua_element_octave_rf_in_port(elements[0], octave, 1)
        # Set the source of the down-conversion LO to be internal (only for RF1In1)
        qm.octave.set_downconversion(
            elements[0], lo_source=RFInputLOSource.Internal, if_mode_i=IFMode.direct, if_mode_q=IFMode.direct
        )
        with program() as hello_octave_readout_1:
            raw_ADC_1 = declare_stream(adc_trace=True)
            measure("readout", elements[0], raw_ADC_1)
            with stream_processing():
                raw_ADC_1.input1().save("adc_1")
                raw_ADC_1.input2().save("adc_2")
        # Execute the program
        job = qm.execute(hello_octave_readout_1)
        res = job.result_handles
        res.wait_for_all_values()
        # Plot the results
        fig, (ax1, ax2) = plt.subplots(2,1, figsize=(10,7))
        fig.suptitle("Inputs from down conversion 1")
        adc_1 = u.raw2volts(res.get("adc_1").fetch_all())
        ax1.plot(adc_1, label="Input 1")
        ax1.set_title("amp VS time Input 1")
        ax1.set_xlabel("Time [ns]")
        ax1.set_ylabel("Signal amplitude [V]")

        adc_2 = u.raw2volts(res.get("adc_2").fetch_all())
        ax2.plot(adc_2, label="Input 2")
        ax2.set_title("amp VS time Input 2")
        ax2.set_xlabel("Time [ns]")
        ax2.set_ylabel("Signal amplitude [V]")
        plt.tight_layout()

    if check_down_converter_2:
        # Reduce the Octave gain to avoid saturating the OPX ADC
        qm.octave.set_rf_output_gain(elements[1], -10) 
        # Set the Octave down-conversion port to be RF1In2 for the second element "qe2"
        qm.octave.set_qua_element_octave_rf_in_port(elements[1], octave, 2)
        # Set the source of the down-conversion LO to be external from the port Dmd2LO in the rear panel
        qm.octave.set_downconversion(
            elements[1], lo_source=RFInputLOSource.Dmd2LO, if_mode_i=IFMode.direct, if_mode_q=IFMode.direct
        )
        with program() as hello_octave_readout_2:
            raw_ADC_2 = declare_stream(adc_trace=True)
            measure("readout", elements[1], raw_ADC_2)
            with stream_processing():
                raw_ADC_2.input1().save("adc_1")
                raw_ADC_2.input2().save("adc_2")
        # Execute the program
        job = qm.execute(hello_octave_readout_2)
        res = job.result_handles
        res.wait_for_all_values()
        # Plot the results
        fig, (ax1, ax2) = plt.subplots(2,1, figsize=(10,5))
        fig.suptitle("Inputs from down conversion 2")
        adc_1 = u.raw2volts(res.get("adc_1").fetch_all())
        ax1.plot(adc_1, label="Input 1")
        ax1.set_title("amp VS time Input 1")
        ax1.set_xlabel("Time [ns]")
        ax1.set_ylabel("Signal amplitude [V]")

        adc_2 = u.raw2volts(res.get("adc_2").fetch_all())
        ax2.plot(adc_2, label="Input 2")
        ax2.set_title("amp VS time Input 2")
        ax2.set_xlabel("Time [ns]")
        ax2.set_ylabel("Signal amplitude [V]")
        plt.tight_layout()

#################################
# Step 6 : checking calibration #
#################################
if calibration:
    print("-" * 37 + " Play before calibration")
    # Step 5.1: Connect RF1 and run these lines in order to see the uncalibrated signal first
    job = qm.execute(hello_octave)
    time.sleep(10)  # The program will run for 10 seconds
    job.halt()
    # Step 5.2: Run this in order to calibrate
    for i in range(len(elements)):
        print("-" * 37 + f" Calibrates {elements[i]}")
        qm.octave.calibrate_element(elements[i], [(LO, IF)])  # can provide many pairs of LO & IFs.
        qm = qmm.open_qm(config)
    # Step 5.3: Run these and look at the spectrum analyzer and check if you get 1 peak at LO+IF (i.e. 6.05GHz)
    print("-" * 37 + " Play after calibration")
    job = qm.execute(hello_octave)
    time.sleep(30)  # The program will run for 30 seconds
    job.halt()
# Out:
# C:\Users\measPC\AppData\Local\Temp\ipykernel_1852\2420983119.py:10: DeprecationWarning: QuantumMachine.octave is deprecated since "1.1.0" and will be removed in "1.2.0". Use ElementWithOctave instead. For further details, see elements API.
#   qm.octave.set_rf_output_mode(el, RFOutputMode.on)
# C:\Users\measPC\AppData\Local\Temp\ipykernel_1852\2420983119.py:10: DeprecationWarning: QuantumMachine.octave is deprecated since "1.1.0" and will be removed in "1.2.0". Use ElementWithOctave instead. For further details, see elements API.
#   qm.octave.set_rf_output_mode(el, RFOutputMode.on)
# ------------------------------------- Checking down-converters
# C:\Users\measPC\AppData\Local\Temp\ipykernel_1852\2420983119.py:20: DeprecationWarning: QuantumMachine.octave is deprecated since "1.1.0" and will be removed in "1.2.0". Use ElementWithOctave instead. For further details, see elements API.
#   qm.octave.set_rf_output_gain(elements[0], -10)
# ...

# %%
# %matplotlib notebook
